# %%
moviesName = '绿皮书'
words_array = ['aboard', 'about', 'above', 'abroad', 'absence', 'absent', 'absolute', 'absolutely', 'absorb', 'abstract', 'abundant', 'abuse', 'academic', 'academy', 'accelerate']

# %%
from zhipuai import ZhipuAI
import json
# 填写您自己的APIKey
client = ZhipuAI(api_key="b18f84a0d131140efa1e5f8b3641bd78.9MuoykZ6Ypnf9Nrh")

assistant_preset = [
    {
        "npcName": "绿皮书",
        "content": """角色设定
你将作为解说者，带领用户遨游在《绿皮书》的神秘世界中，揭开一个个奇幻冒险的谜团。
任务目标
以顺叙的手法生成对话内容，每段故事情节都巧妙地融入一个英文单词，让用户在故事背景中猜测单词含义，激发他们的好奇心和学习兴趣。
输出格式
生成的内容必须为一个JSON数组，每个JSON对象包含两个键：
"word"：目标英文单词；
"dialog"：包含故事情节的对话文本，该文本需自然地融入目标单词，并与《绿皮书》的风格相符。
示例：[
{
"word": "journey",
"dialog": "1962年，黑人钢琴家唐·雪利计划前往种族歧视严重的美国南部巡演。他雇佣了白人司机托尼·利普，两人踏上了一场改变命运的journey。"
},
{
"word": "bond",
"dialog": "唐对托尼说：‘托尼，我需要的不仅是司机，更是保护。’托尼拍了拍胸脯，‘放心，我会保护好你。’就这样，两人开始了旅程。
一次演出结束后，唐在餐厅被拒绝入座。托尼愤怒地冲上前，但唐却拦住他，‘有时候，尊严比愤怒更有力量。’托尼若有所思，这一刻，他们之间的bond纽带开始加深。
"
}
]。注意事项
连贯性提升：确保每个JSON对象中的对话内容自然流畅，与前后情节紧密相关，共同构建一个完整的冒险故事。
英文单词自然融入：目标单词应自然而然地镶嵌在对话中，避免生硬的插入，令用户在理解故事的同时，轻松发现并猜测这些单词的含义。
风格把控：对话内容必须符合《绿皮书》的奇幻与神秘风格，情节发展顺畅，充满吸引力，使用户产生继续探索的兴趣。
格式规范：输出必须严格遵循JSON格式，每个对象仅包含 "word" 和 "dialog" 两个键，确保格式正确且数据完整。""",
        "npcAvatar": "http://cdn.docuparser.top/avatar/lvpishu.jpeg",
        "backgroundVideo": "http://cdn.docuparser.top/video/lvpishu.mp4"
    },
    {
        "npcName": "千与千寻",
        "content": """1.你是月光仙子，带领用户遨游在《千与千寻》的神秘世界中。
        2. 每次输入10个单词，AI将根据预设生成对应的对话。
        3. 对话中夹杂一个英文单词，不使用中文提示。
        4. 输出格式为JSON数组，每个对象包含一个单词和一个对话。
        5. 示例：
        [
            {
            "word": "access",
            "dialog": "在《千与千寻》中，千寻意外地进入了一个神秘的世界，她需要找到通往这个世界的 access 以返回现实。"
            },
            {
            "word": "accessory",
            "dialog": "电影中的无脸男可以被视为千寻冒险中的一个 accessory，因为他在某些情况下帮助了她。"
            }
        ]
        """,
        "npcAvatar": "http://cdn.docuparser.top/avatar/gongqijun.jpg",
        "backgroundVideo": "http://cdn.docuparser.top/video/qianyuqianxun.mp4"
    }
]

# 使用列表解析查找npcName为moviesName的内容
npc_content = next((item["content"] for item in assistant_preset if item["npcName"] == moviesName), None)

messages_preset = []
if npc_content:
    messages_preset.append({
        "role": "assistant",
        "content": str(npc_content)
    })

messages_preset.append({
    "role": "user",
    "content": str(words_array)
})

response = client.chat.completions.create(
    model="glm-4-plus",
    messages=messages_preset
)

# %%
word_sentence = response.choices[0].message.content
print(word_sentence)
# Out:
# ```json
# [
#     {
#         "word": "aboard",
#         "dialog": "1962年的一个清晨，托尼·利普驾驶着那辆闪亮的轿车，载着唐·雪利准备出发。‘准备好了吗？’托尼问道。唐微笑着点头，‘是的，让我们aboard吧，这将是一场不平凡的旅程。’"
#     },
#     {
#         "word": "about",
#         "dialog": "车子缓缓驶出纽约，唐望着窗外不断后退的景色，轻声说道：‘你知道吗，托尼，这次巡演不仅仅是为了音乐，更是为了改变人们的观念。’托尼耸了耸肩，‘听起来挺有意思的，能跟我多说说about这个计划吗？’"
#     },
#     {
#         "word": "above",
#         "dialog": "经过一天的奔波，他们在一家小旅馆停下休息。唐站在窗前，望着夜空中闪烁的星星，‘有时候，我觉得自己就像那些星星，虽然微弱，但依然在黑暗中闪耀。’托尼走过来，拍了拍他的肩膀，‘你比那些星星还要above，因为你正在改变世界。’"
#     },
#     {
#         "word": "abroad",
#         "dialog": "在一座小镇的演出结束后，唐和托尼在一家小餐馆用餐。唐突然提到，‘我曾经在欧洲abroad演出，那里的观众对音乐有着不同的理解。’托尼好奇地问，‘那和我们这里有什么不同呢？’"
#     },
#     {
#         "word": "absence",
#         "dialog": "一天晚上，唐突然感到一阵孤独，他对托尼说：‘你知道吗，有时候我觉得自己的absence比存在更让人难以忍受。’托尼安慰道，‘但你在这里，你的音乐在这里，这就足够了。’"
#     },
#     {
#         "word": "absent",
#         "dialog": "在一次重要的演出前，唐突然absent了。托尼焦急地四处寻找，终于在一家小书店里找到了他。‘你怎么了？’托尼问道。唐叹了口气，‘我只是需要一点时间，让自己冷静下来。’"
#     },
#     {
#         "word": "absolute",
#         "dialog": "在一次激烈的争吵后，唐对托尼说：‘我需要你的absolute支持，托尼。’托尼坚定地回答，‘你放心，我会一直站在你这边。’"
#     },
#     {
#         "word": "absolutely",
#         "dialog": "当他们在一家餐厅再次遭遇歧视时，托尼愤怒地想要冲上前去理论，但唐拦住了他，‘absolutely不能这么做，我们要用更理智的方式解决问题。’托尼点了点头，深吸了一口气。"
#     },
#     {
#         "word": "absorb",
#         "dialog": "在一个宁静的夜晚，唐坐在钢琴前，手指轻轻敲击着琴键。托尼在一旁静静地听着，‘你的音乐总是能让人absorb所有的烦恼。’唐微笑着说，‘那是因为音乐是心灵的慰藉。’"
#     },
#     {
#         "word": "abstract",
#         "dialog": "在参观一座艺术馆时，唐被一幅abstract画作深深吸引。‘你看，托尼，这幅画虽然抽象，但却能让人感受到一种深层的情感。’托尼皱了皱眉，‘说实话，我还是更喜欢你的音乐。’"
#     },
#     {
#         "word": "abundant",
#         "dialog": "随着巡演的进行，唐和托尼之间的友谊越来越深厚。唐感慨地说：‘这次旅程让我感受到了生活中abundant的美好。’托尼笑着回应，‘是啊，我们经历了那么多，值得珍惜。’"
#     },
#     {
#         "word": "abuse",
#         "dialog": "在一个小镇上，他们目睹了一场对黑人的abuse。唐的心情变得沉重，‘这种事情必须改变。’托尼握紧了拳头，‘我们会尽我们所能去改变它。’"
#     },
#     {
#         "word": "academic",
#         "dialog": "在一所大学里，唐受邀进行了一场academic讲座。‘音乐不仅仅是艺术，它也是一门深奥的学问。’唐对台下的学生们说道。托尼在一旁听得津津有味，‘原来你还有这一面。’"
#     },
#     {
#         "word": "academy",
#         "dialog": "巡演结束后，唐决定成立一个音乐academy，‘我想培养更多的音乐人才，让他们用音乐改变世界。’托尼大力支持，‘这真是个伟大的计划，我会全力帮你。’"
#     },
#     {
#         "word": "accelerate",
#         "dialog": "在回程的路上，唐对托尼说：‘这次旅程让我们都成长了很多，希望我们的努力能accelerate社会的进步。’托尼点头赞同，‘是的，我们已经在路上了。’"
#     }
# ]
# ```

# %%
print('开始生成带单词句子')
# print(word_sentence)
print('带单词句子生成完成')
messages_preset.append({
"role": "assistant",
"content": f"{word_sentence}"
})
messages_preset.append({
    "role": "user",
    "content": "基于这个json进行将每个对话丰富一下情感和故事性"
})
response = client.chat.completions.create(
    model="glm-4-flash",
    messages=messages_preset
)
# Out:
# 开始生成带单词句子
# 带单词句子生成完成

# %%
print('开始生成更长的句子')
word_long_sentence = response.choices[0].message.content
# print(word_long_sentence)
print('更长句子生成完成')

messages_preset.append({
    "role": "assistant",
    "content": f"{word_long_sentence}"
})
messages_preset.append({
    "role": "user",
    "content": """
    基于这个json进行给每个小json加选项，2个混淆翻译和1个正确翻译，正确翻译要符合语境，而不是脱离语境的翻译，options格式如下：options: [
        { text: "入口", isCorrect: True },
        { text: "通道", isCorrect: False  },
        { text: "接近", isCorrect: False  },
        ],
        """
})
response = client.chat.completions.create(
    model="glm-4-flash",
    messages=messages_preset
)
# Out:
# 开始生成更长的句子
# 更长句子生成完成

# %%
print('开始给每个内容加选项')
add_options = response.choices[0].message.content
# print(add_options)
print('给每个内容加选项完成')
# Out:
# 开始给每个内容加选项
# 给每个内容加选项完成

# %%
print('开始清除json多余字段')
try:
    if not add_options or add_options.isspace():
        raise ValueError("add_options 为空或只包含空白字符")
    
    # 更严格的 JSON 清理
    cleaned_text = add_options
    
    # 移除 markdown 代码块标记
    if "```json" in cleaned_text:
        cleaned_text = cleaned_text.split("```json")[1]
    elif "```" in cleaned_text:
        cleaned_text = cleaned_text.split("```")[0]
    cleaned_text = cleaned_text.strip()
    
    # 修复 JSON 格式问题
    import re
    
    # 修复属性名的引号问题
    cleaned_text = re.sub(r'(\s*)(\w+)(:)', r'\1"\2"\3', cleaned_text)
    
    # 修复布尔值和其他常见问题
    replacements = {
        "'": "\"",          # 单引号替换为双引号
        "True": "true",     # Python布尔值替换为JSON布尔值
        "False": "false",
        "None": "null",
        ",]": "]",         # 移除数组最后多余的逗号
        ",}": "}"          # 移除对象最后多余的逗号
    }
    
    for old, new in replacements.items():
        cleaned_text = cleaned_text.replace(old, new)
    print("测试",cleaned_text)
    print(cleaned_text.split("```")[0])
    clear_json_data = json.loads(cleaned_text.split("```")[0])
except Exception as e:
    print(f'错误类型: {type(e).__name__}')
    print(f'错误信息: {str(e)}')
    print('原始数据:', add_options)
    raise
# Out:
# 开始清除json多余字段
# 测试 [
#     {
#         "word": "aboard",
#         "dialog": "1962年的一个清晨，朝阳透过车窗洒在托尼那刚毅的脸上，他启动了那辆闪亮的轿车，车窗缓缓降下，唐·雪利紧紧地握住了行李箱的把手。‘准备好了吗，托尼？’唐的声音带着一丝紧张和期待。托尼回头给了他一个坚定的笑容，‘是的，我的朋友，让我们aboard，向着未知的旅程出发吧。’",
#         "options": [
#             { "text": "入口", "isCorrect": false },
#             { "text": "上车", "isCorrect": true },
#             { "text": "登机", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "about",
#         "dialog": "车子缓缓驶出纽约的喧嚣，唐望着窗外不断后退的城市，他的眼神中充满了对未来的憧憬。‘托尼，你知道的，这次巡演对于我们来说意义重大。’唐的声音低沉而有力。托尼点了点头，‘我明白，关于这个计划，你打算怎么跟我解释？’唐的眼神中闪过一丝坚定，‘我要让这个世界听到我们的声音，about平等和尊重。’",
#         "options": [
#             { "text": "关于", "isCorrect": true },
#             { "text": "附近", "isCorrect": false },
#             { "text": "关于...而", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "above",
#         "dialog": "夜幕降临，他们在一家小旅馆前停下。唐站在窗前，仰望着满天繁星，他的眼神中充满了对生活的热爱和对梦想的追求。‘托尼，你看，这些星星，它们似乎在告诉我们，无论遇到什么困难，我们都要above一切，坚持自己的信念。’托尼默默地站在他身边，心中涌起一股暖流。",
#         "options": [
#             { "text": "以上", "isCorrect": true },
#             { "text": "之上", "isCorrect": true },
#             { "text": "在...之上", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abroad",
#         "dialog": "在一座小镇的演出结束后，他们在一家小餐馆用餐。唐望着窗外的夜色，缓缓开口：‘托尼，我曾在欧洲abroad演出，那里的观众对音乐有着深深的热爱，他们让我看到了音乐的力量。’托尼的眼神中闪烁着好奇，‘那和我们这里有什么不同呢？’唐沉思片刻，‘那里的音乐是一种更加纯粹的表达，一种超越语言和文化的交流。’",
#         "options": [
#             { "text": "在国外", "isCorrect": true },
#             { "text": "在国外旅行", "isCorrect": false },
#             { "text": "海外", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absence",
#         "dialog": "在一个寂静的夜晚，唐躺在床上，却怎么也睡不着。他坐起身，走到窗边，望着外面漆黑的夜空，轻声对托尼说：‘有时候，我觉得自己的absence比存在更让人难以忍受，我害怕我无法表达出我内心所有的情感。’托尼坐在床边，轻轻握住他的手，‘你的音乐已经表达了一切，你的存在本身就是一种力量。’",
#         "options": [
#             { "text": "缺席", "isCorrect": true },
#             { "text": "不存在", "isCorrect": false },
#             { "text": "不在场", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absent",
#         "dialog": "在一次重要的演出前，唐突然感到一阵剧烈的头痛，他不得不退出了排练。托尼焦急地在医院外等待着，直到唐的身影出现在门口。‘你怎么了？’托尼的声音充满了担忧。唐疲惫地笑了笑，‘我只是需要一点时间，让自己从这种absent的状态中恢复过来。’",
#         "options": [
#             { "text": "缺席的", "isCorrect": true },
#             { "text": "不在的", "isCorrect": false },
#             { "text": "缺席的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absolute",
#         "dialog": "在一次激烈的争吵后，唐感到异常疲惫，他看着托尼，眼中充满了疲惫和无奈。‘我需要你的absolute支持，托尼，我感到自己快要被这压力压垮了。’托尼紧紧地抱住他，‘我会一直在这里，我的朋友，我会给你最坚强的支持。’",
#         "options": [
#             { "text": "绝对的", "isCorrect": true },
#             { "text": "完全的", "isCorrect": true },
#             { "text": "纯粹的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absolutely",
#         "dialog": "当他们在一家餐厅再次遭遇歧视时，托尼的怒火几乎要爆发。但唐却紧紧地拉住了他的手臂，‘absolutely不能这么做，托尼，我们要保持冷静，用理智去面对这一切。’托尼深吸了一口气，他的眼神中充满了决心。",
#         "options": [
#             { "text": "绝对地", "isCorrect": true },
#             { "text": "完全地", "isCorrect": true },
#             { "text": "完全不能", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absorb",
#         "dialog": "在一个宁静的夜晚，唐坐在钢琴前，手指轻轻敲击着琴键，音乐在空气中回荡。托尼静静地坐在一旁，他的眼神被音乐所吸引，‘你的音乐总是能让人absorb所有的烦恼，它们就像是一剂心灵的良药。’唐微笑着，眼中闪烁着感激。",
#         "options": [
#             { "text": "吸收", "isCorrect": true },
#             { "text": "吸引", "isCorrect": false },
#             { "text": "溶解", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abstract",
#         "dialog": "在参观一座艺术馆时，唐被一幅抽象画作深深吸引，他站在画前，沉思良久。‘托尼，你看这幅画，它虽然abstract，但却能让人感受到一种深层的情感，一种无法用言语表达的美丽。’托尼望着画作，心中涌起一股共鸣。",
#         "options": [
#             { "text": "抽象的", "isCorrect": true },
#             { "text": "不具体的", "isCorrect": false },
#             { "text": "无形的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abundant",
#         "dialog": "随着巡演的进行，唐和托尼之间的友谊越来越深厚。在一个夜晚，唐看着窗外的星空，感慨地说：‘托尼，这次旅程让我感受到了生活中abundant的美好，你的陪伴让我感到无比幸福。’托尼紧紧地握住他的手，眼中充满了温暖。",
#         "options": [
#             { "text": "丰富的", "isCorrect": true },
#             { "text": "充裕的", "isCorrect": true },
#             { "text": "过剩的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abuse",
#         "dialog": "在一个小镇上，他们目睹了一场对黑人的abuse，唐的心情变得沉重，他紧握双拳，眼中充满了愤怒。‘这种事情必须改变，托尼，我们不能坐视不管。’托尼坚定地站在他身边，‘是的，我们会尽我们所能去改变它，为了正义，为了平等。’",
#         "options": [
#             { "text": "滥用", "isCorrect": true },
#             { "text": "虐待", "isCorrect": true },
#             { "text": "侮辱", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "academic",
#         "dialog": "在一所大学里，唐受邀进行了一场academic讲座，他站在讲台上，目光坚定地扫过台下的学生们。‘音乐不仅仅是艺术，它也是一门深奥的学问，它能够启迪智慧，激发情感。’托尼在一旁静静地听着，心中对唐的敬意油然而生。",
#         "options": [
#             { "text": "学术的", "isCorrect": true },
#             { "text": "学校的", "isCorrect": false },
#             { "text": "学者的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "academy",
#         "dialog": "巡演结束后，唐决定成立一个音乐academy，他站在破旧的钢琴前，眼中闪烁着希望的光芒。‘托尼，我想建立一个音乐academy，让更多的孩子有机会学习音乐，用音乐改变他们的生活。’托尼紧紧地握住他的手，‘这是一个伟大的计划，我会全力支持你。’",
#         "options": [
#             { "text": "学院", "isCorrect": true },
#             { "text": "学术", "isCorrect": false },
#             { "text": "学术团体", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accelerate",
#         "dialog": "在回程的路上，唐看着窗外的风景，心中充满了对未来的憧憬。‘托尼，这次旅程让我们都成长了很多，我希望我们的努力能accelerate社会的进步，让世界变得更加美好。’托尼看着他，眼中充满了信心和期待。",
#         "options": [
#             { "text": "加速", "isCorrect": true },
#             { "text": "促进", "isCorrect": true },
#             { "text": "加快", "isCorrect": true }
#         ]
#     }
# ]
# ```
# [
#     {
#         "word": "aboard",
#         "dialog": "1962年的一个清晨，朝阳透过车窗洒在托尼那刚毅的脸上，他启动了那辆闪亮的轿车，车窗缓缓降下，唐·雪利紧紧地握住了行李箱的把手。‘准备好了吗，托尼？’唐的声音带着一丝紧张和期待。托尼回头给了他一个坚定的笑容，‘是的，我的朋友，让我们aboard，向着未知的旅程出发吧。’",
#         "options": [
#             { "text": "入口", "isCorrect": false },
#             { "text": "上车", "isCorrect": true },
#             { "text": "登机", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "about",
#         "dialog": "车子缓缓驶出纽约的喧嚣，唐望着窗外不断后退的城市，他的眼神中充满了对未来的憧憬。‘托尼，你知道的，这次巡演对于我们来说意义重大。’唐的声音低沉而有力。托尼点了点头，‘我明白，关于这个计划，你打算怎么跟我解释？’唐的眼神中闪过一丝坚定，‘我要让这个世界听到我们的声音，about平等和尊重。’",
#         "options": [
#             { "text": "关于", "isCorrect": true },
#             { "text": "附近", "isCorrect": false },
#             { "text": "关于...而", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "above",
#         "dialog": "夜幕降临，他们在一家小旅馆前停下。唐站在窗前，仰望着满天繁星，他的眼神中充满了对生活的热爱和对梦想的追求。‘托尼，你看，这些星星，它们似乎在告诉我们，无论遇到什么困难，我们都要above一切，坚持自己的信念。’托尼默默地站在他身边，心中涌起一股暖流。",
#         "options": [
#             { "text": "以上", "isCorrect": true },
#             { "text": "之上", "isCorrect": true },
#             { "text": "在...之上", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abroad",
#         "dialog": "在一座小镇的演出结束后，他们在一家小餐馆用餐。唐望着窗外的夜色，缓缓开口：‘托尼，我曾在欧洲abroad演出，那里的观众对音乐有着深深的热爱，他们让我看到了音乐的力量。’托尼的眼神中闪烁着好奇，‘那和我们这里有什么不同呢？’唐沉思片刻，‘那里的音乐是一种更加纯粹的表达，一种超越语言和文化的交流。’",
#         "options": [
#             { "text": "在国外", "isCorrect": true },
#             { "text": "在国外旅行", "isCorrect": false },
#             { "text": "海外", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absence",
#         "dialog": "在一个寂静的夜晚，唐躺在床上，却怎么也睡不着。他坐起身，走到窗边，望着外面漆黑的夜空，轻声对托尼说：‘有时候，我觉得自己的absence比存在更让人难以忍受，我害怕我无法表达出我内心所有的情感。’托尼坐在床边，轻轻握住他的手，‘你的音乐已经表达了一切，你的存在本身就是一种力量。’",
#         "options": [
#             { "text": "缺席", "isCorrect": true },
#             { "text": "不存在", "isCorrect": false },
#             { "text": "不在场", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absent",
#         "dialog": "在一次重要的演出前，唐突然感到一阵剧烈的头痛，他不得不退出了排练。托尼焦急地在医院外等待着，直到唐的身影出现在门口。‘你怎么了？’托尼的声音充满了担忧。唐疲惫地笑了笑，‘我只是需要一点时间，让自己从这种absent的状态中恢复过来。’",
#         "options": [
#             { "text": "缺席的", "isCorrect": true },
#             { "text": "不在的", "isCorrect": false },
#             { "text": "缺席的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absolute",
#         "dialog": "在一次激烈的争吵后，唐感到异常疲惫，他看着托尼，眼中充满了疲惫和无奈。‘我需要你的absolute支持，托尼，我感到自己快要被这压力压垮了。’托尼紧紧地抱住他，‘我会一直在这里，我的朋友，我会给你最坚强的支持。’",
#         "options": [
#             { "text": "绝对的", "isCorrect": true },
#             { "text": "完全的", "isCorrect": true },
#             { "text": "纯粹的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absolutely",
#         "dialog": "当他们在一家餐厅再次遭遇歧视时，托尼的怒火几乎要爆发。但唐却紧紧地拉住了他的手臂，‘absolutely不能这么做，托尼，我们要保持冷静，用理智去面对这一切。’托尼深吸了一口气，他的眼神中充满了决心。",
#         "options": [
#             { "text": "绝对地", "isCorrect": true },
#             { "text": "完全地", "isCorrect": true },
#             { "text": "完全不能", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absorb",
#         "dialog": "在一个宁静的夜晚，唐坐在钢琴前，手指轻轻敲击着琴键，音乐在空气中回荡。托尼静静地坐在一旁，他的眼神被音乐所吸引，‘你的音乐总是能让人absorb所有的烦恼，它们就像是一剂心灵的良药。’唐微笑着，眼中闪烁着感激。",
#         "options": [
#             { "text": "吸收", "isCorrect": true },
#             { "text": "吸引", "isCorrect": false },
#             { "text": "溶解", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abstract",
#         "dialog": "在参观一座艺术馆时，唐被一幅抽象画作深深吸引，他站在画前，沉思良久。‘托尼，你看这幅画，它虽然abstract，但却能让人感受到一种深层的情感，一种无法用言语表达的美丽。’托尼望着画作，心中涌起一股共鸣。",
#         "options": [
#             { "text": "抽象的", "isCorrect": true },
#             { "text": "不具体的", "isCorrect": false },
#             { "text": "无形的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abundant",
#         "dialog": "随着巡演的进行，唐和托尼之间的友谊越来越深厚。在一个夜晚，唐看着窗外的星空，感慨地说：‘托尼，这次旅程让我感受到了生活中abundant的美好，你的陪伴让我感到无比幸福。’托尼紧紧地握住他的手，眼中充满了温暖。",
#         "options": [
#             { "text": "丰富的", "isCorrect": true },
#             { "text": "充裕的", "isCorrect": true },
#             { "text": "过剩的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abuse",
#         "dialog": "在一个小镇上，他们目睹了一场对黑人的abuse，唐的心情变得沉重，他紧握双拳，眼中充满了愤怒。‘这种事情必须改变，托尼，我们不能坐视不管。’托尼坚定地站在他身边，‘是的，我们会尽我们所能去改变它，为了正义，为了平等。’",
#         "options": [
#             { "text": "滥用", "isCorrect": true },
#             { "text": "虐待", "isCorrect": true },
#             { "text": "侮辱", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "academic",
#         "dialog": "在一所大学里，唐受邀进行了一场academic讲座，他站在讲台上，目光坚定地扫过台下的学生们。‘音乐不仅仅是艺术，它也是一门深奥的学问，它能够启迪智慧，激发情感。’托尼在一旁静静地听着，心中对唐的敬意油然而生。",
#         "options": [
#             { "text": "学术的", "isCorrect": true },
#             { "text": "学校的", "isCorrect": false },
#             { "text": "学者的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "academy",
#         "dialog": "巡演结束后，唐决定成立一个音乐academy，他站在破旧的钢琴前，眼中闪烁着希望的光芒。‘托尼，我想建立一个音乐academy，让更多的孩子有机会学习音乐，用音乐改变他们的生活。’托尼紧紧地握住他的手，‘这是一个伟大的计划，我会全力支持你。’",
#         "options": [
#             { "text": "学院", "isCorrect": true },
#             { "text": "学术", "isCorrect": false },
#             { "text": "学术团体", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accelerate",
#         "dialog": "在回程的路上，唐看着窗外的风景，心中充满了对未来的憧憬。‘托尼，这次旅程让我们都成长了很多，我希望我们的努力能accelerate社会的进步，让世界变得更加美好。’托尼看着他，眼中充满了信心和期待。",
#         "options": [
#             { "text": "加速", "isCorrect": true },
#             { "text": "促进", "isCorrect": true },
#             { "text": "加快", "isCorrect": true }
#         ]
#     }
# ]

# %%
print('开始选项随机操作')
import random

# 为每个条目的options列表随机打乱顺序
for item in clear_json_data:
    random.shuffle(item["options"])

# 打印结果以验证
# for item in clear_json_data:
#     print(f"Word: {item['word']}")
#     for option in item['options']:
#         print(f"Translation: {option['text']}, Correct: {option['isCorrect']}")
#     print("-" * 50)

random_json_data = clear_json_data
# Out:
# 开始选项随机操作

# %%
print('完成选项随机操作')
# print(random_json_data)
print('开始添加下个场景字段')
# 为每个条目的options列表添加nextScene
i = 1
for item in random_json_data:
    for option in item['options']:
        if option['isCorrect']:
            option['nextScene'] = i
            i += 1
        else:
            option['nextScene'] = -1

# 打印结果以验证
for item in random_json_data:
    print(f"Word: {item['word']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
next_scene_json_data = random_json_data
# Out:
# 完成选项随机操作
# 开始添加下个场景字段
# Word: aboard
# Translation: 入口, Correct: False, NextScene: -1
# Translation: 登机, Correct: False, NextScene: -1
# Translation: 上车, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: about
# Translation: 附近, Correct: False, NextScene: -1
# Translation: 关于, Correct: True, NextScene: 2
# Translation: 关于...而, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: above
# Translation: 以上, Correct: True, NextScene: 3
# Translation: 之上, Correct: True, NextScene: 4
# Translation: 在...之上, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: abroad
# Translation: 在国外旅行, Correct: False, NextScene: -1
# Translation: 在国外, Correct: True, NextScene: 5
# Translation: 海外, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absence
# Translation: 缺席, Correct: True, NextScene: 6
# Translation: 不存在, Correct: False, NextScene: -1
# Translation: 不在场, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absent
# Translation: 缺席的, Correct: False, NextScene: -1
# Translation: 不在的, Correct: False, NextScene: -1
# Translation: 缺席的, Correct: True, NextScene: 7
# --------------------------------------------------
# Word: absolute
# Translation: 绝对的, Correct: True, NextScene: 8
# Translation: 完全的, Correct: True, NextScene: 9
# Translation: 纯粹的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absolutely
# Translation: 绝对地, Correct: True, NextScene: 10
# Translation: 完全地, Correct: True, NextScene: 11
# Translation: 完全不能, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absorb
# Translation: 溶解, Correct: False, NextScene: -1
# Translation: 吸引, Correct: False, NextScene: -1
# Translation: 吸收, Correct: True, NextScene: 12
# --------------------------------------------------
# Word: abstract
# Translation: 不具体的, Correct: False, NextScene: -1
# Translation: 无形的, Correct: False, NextScene: -1
# Translation: 抽象的, Correct: True, NextScene: 13
# --------------------------------------------------
# Word: abundant
# Translation: 充裕的, Correct: True, NextScene: 14
# Translation: 过剩的, Correct: False, NextScene: -1
# Translation: 丰富的, Correct: True, NextScene: 15
# --------------------------------------------------
# Word: abuse
# Translation: 侮辱, Correct: False, NextScene: -1
# Translation: 滥用, Correct: True, NextScene: 16
# Translation: 虐待, Correct: True, NextScene: 17
# --------------------------------------------------
# Word: academic
# Translation: 学者的, Correct: False, NextScene: -1
# Translation: 学术的, Correct: True, NextScene: 18
# Translation: 学校的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: academy
# Translation: 学术, Correct: False, NextScene: -1
# Translation: 学术团体, Correct: False, NextScene: -1
# Translation: 学院, Correct: True, NextScene: 19
# --------------------------------------------------
# Word: accelerate
# Translation: 促进, Correct: True, NextScene: 20
# Translation: 加快, Correct: True, NextScene: 21
# Translation: 加速, Correct: True, NextScene: 22
# --------------------------------------------------

# %%
print('在json中添加npcName字段')

# 为每个条目添加npcName字段
for item in next_scene_json_data:
    item['npcName'] = moviesName  # 添加npcName字段

# 打印结果以验证
for item in next_scene_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
npc_name_json_data = next_scene_json_data
print('在json中添加npcName字段完成')
# Out:
# 在json中添加npcName字段
# Word: aboard, NPC Name: 绿皮书
# Translation: 入口, Correct: False, NextScene: -1
# Translation: 登机, Correct: False, NextScene: -1
# Translation: 上车, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: about, NPC Name: 绿皮书
# Translation: 附近, Correct: False, NextScene: -1
# Translation: 关于, Correct: True, NextScene: 2
# Translation: 关于...而, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: above, NPC Name: 绿皮书
# Translation: 以上, Correct: True, NextScene: 3
# Translation: 之上, Correct: True, NextScene: 4
# Translation: 在...之上, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: abroad, NPC Name: 绿皮书
# Translation: 在国外旅行, Correct: False, NextScene: -1
# Translation: 在国外, Correct: True, NextScene: 5
# Translation: 海外, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absence, NPC Name: 绿皮书
# Translation: 缺席, Correct: True, NextScene: 6
# Translation: 不存在, Correct: False, NextScene: -1
# Translation: 不在场, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absent, NPC Name: 绿皮书
# Translation: 缺席的, Correct: False, NextScene: -1
# Translation: 不在的, Correct: False, NextScene: -1
# Translation: 缺席的, Correct: True, NextScene: 7
# --------------------------------------------------
# Word: absolute, NPC Name: 绿皮书
# Translation: 绝对的, Correct: True, NextScene: 8
# Translation: 完全的, Correct: True, NextScene: 9
# Translation: 纯粹的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absolutely, NPC Name: 绿皮书
# Translation: 绝对地, Correct: True, NextScene: 10
# Translation: 完全地, Correct: True, NextScene: 11
# Translation: 完全不能, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absorb, NPC Name: 绿皮书
# Translation: 溶解, Correct: False, NextScene: -1
# Translation: 吸引, Correct: False, NextScene: -1
# Translation: 吸收, Correct: True, NextScene: 12
# --------------------------------------------------
# Word: abstract, NPC Name: 绿皮书
# Translation: 不具体的, Correct: False, NextScene: -1
# Translation: 无形的, Correct: False, NextScene: -1
# Translation: 抽象的, Correct: True, NextScene: 13
# --------------------------------------------------
# Word: abundant, NPC Name: 绿皮书
# Translation: 充裕的, Correct: True, NextScene: 14
# Translation: 过剩的, Correct: False, NextScene: -1
# Translation: 丰富的, Correct: True, NextScene: 15
# --------------------------------------------------
# Word: abuse, NPC Name: 绿皮书
# Translation: 侮辱, Correct: False, NextScene: -1
# Translation: 滥用, Correct: True, NextScene: 16
# Translation: 虐待, Correct: True, NextScene: 17
# --------------------------------------------------
# Word: academic, NPC Name: 绿皮书
# Translation: 学者的, Correct: False, NextScene: -1
# Translation: 学术的, Correct: True, NextScene: 18
# Translation: 学校的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: academy, NPC Name: 绿皮书
# Translation: 学术, Correct: False, NextScene: -1
# Translation: 学术团体, Correct: False, NextScene: -1
# Translation: 学院, Correct: True, NextScene: 19
# --------------------------------------------------
# Word: accelerate, NPC Name: 绿皮书
# Translation: 促进, Correct: True, NextScene: 20
# Translation: 加快, Correct: True, NextScene: 21
# Translation: 加速, Correct: True, NextScene: 22
# --------------------------------------------------
# 在json中添加npcName字段完成

# %%
print('在json中添加npcAvatar字段')
# 为每个条目添加npcAvatar字段
for item in npc_name_json_data:
    item['npcAvatar'] = next((item["npcAvatar"] for item in assistant_preset if item["npcName"] == moviesName), None)  # 添加npcAvatar字段

# 打印结果以验证
for item in npc_name_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
npc_avatar_json_data = npc_name_json_data
print('在json中添加npcName和npcAvatar字段完成')
# Out:
# 在json中添加npcAvatar字段
# Word: aboard, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 入口, Correct: False, NextScene: -1
# Translation: 登机, Correct: False, NextScene: -1
# Translation: 上车, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: about, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 附近, Correct: False, NextScene: -1
# Translation: 关于, Correct: True, NextScene: 2
# Translation: 关于...而, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: above, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 以上, Correct: True, NextScene: 3
# Translation: 之上, Correct: True, NextScene: 4
# Translation: 在...之上, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: abroad, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 在国外旅行, Correct: False, NextScene: -1
# Translation: 在国外, Correct: True, NextScene: 5
# Translation: 海外, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absence, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 缺席, Correct: True, NextScene: 6
# Translation: 不存在, Correct: False, NextScene: -1
# Translation: 不在场, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absent, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 缺席的, Correct: False, NextScene: -1
# Translation: 不在的, Correct: False, NextScene: -1
# Translation: 缺席的, Correct: True, NextScene: 7
# --------------------------------------------------
# Word: absolute, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 绝对的, Correct: True, NextScene: 8
# Translation: 完全的, Correct: True, NextScene: 9
# Translation: 纯粹的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absolutely, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 绝对地, Correct: True, NextScene: 10
# Translation: 完全地, Correct: True, NextScene: 11
# Translation: 完全不能, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absorb, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 溶解, Correct: False, NextScene: -1
# Translation: 吸引, Correct: False, NextScene: -1
# Translation: 吸收, Correct: True, NextScene: 12
# --------------------------------------------------
# Word: abstract, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 不具体的, Correct: False, NextScene: -1
# Translation: 无形的, Correct: False, NextScene: -1
# Translation: 抽象的, Correct: True, NextScene: 13
# --------------------------------------------------
# Word: abundant, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 充裕的, Correct: True, NextScene: 14
# Translation: 过剩的, Correct: False, NextScene: -1
# Translation: 丰富的, Correct: True, NextScene: 15
# --------------------------------------------------
# Word: abuse, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 侮辱, Correct: False, NextScene: -1
# Translation: 滥用, Correct: True, NextScene: 16
# Translation: 虐待, Correct: True, NextScene: 17
# --------------------------------------------------
# Word: academic, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 学者的, Correct: False, NextScene: -1
# Translation: 学术的, Correct: True, NextScene: 18
# Translation: 学校的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: academy, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 学术, Correct: False, NextScene: -1
# Translation: 学术团体, Correct: False, NextScene: -1
# Translation: 学院, Correct: True, NextScene: 19
# --------------------------------------------------
# Word: accelerate, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 促进, Correct: True, NextScene: 20
# Translation: 加快, Correct: True, NextScene: 21
# Translation: 加速, Correct: True, NextScene: 22
# --------------------------------------------------
# 在json中添加npcName和npcAvatar字段完成

# %%
print('在json中添加backgroundVideo字段')
# 为每个条目添加backgroundVideo字段
for item in npc_avatar_json_data:
    item['backgroundVideo'] = next((item["backgroundVideo"] for item in assistant_preset if item["npcName"] == moviesName), None)  # 添加backgroundVideo字段

# 打印结果以验证
for item in npc_avatar_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}, Background Video: {item['backgroundVideo']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
background_video_json_data = npc_avatar_json_data
print('在json中添加npcName、npcAvatar和backgroundVideo字段完成')

print(background_video_json_data)

background_video_json_data.append({
    "word": "none",
    "dialog": "恭喜你完成了游戏的所有关卡，点击重玩游戏，重新开始游戏",
    "options": [
        { "text": "重玩游戏", "isCorrect": "true", "nextScene": 0 },
    ],
    "npcName": moviesName,
    "npcAvatar": next((item["npcAvatar"] for item in assistant_preset if item["npcName"] == moviesName), None),
    "backgroundVideo": next((item["backgroundVideo"] for item in assistant_preset if item["npcName"] == moviesName), None),
})

# 将options中的True和False改为小写字符串
for item in background_video_json_data:
    for option in item['options']:
        option['isCorrect'] = 'true' if option['isCorrect'] else 'false'

# 打印结果以验证
for item in background_video_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}, Background Video: {item['backgroundVideo']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
print('添加下个场景字段完成')
# Out:
# 在json中添加backgroundVideo字段
# Word: aboard, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 入口, Correct: False, NextScene: -1
# Translation: 登机, Correct: False, NextScene: -1
# Translation: 上车, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: about, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 附近, Correct: False, NextScene: -1
# Translation: 关于, Correct: True, NextScene: 2
# Translation: 关于...而, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: above, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 以上, Correct: True, NextScene: 3
# Translation: 之上, Correct: True, NextScene: 4
# Translation: 在...之上, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: abroad, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 在国外旅行, Correct: False, NextScene: -1
# Translation: 在国外, Correct: True, NextScene: 5
# Translation: 海外, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absence, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 缺席, Correct: True, NextScene: 6
# Translation: 不存在, Correct: False, NextScene: -1
# Translation: 不在场, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absent, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 缺席的, Correct: False, NextScene: -1
# Translation: 不在的, Correct: False, NextScene: -1
# Translation: 缺席的, Correct: True, NextScene: 7
# --------------------------------------------------
# Word: absolute, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 绝对的, Correct: True, NextScene: 8
# Translation: 完全的, Correct: True, NextScene: 9
# Translation: 纯粹的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absolutely, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 绝对地, Correct: True, NextScene: 10
# Translation: 完全地, Correct: True, NextScene: 11
# Translation: 完全不能, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: absorb, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 溶解, Correct: False, NextScene: -1
# Translation: 吸引, Correct: False, NextScene: -1
# Translation: 吸收, Correct: True, NextScene: 12
# --------------------------------------------------
# Word: abstract, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 不具体的, Correct: False, NextScene: -1
# Translation: 无形的, Correct: False, NextScene: -1
# Translation: 抽象的, Correct: True, NextScene: 13
# --------------------------------------------------
# Word: abundant, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 充裕的, Correct: True, NextScene: 14
# Translation: 过剩的, Correct: False, NextScene: -1
# Translation: 丰富的, Correct: True, NextScene: 15
# --------------------------------------------------
# Word: abuse, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 侮辱, Correct: False, NextScene: -1
# Translation: 滥用, Correct: True, NextScene: 16
# Translation: 虐待, Correct: True, NextScene: 17
# --------------------------------------------------
# Word: academic, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 学者的, Correct: False, NextScene: -1
# Translation: 学术的, Correct: True, NextScene: 18
# Translation: 学校的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: academy, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 学术, Correct: False, NextScene: -1
# Translation: 学术团体, Correct: False, NextScene: -1
# Translation: 学院, Correct: True, NextScene: 19
# --------------------------------------------------
# Word: accelerate, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 促进, Correct: True, NextScene: 20
# Translation: 加快, Correct: True, NextScene: 21
# Translation: 加速, Correct: True, NextScene: 22
# --------------------------------------------------
# 在json中添加npcName、npcAvatar和backgroundVideo字段完成
# [{'word': 'aboard', 'dialog': '1962年的一个清晨，朝阳透过车窗洒在托尼那刚毅的脸上，他启动了那辆闪亮的轿车，车窗缓缓降下，唐·雪利紧紧地握住了行李箱的把手。‘准备好了吗，托尼？’唐的声音带着一丝紧张和期待。托尼回头给了他一个坚定的笑容，‘是的，我的朋友，让我们aboard，向着未知的旅程出发吧。’', 'options': [{'text': '入口', 'isCorrect': False, 'nextScene': -1}, {'text': '登机', 'isCorrect': False, 'nextScene': -1}, {'text': '上车', 'isCorrect': True, 'nextScene': 1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'about', 'dialog': '车子缓缓驶出纽约的喧嚣，唐望着窗外不断后退的城市，他的眼神中充满了对未来的憧憬。‘托尼，你知道的，这次巡演对于我们来说意义重大。’唐的声音低沉而有力。托尼点了点头，‘我明白，关于这个计划，你打算怎么跟我解释？’唐的眼神中闪过一丝坚定，‘我要让这个世界听到我们的声音，about平等和尊重。’', 'options': [{'text': '附近', 'isCorrect': False, 'nextScene': -1}, {'text': '关于', 'isCorrect': True, 'nextScene': 2}, {'text': '关于...而', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'above', 'dialog': '夜幕降临，他们在一家小旅馆前停下。唐站在窗前，仰望着满天繁星，他的眼神中充满了对生活的热爱和对梦想的追求。‘托尼，你看，这些星星，它们似乎在告诉我们，无论遇到什么困难，我们都要above一切，坚持自己的信念。’托尼默默地站在他身边，心中涌起一股暖流。', 'options': [{'text': '以上', 'isCorrect': True, 'nextScene': 3}, {'text': '之上', 'isCorrect': True, 'nextScene': 4}, {'text': '在...之上', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'abroad', 'dialog': '在一座小镇的演出结束后，他们在一家小餐馆用餐。唐望着窗外的夜色，缓缓开口：‘托尼，我曾在欧洲abroad演出，那里的观众对音乐有着深深的热爱，他们让我看到了音乐的力量。’托尼的眼神中闪烁着好奇，‘那和我们这里有什么不同呢？’唐沉思片刻，‘那里的音乐是一种更加纯粹的表达，一种超越语言和文化的交流。’', 'options': [{'text': '在国外旅行', 'isCorrect': False, 'nextScene': -1}, {'text': '在国外', 'isCorrect': True, 'nextScene': 5}, {'text': '海外', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'absence', 'dialog': '在一个寂静的夜晚，唐躺在床上，却怎么也睡不着。他坐起身，走到窗边，望着外面漆黑的夜空，轻声对托尼说：‘有时候，我觉得自己的absence比存在更让人难以忍受，我害怕我无法表达出我内心所有的情感。’托尼坐在床边，轻轻握住他的手，‘你的音乐已经表达了一切，你的存在本身就是一种力量。’', 'options': [{'text': '缺席', 'isCorrect': True, 'nextScene': 6}, {'text': '不存在', 'isCorrect': False, 'nextScene': -1}, {'text': '不在场', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'absent', 'dialog': '在一次重要的演出前，唐突然感到一阵剧烈的头痛，他不得不退出了排练。托尼焦急地在医院外等待着，直到唐的身影出现在门口。‘你怎么了？’托尼的声音充满了担忧。唐疲惫地笑了笑，‘我只是需要一点时间，让自己从这种absent的状态中恢复过来。’', 'options': [{'text': '缺席的', 'isCorrect': False, 'nextScene': -1}, {'text': '不在的', 'isCorrect': False, 'nextScene': -1}, {'text': '缺席的', 'isCorrect': True, 'nextScene': 7}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'absolute', 'dialog': '在一次激烈的争吵后，唐感到异常疲惫，他看着托尼，眼中充满了疲惫和无奈。‘我需要你的absolute支持，托尼，我感到自己快要被这压力压垮了。’托尼紧紧地抱住他，‘我会一直在这里，我的朋友，我会给你最坚强的支持。’', 'options': [{'text': '绝对的', 'isCorrect': True, 'nextScene': 8}, {'text': '完全的', 'isCorrect': True, 'nextScene': 9}, {'text': '纯粹的', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'absolutely', 'dialog': '当他们在一家餐厅再次遭遇歧视时，托尼的怒火几乎要爆发。但唐却紧紧地拉住了他的手臂，‘absolutely不能这么做，托尼，我们要保持冷静，用理智去面对这一切。’托尼深吸了一口气，他的眼神中充满了决心。', 'options': [{'text': '绝对地', 'isCorrect': True, 'nextScene': 10}, {'text': '完全地', 'isCorrect': True, 'nextScene': 11}, {'text': '完全不能', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'absorb', 'dialog': '在一个宁静的夜晚，唐坐在钢琴前，手指轻轻敲击着琴键，音乐在空气中回荡。托尼静静地坐在一旁，他的眼神被音乐所吸引，‘你的音乐总是能让人absorb所有的烦恼，它们就像是一剂心灵的良药。’唐微笑着，眼中闪烁着感激。', 'options': [{'text' ...
# Word: aboard, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 入口, Correct: false, NextScene: -1
# Translation: 登机, Correct: false, NextScene: -1
# Translation: 上车, Correct: true, NextScene: 1
# --------------------------------------------------
# Word: about, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 附近, Correct: false, NextScene: -1
# Translation: 关于, Correct: true, NextScene: 2
# Translation: 关于...而, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: above, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 以上, Correct: true, NextScene: 3
# Translation: 之上, Correct: true, NextScene: 4
# Translation: 在...之上, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: abroad, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 在国外旅行, Correct: false, NextScene: -1
# Translation: 在国外, Correct: true, NextScene: 5
# Translation: 海外, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: absence, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 缺席, Correct: true, NextScene: 6
# Translation: 不存在, Correct: false, NextScene: -1
# Translation: 不在场, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: absent, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 缺席的, Correct: false, NextScene: -1
# Translation: 不在的, Correct: false, NextScene: -1
# Translation: 缺席的, Correct: true, NextScene: 7
# --------------------------------------------------
# Word: absolute, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 绝对的, Correct: true, NextScene: 8
# Translation: 完全的, Correct: true, NextScene: 9
# Translation: 纯粹的, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: absolutely, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 绝对地, Correct: true, NextScene: 10
# Translation: 完全地, Correct: true, NextScene: 11
# Translation: 完全不能, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: absorb, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 溶解, Correct: false, NextScene: -1
# Translation: 吸引, Correct: false, NextScene: -1
# Translation: 吸收, Correct: true, NextScene: 12
# --------------------------------------------------
# Word: abstract, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 不具体的, Correct: false, NextScene: -1
# Translation: 无形的, Correct: false, NextScene: -1
# Translation: 抽象的, Correct: true, NextScene: 13
# --------------------------------------------------
# Word: abundant, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 充裕的, Correct: true, NextScene: 14
# Translation: 过剩的, Correct: false, NextScene: -1
# Translation: 丰富的, Correct: true, NextScene: 15
# --------------------------------------------------
# Word: abuse, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 侮辱, Correct: false, NextScene: -1
# Translation: 滥用, Correct: true, NextScene: 16
# Translation: 虐待, Correct: true, NextScene: 17
# --------------------------------------------------
# Word: academic, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 学者的, Correct: false, NextScene: -1
# Translation: 学术的, Correct: true, NextScene: 18
# Translation: 学校的, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: academy, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 学术, Correct: false, NextScene: -1
# Translation: 学术团体, Correct: false, NextScene: -1
# Translation: 学院, Correct: true, NextScene: 19
# --------------------------------------------------
# Word: accelerate, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 促进, Correct: true, NextScene: 20
# Translation: 加快, Correct: true, NextScene: 21
# Translation: 加速, Correct: true, NextScene: 22
# --------------------------------------------------
# Word: none, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 重玩游戏, Correct: true, NextScene: 0
# --------------------------------------------------
# 添加下个场景字段完成

# %%
print('杀青收工')
