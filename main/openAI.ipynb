# %% [markdown]
# # OPEN API

# %% [markdown]
# ## 0 前置条件：预设

# %%
role_message = [
    {"name": "月光仙子", "avatar": "LunaFairy.png"},
    {"name": "森林守护者", "avatar": "ForestGuardian.png"},
    {"name": "智慧老人", "avatar": "WiseOldMan.png"},
    {"name": "星辰旅者", "avatar": "StarTraveler.png"},
    {"name": "玫瑰公主", "avatar": "RosePrincess.png"},
    {"name": "风语者", "avatar": "WhisperingWind.png"},
    {"name": "梦境行者", "avatar": "DreamWalker.png"},
    {"name": "魔法猫咪", "avatar": "MagicKitten.png"},
    {"name": "时间守护者", "avatar": "TimeKeeper.png"},
    {"name": "水晶精灵", "avatar": "CrystalSprite.png"},
    {"name": "火焰骑士", "avatar": "FlameKnight.png"},
    {"name": "寒冰巫师", "avatar": "IceWizard.png"},
    {"name": "云游诗人", "avatar": "WanderingPoet.png"},
    {"name": "翠绿女巫", "avatar": "EmeraldWitch.png"},
    {"name": "金羽毛勇士", "avatar": "GoldenFeatherWarrior.png"}
  ]

field_message = [
    {"field": "岛屿", "video": "island.mp4"},
    {"field": "森林", "video": "forest.mp4"},
    {"field": "山脉", "video": "mountain.mp4"},
    {"field": "沙漠", "video": "desert.mp4"},
    {"field": "城市", "video": "city.mp4"},
    {"field": "湖泊", "video": "lake.mp4"},
    {"field": "极地", "video": "polar.mp4"},
    {"field": "海底", "video": "ocean_floor.mp4"},
    {"field": "草原", "video": "grassland.mp4"},
    {"field": "夜空", "video": "night_sky.mp4"},
    {"field": "火山", "video": "volcano.mp4"},
    {"field": "瀑布", "video": "waterfall.mp4"},
    {"field": "古堡", "video": "castle.mp4"},
    {"field": "峡谷", "video": "canyon.mp4"},
    {"field": "花田", "video": "flower_field.mp4"}
  ]

# %%
import requests
import json

url = "https://api.openai-hk.com/v1/chat/completions"

headers = {
    "Content-Type": "application/json",
    "Authorization": "hk-k8uxev10000468101dda6e2b13df9fb77af5c78f05867bdf"
}

data = {
    "max_tokens": 1200,
    "model": "gpt-3.5-turbo",
    "temperature": 0.8,
    "top_p": 1,
    "presence_penalty": 1,
    "messages": [
        {
            "role": "system",
            "content": "You are ChatGPT, a large language model trained by OpenAI."
        },
        {
            "role": "user",
            "content": """
 const role_message = [

    {"name": "月光仙子", "avatar": "LunaFairy.png"},

    {"name": "森林守护者", "avatar": "ForestGuardian.png"},

    {"name": "智慧老人", "avatar": "WiseOldMan.png"},

    {"name": "星辰旅者", "avatar": "StarTraveler.png"},

    {"name": "玫瑰公主", "avatar": "RosePrincess.png"},

    {"name": "风语者", "avatar": "WhisperingWind.png"},

    {"name": "梦境行者", "avatar": "DreamWalker.png"},

    {"name": "魔法猫咪", "avatar": "MagicKitten.png"},

    {"name": "时间守护者", "avatar": "TimeKeeper.png"},

    {"name": "水晶精灵", "avatar": "CrystalSprite.png"},

    {"name": "火焰骑士", "avatar": "FlameKnight.png"},

    {"name": "寒冰巫师", "avatar": "IceWizard.png"},

    {"name": "云游诗人", "avatar": "WanderingPoet.png"},

    {"name": "翠绿女巫", "avatar": "EmeraldWitch.png"},

    {"name": "金羽毛勇士", "avatar": "GoldenFeatherWarrior.png"}

  ]

  const field_message = [

    {"field": "岛屿", "video": "island.mp4"},

    {"field": "森林", "video": "forest.mp4"},

    {"field": "山脉", "video": "mountain.mp4"},

    {"field": "沙漠", "video": "desert.mp4"},

    {"field": "城市", "video": "city.mp4"},

    {"field": "湖泊", "video": "lake.mp4"},

    {"field": "极地", "video": "polar.mp4"},

    {"field": "海底", "video": "ocean_floor.mp4"},

    {"field": "草原", "video": "grassland.mp4"},

    {"field": "夜空", "video": "night_sky.mp4"},

    {"field": "火山", "video": "volcano.mp4"},

    {"field": "瀑布", "video": "waterfall.mp4"},

    {"field": "古堡", "video": "castle.mp4"},

    {"field": "峡谷", "video": "canyon.mp4"},

    {"field": "花田", "video": "flower_field.mp4"}

  ]

基于以上角色，写一个小说，先给我背景基于以上角色，选一个合适的角色和场景来写小说，先给我背景,300字左右

格式如下：

{'storyBackground':'在 希尔达大陆 的最北方，有一个神秘的领域——夜空。这个地方充满了无尽的星光和奇异的星云，每当夜幕降临，天空便会化作一片瑰丽的光海。传说中，这片夜空是通往其他世界的桥梁，也是时间之石碎片最有可能隐藏的地方之一。然而，这里也是最不可预测和危险的领域，因为时间的法则在这里完全失效，星辰轨迹变得混乱，空间中充斥着时间的裂隙。



星辰旅者 是唯一能在这片混沌的夜空中穿梭的守护者。他是一个神秘的存在，来自遥远的星际，操控着星光的力量，并能借助星辰之力穿越时空。为了寻找时间之石的碎片，星辰旅者接受了召唤，前往夜空深处展开冒险。'}
"""
        }
    ]
}

response = requests.post(url, headers=headers, data=json.dumps(data).encode('utf-8') )
result = response.content.decode("utf-8")

print(result)
# Out:
# {"error":{"message":"Insufficient points, please recharge 积分不足，请充值","type":"openai_hk_error"}}

# %%
response = json.loads(result)
print(response["choices"][0]["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 response = json.loads(result)
# ----> 2 print(response["choices"][0]["message"]["content"])
#
# KeyError: 'choices'

# %%
scenes_all = [] # 存放结果
role_message = [
    {"name": "月光仙子", "avatar": "/videos/LunaFairy.png"},
    {"name": "森林守护者", "avatar": "ForestGuardian.png"},
    {"name": "智慧老人", "avatar": "WiseOldMan.png"},
    {"name": "星辰旅者", "avatar": "StarTraveler.png"},
    {"name": "玫瑰公主", "avatar": "RosePrincess.png"},
    {"name": "风语者", "avatar": "WhisperingWind.png"},
    {"name": "梦境行者", "avatar": "DreamWalker.png"},
    {"name": "魔法猫咪", "avatar": "MagicKitten.png"},
    {"name": "时间守护者", "avatar": "TimeKeeper.png"},
    {"name": "水晶精灵", "avatar": "CrystalSprite.png"},
    {"name": "火焰骑士", "avatar": "FlameKnight.png"},
    {"name": "寒冰巫师", "avatar": "IceWizard.png"},
    {"name": "云游诗人", "avatar": "WanderingPoet.png"},
    {"name": "翠绿女巫", "avatar": "EmeraldWitch.png"},
    {"name": "金羽毛勇士", "avatar": "GoldenFeatherWarrior.png"}
  ]

field_message = [
    {"field": "岛屿", "video": "island.mp4"},
    {"field": "森林", "video": "forest.mp4"},
    {"field": "山脉", "video": "mountain.mp4"},
    {"field": "沙漠", "video": "desert.mp4"},
    {"field": "城市", "video": "city.mp4"},
    {"field": "湖泊", "video": "lake.mp4"},
    {"field": "极地", "video": "polar.mp4"},
    {"field": "海底", "video": "ocean_floor.mp4"},
    {"field": "草原", "video": "grassland.mp4"},
    {"field": "夜空", "video": "night_sky.mp4"},
    {"field": "火山", "video": "volcano.mp4"},
    {"field": "瀑布", "video": "waterfall.mp4"},
    {"field": "古堡", "video": "castle.mp4"},
    {"field": "峡谷", "video": "canyon.mp4"},
    {"field": "花田", "video": "flower_field.mp4"}
  ]

def get_avatar_by_name(name):
    role_message = [
    {"name": "月光仙子", "avatar": "/avatars/LunaFairy.png"},
    {"name": "森林守护者", "avatar": "/avatars/ForestGuardian.png"},
    {"name": "智慧老人", "avatar": "/avatars/WiseOldMan.png"},
    {"name": "星辰旅者", "avatar": "/avatars/StarTraveler.png"},
    {"name": "玫瑰公主", "avatar": "/avatars/RosePrincess.png"},
    {"name": "风语者", "avatar": "/avatars/WhisperingWind.png"},
    {"name": "梦境行者", "avatar": "/avatars/DreamWalker.png"},
    {"name": "魔法猫咪", "avatar": "/avatars/MagicKitten.png"},
    {"name": "时间守护者", "avatar": "/avatars/TimeKeeper.png"},
    {"name": "水晶精灵", "avatar": "/avatars/CrystalSprite.png"},
    {"name": "火焰骑士", "avatar": "/avatars/FlameKnight.png"},
    {"name": "寒冰巫师", "avatar": "/avatars/IceWizard.png"},
    {"name": "云游诗人", "avatar": "/avatars/WanderingPoet.png"},
    {"name": "翠绿女巫", "avatar": "/avatars/EmeraldWitch.png"},
    {"name": "金羽毛勇士", "avatar": "/avatars/GoldenFeatherWarrior.png"}
  ]
    try:
        return next(item["avatar"] for item in role_message if item["name"] == name)
    except StopIteration:
        return None  # 如果没找到对应的name，返回None

# 使用示例
avatar = get_avatar_by_name("梦境行者")

# %%
print(response)
# Out:
# {'error': {'message': 'Insufficient points, please recharge 积分不足，请充值', 'type': 'openai_hk_error'}}

# %%
word = ['ambitious','angry','funny','romantic']

for i in range(len(word)):
  # 保存上一次的回复
  previous_response = response["choices"][0]["message"]["content"]

  # 更新data中的messages，添加上一轮对话
  data["messages"].extend([
        {
            "role": "assistant",
        "content": previous_response
    },
    {
        "role": "user",
        "content" : f"""
      基于上述背景续写100字左右的对话，对话是中文，并且必须在对话要自然地嵌入{word[i]}单词，与背景故事衔接得当，禁止在对话中提示中文意思，并且说明一下使用什么场景，场景原则上与对话所在场景一致，选项包含1个正确翻译和两个错误翻译，正确翻译要符合角色设定和背景氛围，角色的话可以从之前的role_messages中选，场景可以从field_messages中选。narrator是进入这个对话前出现的旁白，会告诉你现在的环境以或提示你该做什么。选择正确选项就会跳转到下个场景，我每次提问你续写json都要在上个nextScene的基础加1。示例如下：
      {{
      "narrator":"你叫艾尔达，为了探索森林的秘密，你来到了一个古老且神秘的森林",
      "npcName":"森林守护者",
      "dialog":"你看起来真是个ambitious的冒险者啊，总想着探索这片古老的森林。但要小心，贪欲可是很危险的。",
      "scene":"峡谷",
      "options":[
              {{"text":"有野心的","isCorrect":true,"nextScene":1}},
              {{"text":"复杂的","isCorrect":false}},
              {{"text":"有充分的","isCorrect":false}}
      ]
      }}
      注意：只返回json
      """
    }
  ])
  response = requests.post(url, headers=headers, data=json.dumps(data).encode('utf-8'))
  result = response.content.decode("utf-8")
  response = json.loads(result)
  current_data = json.loads(response["choices"][0]["message"]["content"])
  scenes_all.append({
    "narrator":str(current_data['narrator']),
    "npcName": str(current_data['npcName']),
    "npcDialog": str(current_data['dialog']),
    "npcAvatar": str(get_avatar_by_name(current_data['npcName'])),
    "backgroundVideo": "/videos/2077.mp4",
    "vocabulary": {
      "word": word[i],
      "options": current_data['options']
    }
  })
  print(current_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 5
#       1 word = ['ambitious','angry','funny','romantic']
#       3 for i in range(len(word)):
#       4   # 保存上一次的回复
# ----> 5   previous_response = response["choices"][0]["message"]["content"]
#       7   # 更新data中的messages，添加上一轮对话
#       8   data["messages"].extend([
#       9         {
#      10             "role": "assistant",
#    (...)
#      30     }
#      31   ])
#
# KeyError: 'choices'

# %%
print(scenes_all)
# Out:
# [{'narrator': '你叫艾尔达，为了探索森林的秘密，你来到了一个古老且神秘的森林', 'npcName': '水晶精灵', 'npcDialog': "梦境行者看着你，眼中透露出一种 ['ambitious', 'angry', 'funny', 'romantic'] 的光芒。她微笑着说：“在这片水晶森林里，每一个梦都是一段浪漫的旅程，每一颗水晶都跃动着爱的力量。”", 'npcAvatar': '/avatars/CrystalSprite.png', 'backgroundVideo': '/videos/2077.mp4', 'vocabulary': {'word': 'mysterious', 'options': [{'text': '浪漫的', 'isCorrect': True, 'nextScene': 1}, {'text': '独特的', 'isCorrect': False}, {'text': '美丽的', 'isCorrect': False}]}}, {'narrator': '你叫艾尔达，为了探索森林的秘密，你来到了一个古老且神秘的森林', 'npcName': '水晶精灵', 'npcDialog': "梦境行者看着你，眼中透露出一种 ['ambitious', 'angry', 'funny', 'romantic'] 的光芒。她微笑着说：“在这片水晶森林里，每一个梦都是一段浪漫的旅程，每一颗水晶都跃动着爱的力量。”", 'npcAvatar': '/avatars/CrystalSprite.png', 'backgroundVideo': '/videos/2077.mp4', 'vocabulary': {'word': 'romantic', 'options': [{'text': '浪漫的', 'isCorrect': True, 'nextScene': 1}, {'text': '独特的', 'isCorrect': False}, {'text': '美丽的', 'isCorrect': False}]}}, {'narrator': '你来到了神秘的水晶精灵森林，迷失其中。梦境行者出现在你面前。', 'npcName': '梦境行者', 'npcDialog': '她微笑着说：“在这片水晶森林中，每一个梦都是一段浪漫的旅程。”', 'npcAvatar': '/avatars/DreamWalker.png', 'backgroundVideo': '/videos/2077.mp4', 'vocabulary': {'word': 'romantic', 'options': [{'text': '浪漫的', 'isCorrect': True, 'nextScene': 1}, {'text': '神秘的', 'isCorrect': False}, {'text': '美丽的', 'isCorrect': False}]}}, {'narrator': '你来到了神秘的水晶精灵森林，迷失其中。梦境行者出现在你面前。', 'npcName': '梦境行者', 'npcDialog': "她微笑着说：“在这片水晶森林中，每一个梦都是一段 ['ambitious', 'angry', 'funny', 'romantic'] 的旅程。”", 'npcAvatar': '/avatars/DreamWalker.png', 'backgroundVideo': '/videos/2077.mp4', 'vocabulary': {'word': 'ambitious', 'options': [{'text': '野心勃勃的', 'isCorrect': True, 'nextScene': 1}, {'text': '复杂的', 'isCorrect': False}, {'text': '富有充分的', 'isCorrect': False}]}}, {'narrator': '你来到了神秘的水晶精灵森林，迷失其中。梦境行者出现在你面前。', 'npcName': '梦境行者', 'npcDialog': "她微笑着说：“在这片水晶森林中，每一个梦都是一段 ['ambitious', 'angry', 'funny', 'romantic'] 的旅程。”", 'npcAvatar': '/avatars/DreamWalker.png', 'backgroundVideo': '/videos/2077.mp4', 'vocabulary': {'word': 'angry', 'options': [{'text': '雄心勃勃的', 'isCorrect': True, 'nextScene': 1}, {'text': '错综复杂的', 'isCorrect': False}, {'text': '充足的', 'isCorrect': False}]}}, {'narrator': '你来到了神秘的水晶精灵森林，迷失其中。梦境行者出现在你面前。', 'npcName': '梦境行者', 'npcDialog': "她微笑着说：“在这片水晶森林中，每一个梦都是一段 ['ambitious', 'angry', 'funny', 'romantic'] 的旅程。”", 'npcAvatar': '/avatars/DreamWalker.png', 'backgroundVideo': '/videos/2077.mp4', 'vocabulary': {'word': 'funny', 'options': [{'text': '幽默的', 'isCorrect': True, 'nextScene': 1}, {'text': '错综复杂的', 'isCorrect': False}, {'text': '充足的', 'isCorrect': False}]}}, {'narrator': '你来到了神秘的水晶精灵森林，迷失其中。梦境行者出现在你面前。', 'npcName': '梦境行者', 'npcDialog': "她微笑着说：“在这片水晶森林中，每一个梦都是一段 ['ambitious', 'angry', 'funny', 'romantic'] 的旅程。”", 'npcAvatar': '/avatars/DreamWalker.png', 'backgroundVideo': '/videos/2077.mp4', 'vocabulary': {'word': 'romantic', 'options': [{'text': '浪漫的', 'isCorrect': True, 'nextScene': 1}, {'text': '独特的', 'isCorrect': False}, {'text': '美丽的', 'isCorrect': False}]}}]

# %%
import openai

openai.api_key = "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"
proxies={
'http': 'http://127.0.0.1:2022',
'https': 'http://127.0.0.1:2022'  # https -> http
}
openai.proxy = proxies

completion = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Hello!"}
  ]
)

print(completion.choices[0].message)

# %%
import openai
import requests

proxies = {
  'http': 'http://149.104.52.150:3033',
  'https': 'https://149.104.52.150:3033'
}

response = requests.get('https://api.openai.com/v1/models', proxies=proxies, headers={
  'Authorization': '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'
})
print(response.json())

# %%
import requests

proxies = {
    "http": "http://149.104.52.150:3033",
    "https": "http://149.104.52.150:3033",
}

response = requests.get("https://api.openai.com", proxies=proxies, headers={
  'Authorization': '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'
})
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connectionpool.py:775, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     774 try:
# --> 775     self._prepare_proxy(conn)
#     776 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connectionpool.py:1044, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1038 conn.set_tunnel(
#    1039     scheme=tunnel_scheme,
#    1040     host=self._tunnel_host,
#    1041     port=self.port,
#    1042     headers=self.proxy_headers,
#    1043 )
# -> 1044 conn.connect()
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connection.py:710, in HTTPSConnection.connect(self)
#     708 self._has_connected_to_proxy = True
# --> 710 self._tunnel()
#     711 # Override the host with the one we're requesting data from.
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connection.py:258, in HTTPConnection._tunnel(self)
#     257 try:
# --> 258     (version, code, message) = response._read_status()  # type: ignore[attr-defined]
#     260     if code != http.HTTPStatus.OK:
#
# File d:\2024秋招-大四上\conda_env\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#
# File d:\2024秋招-大四上\conda_env\lib\socket.py:716, in SocketIO.readinto(self, b)
#     715 try:
# --> 716     return self._sock.recv_into(b)
#     717 except timeout:
#
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connectionpool.py:775, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     774 try:
# --> 775     self._prepare_proxy(conn)
#     776 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connectionpool.py:1044, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1038 conn.set_tunnel(
#    1039     scheme=tunnel_scheme,
#    1040     host=self._tunnel_host,
#    1041     port=self.port,
#    1042     headers=self.proxy_headers,
#    1043 )
# -> 1044 conn.connect()
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connection.py:710, in HTTPSConnection.connect(self)
#     708 self._has_connected_to_proxy = True
# --> 710 self._tunnel()
#     711 # Override the host with the one we're requesting data from.
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connection.py:258, in HTTPConnection._tunnel(self)
#     257 try:
# --> 258     (version, code, message) = response._read_status()  # type: ignore[attr-defined]
#     260     if code != http.HTTPStatus.OK:
#
# File d:\2024秋招-大四上\conda_env\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#
# File d:\2024秋招-大四上\conda_env\lib\socket.py:716, in SocketIO.readinto(self, b)
#     715 try:
# --> 716     return self._sock.recv_into(b)
#     717 except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 8
#       1 import requests
#       3 proxies = {
#       4     "http": "http://149.104.52.150:3033",
#       5     "https": "http://149.104.52.150:3033",
#       6 }
# ----> 8 response = requests.get("https://api.openai.com", proxies=proxies, headers={
#       9   'Authorization': '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'
#      10 })
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))

# %%
import requests
import json

url = "https://api.openai.com/v1/chat/completions"

proxies = {
    "http": "http://127.0.0.1:9006",
    "https": "http://127.0.0.1:9006",
}

headers = {
    "Content-Type": "application/json",
    "Authorization": "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"
}

data = {
    "max_tokens": 1200,
    "model": "gpt-3.5-turbo",
    "temperature": 0.8,
    "top_p": 1,
    "presence_penalty": 1,
    "messages": [
        {
            "role": "system",
            "content": "You are ChatGPT, a large language model trained by OpenAI."
        },
        {
            "role": "user",
            "content": "n你好"
        }
    ]
}

response = requests.post(url, headers=headers, proxies=proxies, data=json.dumps(data).encode('utf-8') )
result = response.content.decode("utf-8")

print(result)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connectionpool.py:775, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     774 try:
# --> 775     self._prepare_proxy(conn)
#     776 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connectionpool.py:1044, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1038 conn.set_tunnel(
#    1039     scheme=tunnel_scheme,
#    1040     host=self._tunnel_host,
#    1041     port=self.port,
#    1042     headers=self.proxy_headers,
#    1043 )
# -> 1044 conn.connect()
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connection.py:693, in HTTPSConnection.connect(self)
#     692 sock: socket.socket | ssl.SSLSocket
# --> 693 self.sock = sock = self._new_conn()
#     694 server_hostname: str = self.host
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connection.py:214, in HTTPConnection._new_conn(self)
#     213 except OSError as e:
# --> 214     raise NewConnectionError(
#     215         self, f"Failed to establish a new connection: {e}"
#     216     ) from e
#     218 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x00000227D4C2BA00>: Failed to establish a new connection: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# The above exception was the direct cause of the following exception:
#
# ProxyError                                Traceback (most recent call last)
# ProxyError: ('Unable to connect to proxy', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000227D4C2BA00>: Failed to establish a new connection: [WinError 10061] 由于目标计算机积极拒绝，无法连接。'))
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.openai.com', port=443): Max retries exceeded with url: /v1/chat/completions (Caused by ProxyError('Unable to connect to proxy', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000227D4C2BA00>: Failed to establish a new connection: [WinError 10061] 由于目标计算机积极拒绝，无法连接。')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# Cell In[7], line 34
#      11 headers = {
#      12     "Content-Type": "application/json",
#      13     "Authorization": "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"
#      14 }
#      16 data = {
#      17     "max_tokens": 1200,
#      18     "model": "gpt-3.5-turbo",
#    (...)
#      31     ]
#      32 }
# ---> 34 response = requests.post(url, headers=headers, proxies=proxies, data=json.dumps(data).encode('utf-8') )
#      35 result = response.content.decode("utf-8")
#      37 print(result)
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\2024秋招-大四上\conda_env\lib\site-packages\requests\adapters.py:694, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     691     raise RetryError(e, request=request)
#     693 if isinstance(e.reason, _ProxyError):
# --> 694     raise ProxyError(e, request=request)
#     696 if isinstance(e.reason, _SSLError):
#     697     # This branch is for urllib3 v1.22 and later.
#     698     raise SSLError(e, request=request)
#
# ProxyError: HTTPSConnectionPool(host='api.openai.com', port=443): Max retries exceeded with url: /v1/chat/completions (Caused by ProxyError('Unable to connect to proxy', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000227D4C2BA00>: Failed to establish a new connection: [WinError 10061] 由于目标计算机积极拒绝，无法连接。')))
