# %%
moviesName = '绿皮书'
words_array = ['access','accessory','accident','accidental','accompany','accomplish','accord','accordance','afraid','punish']

# %%
from api.getWordsArr import get_words_arr
from api.generate_scene import generate_scene
words_array = get_words_arr('d:/2024秋招-大四上/毕业论文/DocuAssist_flask/static/doc/word.docx')
print('单词数组', words_array[0])
# Out:
# {
#   "array1": [
#     "abandon",
#     "ability",
#     "able",
#     "abnormal",
#     "aboard",
#     "about",
#     "above",
#     "abroad",
#     "absence",
#     "absent",
#     "absolute",
#     "absolutely",
#     "absorb",
#     "abstract",
#     "abundant"
#   ],
#   "array2": [
#     "abuse",
#     "academic",
#     "academy",
#     "accelerate",
#     "acceleration",
#     "accent",
#     "accept",
#     "acceptable",
#     "acceptance",
#     "access",
#     "accessory",
#     "accident",
#     "accidental",
#     "accompany",
#     "accomplish"
#   ],
#   "array3": [
#     "accord",
#     "accordance",
#     "accordingly",
#     "account",
#     "accumulate",
#     "accuracy",
#     "accurate",
#     "accuse",
#     "affection",
#     "afford",
#     "afraid",
#     "Africa",
#     "African",
#     "after",
#     "afternoon"
#   ],
#   "array4": [
#     "afterward",
#     "again",
#     "against",
#     "age",
#     "agency",
#     "agent",
#     "aggressive",
#     "ago",
#     "agony",
#     "agree",
#     "agreement",
#     "ahead",
#     "aid",
#     "aim",
#     "air",
#     "aircraft"
#   ]
# }
# [['abandon', 'ability', 'able', 'abnormal', 'aboard', 'about', 'above', 'abroad', 'absence', 'absent', 'absolute', 'absolutely', 'absorb', 'abstract', 'abundant'], ['abuse', 'academic', 'academy', 'accelerate', 'acceleration', 'accent', 'accept', 'acceptable', 'acceptance', 'access', 'accessory', 'accident', 'accidental', 'accompany', 'accomplish'], ['accord', 'accordance', 'accordingly', 'account', 'accumulate', 'accuracy', 'accurate', 'accuse', 'affection', 'afford', 'afraid', 'Africa', 'African', 'after', 'afternoon'], ['afterward', 'again', 'against', 'age', 'agency', 'agent', 'aggressive', 'ago', 'agony', 'agree', 'agreement', 'ahead', 'aid', 'aim', 'air', 'aircraft']]
# 单词数组 ['abandon', 'ability', 'able', 'abnormal', 'aboard', 'about', 'above', 'abroad', 'absence', 'absent', 'absolute', 'absolutely', 'absorb', 'abstract', 'abundant']

# %%
generate_scene('绿皮书',  ['aboard', 'about', 'above', 'abroad', 'absence', 'absent', 'absolute', 'absolutely', 'absorb', 'abstract', 'abundant', 'abuse', 'academic', 'academy', 'accelerate'])
# Out:
# 开始生成带单词句子
# 带单词句子生成完成
# 开始生成更长的句子
# 更长句子生成完成
# 开始给每个内容加选项
# 给每个内容加选项完成
# 开始清除json多余字段
# JSON 解析错误位置: 行 4, 列 56
# 错误信息: Expecting ',' delimiter
# 问题字符附近的内容:
# 第 4 行:         "dialog": "在《泰坦尼克号》中，杰克和罗丝站在船头，他们的眼中闪烁着对未来的憧憬。"Aboard this majestic ship," 杰克激动地说，他的声音中充满了对未知世界的渴望。罗丝紧紧抓住他的手，她的心跳随着这艘巨轮的缓缓起航而加速。",
#                                                        ^
# JSON 解析错误: Expecting ',' delimiter: line 4 column 56 (char 89)
# 原始数据: ```json
# [
#     {
#         "word": "aboard",
#         "dialog": "在《泰坦尼克号》中，杰克和罗丝站在船头，他们的眼中闪烁着对未来的憧憬。'Aboard this majestic ship,' 杰克激动地说，他的声音中充满了对未知世界的渴望。罗丝紧紧抓住他的手，她的心跳随着这艘巨轮的缓缓起航而加速。",
#         "options": [
#             { "text": "船上", "isCorrect": true },
#             { "text": "船后", "isCorrect": false },
#             { "text": "船边", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "about",
#         "dialog": "在《哈利·波特》系列中，哈利从邓布利多那里听到关于霍格沃茨的传说，他的眼睛里闪烁着好奇和兴奋。'About this mystical place,' 邓布利多神秘地说，'it holds the key to your destiny.' 哈利的心中燃起了一团火焰，他知道自己的冒险即将开始。",
#         "options": [
#             { "text": "关于", "isCorrect": true },
#             { "text": "在...附近", "isCorrect": false },
#             { "text": "在...之上", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "above",
#         "dialog": "在《指环王》中，咕嚕姆坐在咕嚕姆洞的入口，他的眼神空洞，仿佛在above的黑暗中寻找着什么。'Above, in the mountains,' 他低声自语，'there lies the One Ring, the Ring of Power.' 他的话语中透露出一种对力量的渴望和对命运的无奈。",
#         "options": [
#             { "text": "上方", "isCorrect": true },
#             { "text": "上面", "isCorrect": false },
#             { "text": "上面的一部分", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abroad",
#         "dialog": "在《加勒比海盗》系列中，杰克·斯派洛船长站在甲板上，眺望着远方的海平线。'Abroad, on the seven seas,' 他自言自语，'is where I belong.' 他的眼神中充满了对自由的渴望和对冒险的向往。",
#         "options": [
#             { "text": "国外", "isCorrect": true },
#             { "text": "海外", "isCorrect": false },
#             { "text": "海外的一部分", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absence",
#         "dialog": "在《小妇人》中，梅格在剧院后台焦急地等待着艾米莉的归来。'Her absence is like a void,' 她心中想道，'without her, the joy of the performance feels incomplete.' 她的脸上写满了担忧，但同时也充满了对妹妹的深深爱意。",
#         "options": [
#             { "text": "缺席", "isCorrect": true },
#             { "text": "缺席的人", "isCorrect": false },
#             { "text": "缺席的状态", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absent",
#         "dialog": "在《哈利·波特》中，哈利在霍格沃茨的教室里，看着那些absent的同学，心中充满了同情。'They must be missing home,' 他想道，'but they will find their place among us soon.' 他的话语中透露出一种包容和温暖，希望能够安慰那些孤独的心灵。",
#         "options": [
#             { "text": "缺席的", "isCorrect": true },
#             { "text": "不在场的", "isCorrect": false },
#             { "text": "缺席的场合", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absolute",
#         "dialog": "在《阿甘正传》中，阿甘的母亲坐在摇椅上，温柔地看着他。'Absolute truth, my child,' 她轻声说，'is not always easy to see.' 她的话中充满了智慧，阿甘虽然无法完全理解，但他知道母亲的信念是坚定的，就像她的话语一样绝对。",
#         "options": [
#             { "text": "绝对的", "isCorrect": true },
#             { "text": "完全的", "isCorrect": false },
#             { "text": "绝对的信念", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absolutely",
#         "dialog": "在《肖申克的救赎》中，瑞德看着安迪，他的眼中充满了信任和敬佩。'Absolutely, Andy,' 他说，'you will get out of here one day.' 他的话语中透露出对安迪的坚定信念，即使面对重重困难，他也相信安迪能够逃脱。",
#         "options": [
#             { "text": "绝对地", "isCorrect": true },
#             { "text": "完全地", "isCorrect": false },
#             { "text": "绝对地相信", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "absorb",
#         "dialog": "在《哈利·波特》中，哈利在霍格沃茨的图书馆里，翻阅着一本又一本的魔法书籍。'Absorb this knowledge,' 他心中想道，'and it will become a part of me.' 他的眼神中充满了对知识的渴望，他的大脑仿佛是一块海绵，贪婪地吸收着每一本书中的智慧。",
#         "options": [
#             { "text": "吸收", "isCorrect": true },
#             { "text": "吸取", "isCorrect": false },
#             { "text": "吸收知识", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abstract",
#         "dialog": "在《黑客帝国》中，尼奥在尼欧蒂姆的办公室里，听到了关于矩阵的真相。'Abstract concepts,' 尼欧蒂姆解释说，'are difficult to grasp, but once you understand them, they change everything.' 尼奥的眼神中充满了困惑，但同时也充满了对真理的追求。",
#         "options": [
#             { "text": "抽象的", "isCorrect": true },
#             { "text": "概括的", "isCorrect": false },
#             { "text": "抽象概念", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abundant",
#         "dialog": "在《哈利·波特》中，霍格沃茨的商店里摆满了各种魔法用品，学生们兴奋地挑选着。'Abundant choices,' 老佛莱迪笑着说，'for all your magical needs.' 学生的笑声和欢呼声充满了整个商店，他们的眼中闪烁着对魔法世界的无限向往。",
#         "options": [
#             { "text": "丰富的", "isCorrect": true },
#             { "text": "充足的", "isCorrect": false },
#             { "text": "丰富的资源", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "abuse",
#         "dialog": "在《楚门的世界》中，楚门开始怀疑自己的现实。'This is not a game,' 他愤怒地对导演说，'this is abuse.' 他的声音中充满了愤怒和绝望，他意识到自己可能一直被困在一个巨大的谎言之中。",
#         "options": [
#             { "text": "滥用", "isCorrect": true },
#             { "text": "虐待", "isCorrect": false },
#             { "text": "滥用权力", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "academic",
#         "dialog": "在《美国往事》中，乔·塔斯克站在讲台上，他的眼神坚定，充满自信。'Academic success,' 他说，'is not just about grades, but about character.' 他的话语激励着学生们，让他们明白成功不仅仅是学术上的成就，更是品格的体现。",
#         "options": [
#             { "text": "学术的", "isCorrect": true },
#             { "text": "学校的", "isCorrect": false },
#             { "text": "学术上的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "academy",
#         "dialog": "在《少年派的奇幻漂流》中，派和他的老虎理查德·帕克在荒岛上建立了自己的academy。'This is our academy,' 派宣布，'where we learn to survive.' 他们的生活充满了挑战，但在这片孤岛上，他们共同成长，建立了深厚的友谊。",
#         "options": [
#             { "text": "学院", "isCorrect": true },
#             { "text": "学校", "isCorrect": false },
#             { "text": "学术机构", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accelerate",
#         "dialog": "在《速度与激情》系列中，卢克·霍布斯驾驶着他的超高速车辆，在赛道上飞速驰骋。'Accelerate,' 他对队友说，'and we'll leave no one behind.' 他的话语中充满了决心和勇气，他愿意为了正义和友谊不惜一切代价。",
#         "options": [
#             { "text": "加速", "isCorrect": true },
#             { "text": "加快", "isCorrect": false },
#             { "text": "加速过程", "isCorrect": false }
#         ]
#     }
# ]
# ```
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 generate_scene('绿皮书',  ['aboard', 'about', 'above', 'abroad', 'absence', 'absent', 'absolute', 'absolutely', 'absorb', 'abstract', 'abundant', 'abuse', 'academic', 'academy', 'accelerate'])
#
# File d:\2024秋招-大四上\毕业论文\DocuAssist_flask\main\api\generate_scene.py:114, in generate_scene(moviesName, words_array)
#     111 cleaned_text = cleaned_text.replace("False", "false")
#     113 try:
# --> 114     clear_json_data = json.loads(cleaned_text)
#     115 except json.JSONDecodeError as e:
#     116     print(f"JSON 解析错误位置: 行 {e.lineno}, 列 {e.colno}")
#
# File d:\2024秋招-大四上\conda_env\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File d:\2024秋招-大四上\conda_env\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File d:\2024秋招-大四上\conda_env\lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 4 column 56 (char 89)

# %%
from zhipuai import ZhipuAI
import json
# 填写您自己的APIKey
client = ZhipuAI(api_key="b18f84a0d131140efa1e5f8b3641bd78.9MuoykZ6Ypnf9Nrh")

assistant_preset = [
    {
        "npcName": "绿皮书",
        "content": """你是月光仙子，你现在需要带领用户遨游在绿皮书世界，接受用户单词的同时高效地教会用户单词。
        可以拿具体某一部电影来说，而不是一直切换电影，并以json形式储存,示例:
        [{"word":"access","dialog":"在《千与千寻》中，千寻意外地进入了一个神秘的世界，她需要找到通往这个世界的access以返回现实。"},
        {"word":"accessory","dialog":"电影中的无脸男可以被视为千寻冒险中的一个accessory，因为他在某些情况下帮助了她。"}]；
        注意：对话主要为中文，夹杂唯一的一个英文单词，不要有中文提示，不理解可以看我示例里面的dialog""",
        "npcAvatar": "http://cdn.docuparser.top/avatar/lvpishu.jpeg",
        "backgroundVideo": "http://cdn.docuparser.top/video/lvpishu.mp4"
    },
    {
        "npcName": "千与千寻",
        "content": """你是月光仙子，你现在需要带领用户遨游在宫崎骏笔下的千与千寻的世界，接受用户单词的同时高效地教会用户单词。
        可以拿具体某一部电影来说，而不是一直切换电影，并以json形式储存,示例:
        [{"word":"access","dialog":"在《千与千寻》中，千寻意外地进入了一个神秘的世界，她需要找到通往这个世界的access以返回现实。"},
        {"word":"accessory","dialog":"电影中的无脸男可以被视为千寻冒险中的一个accessory，因为他在某些情况下帮助了她。"}]；
        注意：对话主要为中文，夹杂唯一的一个英文单词，不要有中文提示，不理解可以看我示例里面的dialog""",
        "npcAvatar": "http://cdn.docuparser.top/avatar/gongqijun.jpg",
        "backgroundVideo": "http://cdn.docuparser.top/video/qianyuqianxun.mp4"
    }
]

# 使用列表解析查找npcName为moviesName的内容
npc_content = next((item["content"] for item in assistant_preset if item["npcName"] == moviesName), None)

messages_preset = []
if npc_content:
    messages_preset.append({
        "role": "assistant",
        "content": str(npc_content)
    })

messages_preset.append({
    "role": "user",
    "content": str(words_array)
})

response = client.chat.completions.create(
    model="glm-4-flash",
    messages=messages_preset
)

# %%
print('开始生成带单词句子')
word_sentence = response.choices[0].message.content
print(word_sentence)
print('带单词句子生成完成')
# Out:
# 开始生成带单词句子
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《千与千寻》中，千寻意外地进入了一个神秘的世界，她需要找到通往这个世界的access以返回现实。"
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中的无脸男可以被视为千寻冒险中的一个accessory，因为他在某些情况下帮助了她。"
#     },
#     {
#         "word": "accident",
#         "dialog": "在《阿甘正传》中，阿甘的许多生活经历都是由于意外的accident而改变的。"
#     },
#     {
#         "word": "accidental",
#         "dialog": "电影《海上钢琴师》中，1900的钢琴演奏被描述为一种accidental的天赋，而非刻意学习。"
#     },
#     {
#         "word": "accompany",
#         "dialog": "在《哈利·波特》系列中，哈利在许多冒险中都由罗恩和赫敏accompany，共同面对困难。"
#     },
#     {
#         "word": "accomplish",
#         "dialog": "《肖申克的救赎》中，安迪通过不懈的努力和智慧，最终accomplished他的自由。"
#     },
#     {
#         "word": "accord",
#         "dialog": "在《美丽心灵》中，纳什与妻子艾莉西亚努力维持婚姻accord，尽管面临巨大的心理挑战。"
#     },
#     {
#         "word": "accordance",
#         "dialog": "《教父》中，迈克尔·柯里昂遵循家族传统，在处理事务时总是遵循严格的accordance。"
#     },
#     {
#         "word": "afraid",
#         "dialog": "在《少年派的奇幻漂流》中，少年派在漂流过程中多次表达出afraid的情绪，但他勇敢地面对了困境。"
#     },
#     {
#         "word": "punish",
#         "dialog": "《辛德勒的名单》中，辛德勒因为保护犹太人而受到纳粹的punish，但他坚信这是正确的选择。"
#     }
# ]
# ```
# 带单词句子生成完成

# %%
messages_preset.append({
    "role": "assistant",
    "content": f"{word_sentence}"
})
messages_preset.append({
    "role": "user",
    "content": "基于这个json进行将每个对话丰富一下情感和故事性"
})
response = client.chat.completions.create(
    model="glm-4-flash",
    messages=messages_preset
)

# %%
print('开始生成更长的句子')
word_long_sentence = response.choices[0].message.content
print(word_long_sentence)
print('更长句子生成完成')

messages_preset.append({
    "role": "assistant",
    "content": f"{word_long_sentence}"
})
messages_preset.append({
    "role": "user",
    "content": """
    基于这个json进行给每个小json加选项，2个混淆翻译和1个正确翻译，正确翻译要符合语境，而不是脱离语境的翻译，options格式如下：options: [
        { text: "入口", isCorrect: True },
        { text: "通道", isCorrect: False  },
        { text: "接近", isCorrect: False  },
        ],
        """
})
response = client.chat.completions.create(
    model="glm-4-flash",
    messages=messages_preset
)

print('开始给每个内容加选项')
add_options = response.choices[0].message.content
print(add_options)
print('给每个内容加选项完成')
# Out:
# 开始生成更长的句子
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《千与千寻》中，千寻意外地进入了一个神秘的世界，她惊恐地发现，自己必须找到通往这个世界的access，否则她将永远失去回家的路。她的眼中闪烁着无助和恐惧，但当她看到那扇通往现实的大门时，她的眼神中又燃起了希望的火花。"
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中的无脸男，一个看似普通的存在，却成为了千寻冒险中的一个不可或缺的accessory。他默默地在背后帮助她，用他那无形的双手支撑着千寻，让她在困境中找到了前进的力量。他的存在，就像是千寻内心深处的一盏明灯，照亮了她前行的道路。"
#     },
#     {
#         "word": "accident",
#         "dialog": "在《阿甘正传》中，阿甘的人生充满了accident。他的人生轨迹因为一次偶然的跑步而改变，他因为这次accident而成为了越战英雄，也因为另一次accident而结识了挚爱的珍妮。阿甘的故事告诉我们，生活中的accident往往在不经意间塑造了我们的命运。"
#     },
#     {
#         "word": "accidental",
#         "dialog": "《海上钢琴师》中，1900的钢琴演奏被描述为一种accidental的天赋。他在船上出生，从未接触过钢琴，却能在琴键上自由穿梭，弹奏出美妙的旋律。这种accidental的天赋让他成为了传奇，也让他在音乐的海洋中找到了属于自己的归宿。"
#     },
#     {
#         "word": "accompany",
#         "dialog": "在《哈利·波特》系列中，哈利在成长的道路上，始终有罗恩和赫敏的accompany。他们一起面对黑魔法的威胁，一起经历了无数的冒险。在彼此的陪伴下，他们学会了勇敢和信任，也收获了深厚的友谊。"
#     },
#     {
#         "word": "accomplish",
#         "dialog": "《肖申克的救赎》中，安迪通过不懈的努力和智慧，最终accomplished他的自由。他在监狱中建立了图书馆，帮助了无数囚犯，他的坚持和毅力最终感动了监狱长，使他得以重获自由。这是一个关于希望和坚持的故事，告诉我们只要有梦想，就能accomplish奇迹。"
#     },
#     {
#         "word": "accord",
#         "dialog": "在《美丽心灵》中，纳什与妻子艾莉西亚努力维持婚姻accord，尽管他们面临着纳什精神分裂症的巨大挑战。艾莉西亚始终坚守在纳什身边，她的爱和耐心成为了纳什对抗病魔的强大支柱。他们的故事告诉我们，真正的accord不仅仅是一种协议，更是一种无私的奉献和承诺。"
#     },
#     {
#         "word": "accordance",
#         "dialog": "《教父》中，迈克尔·柯里昂遵循家族传统，在处理事务时总是遵循严格的accordance。他的决策和行动都体现了家族的荣誉和利益，他的领导力和智慧使家族势力日益壮大。然而，这也让他陷入了复杂的权力斗争，最终付出了沉重的代价。"
#     },
#     {
#         "word": "afraid",
#         "dialog": "在《少年派的奇幻漂流》中，少年派在漂流过程中多次表达出afraid的情绪。他害怕孤独，害怕死亡，害怕失去希望。然而，正是这种afraid让他更加珍惜生命，更加勇敢地面对困境。在漫长的漂流中，他学会了生存，也学会了成长。"
#     },
#     {
#         "word": "punish",
#         "dialog": "《辛德勒的名单》中，辛德勒因为保护犹太人而受到纳粹的punish。他被剥夺了财产，被关进了集中营，甚至差点失去了生命。然而，他并没有放弃，他用自己的智慧和勇气，最终拯救了上千名犹太人的生命。他的故事告诉我们，即使面对punish，也要坚持正义和善良。"
#     }
# ]
# ```
# 更长句子生成完成
# 开始给每个内容加选项
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《千与千寻》中，千寻意外地进入了一个神秘的世界，她惊恐地发现，自己必须找到通往这个世界的access，否则她将永远失去回家的路。她的眼中闪烁着无助和恐惧，但当她看到那扇通往现实的大门时，她的眼神中又燃起了希望的火花。",
#         "options": [
#             { "text": "入口", "isCorrect": true },
#             { "text": "通道", "isCorrect": false },
#             { "text": "接近", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中的无脸男，一个看似普通的存在，却成为了千寻冒险中的一个不可或缺的accessory。他默默地在背后帮助她，用他那无形的双手支撑着千寻，让她在困境中找到了前进的力量。他的存在，就像是千寻内心深处的一盏明灯，照亮了她前行的道路。",
#         "options": [
#             { "text": "伙伴", "isCorrect": true },
#             { "text": "装饰品", "isCorrect": false },
#             { "text": "配件", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accident",
#         "dialog": "在《阿甘正传》中，阿甘的人生充满了accident。他的人生轨迹因为一次偶然的跑步而改变，他因为这次accident而成为了越战英雄，也因为另一次accident而结识了挚爱的珍妮。阿甘的故事告诉我们，生活中的accident往往在不经意间塑造了我们的命运。",
#         "options": [
#             { "text": "事故", "isCorrect": true },
#             { "text": "意外", "isCorrect": true },
#             { "text": "偶然", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accidental",
#         "dialog": "《海上钢琴师》中，1900的钢琴演奏被描述为一种accidental的天赋。他在船上出生，从未接触过钢琴，却能在琴键上自由穿梭，弹奏出美妙的旋律。这种accidental的天赋让他成为了传奇，也让他在音乐的海洋中找到了属于自己的归宿。",
#         "options": [
#             { "text": "意外的", "isCorrect": true },
#             { "text": "偶然的", "isCorrect": true },
#             { "text": "偶然发现", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accompany",
#         "dialog": "在《哈利·波特》系列中，哈利在成长的道路上，始终有罗恩和赫敏的accompany。他们一起面对黑魔法的威胁，一起经历了无数的冒险。在彼此的陪伴下，他们学会了勇敢和信任，也收获了深厚的友谊。",
#         "options": [
#             { "text": "伴随", "isCorrect": true },
#             { "text": "陪同", "isCorrect": true },
#             { "text": "跟随", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accomplish",
#         "dialog": "《肖申克的救赎》中，安迪通过不懈的努力和智慧，最终accomplished他的自由。他在监狱中建立了图书馆，帮助了无数囚犯，他的坚持和毅力最终感动了监狱长，使他得以重获自由。这是一个关于希望和坚持的故事，告诉我们只要有梦想，就能accomplish奇迹。",
#         "options": [
#             { "text": "完成", "isCorrect": true },
#             { "text": "实现", "isCorrect": true },
#             { "text": "达到", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accord",
#         "dialog": "在《美丽心灵》中，纳什与妻子艾莉西亚努力维持婚姻accord，尽管他们面临着纳什精神分裂症的巨大挑战。艾莉西亚始终坚守在纳什身边，她的爱和耐心成为了纳什对抗病魔的强大支柱。他们的故事告诉我们，真正的accord不仅仅是一种协议，更是一种无私的奉献和承诺。",
#         "options": [
#             { "text": "协议", "isCorrect": true },
#             { "text": "和谐", "isCorrect": true },
#             { "text": "一致", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accordance",
#         "dialog": "《教父》中，迈克尔·柯里昂遵循家族传统，在处理事务时总是遵循严格的accordance。他的决策和行动都体现了家族的荣誉和利益，他的领导力和智慧使家族势力日益壮大。然而，这也让他陷入了复杂的权力斗争，最终付出了沉重的代价。",
#         "options": [
#             { "text": "一致性", "isCorrect": true },
#             { "text": "协议", "isCorrect": true },
#             { "text": "一致性", "isCorrect": true }
#         ]
#     },
#     {
#         "word": "afraid",
#         "dialog": "在《少年派的奇幻漂流》中，少年派在漂流过程中多次表达出afraid的情绪。他害怕孤独，害怕死亡，害怕失去希望。然而，正是这种afraid让他更加珍惜生命，更加勇敢地面对困境。",
#         "options": [
#             { "text": "害怕", "isCorrect": true },
#             { "text": "担忧", "isCorrect": true },
#             { "text": "恐惧", "isCorrect": true }
#         ]
#     },
#     {
#         "word": "punish",
#         "dialog": "《辛德勒的名单》中，辛德勒因为保护犹太人而受到纳粹的punish。他被剥夺了财产，被关进了集中营，甚至差点失去了生命。然而，他并没有放弃，他用自己的智慧和勇气，最终拯救了上千名犹太人的生命。他的故事告诉我们，即使面对punish，也要坚持正义和善良。",
#         "options": [
#             { "text": "惩罚", "isCorrect": true },
#             { "text": "处罚", "isCorrect": true },
#             { "text": "报复", "isCorrect": false }
#         ]
#     }
# ]
# ```
# 给每个内容加选项完成

# %%
print('开始清除json多余字段')
clear_json_data = json.loads(add_options.replace("```json", "").replace("```", "").strip())
print(clear_json_data)
print('完成清除json多余字段')
# Out:
# 开始清除json多余字段
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地进入了一个神秘的世界，她惊恐地发现，自己必须找到通往这个世界的access，否则她将永远失去回家的路。她的眼中闪烁着无助和恐惧，但当她看到那扇通往现实的大门时，她的眼神中又燃起了希望的火花。', 'options': [{'text': '入口', 'isCorrect': True}, {'text': '通道', 'isCorrect': False}, {'text': '接近', 'isCorrect': False}]}, {'word': 'accessory', 'dialog': '电影中的无脸男，一个看似普通的存在，却成为了千寻冒险中的一个不可或缺的accessory。他默默地在背后帮助她，用他那无形的双手支撑着千寻，让她在困境中找到了前进的力量。他的存在，就像是千寻内心深处的一盏明灯，照亮了她前行的道路。', 'options': [{'text': '伙伴', 'isCorrect': True}, {'text': '装饰品', 'isCorrect': False}, {'text': '配件', 'isCorrect': False}]}, {'word': 'accident', 'dialog': '在《阿甘正传》中，阿甘的人生充满了accident。他的人生轨迹因为一次偶然的跑步而改变，他因为这次accident而成为了越战英雄，也因为另一次accident而结识了挚爱的珍妮。阿甘的故事告诉我们，生活中的accident往往在不经意间塑造了我们的命运。', 'options': [{'text': '事故', 'isCorrect': True}, {'text': '意外', 'isCorrect': True}, {'text': '偶然', 'isCorrect': False}]}, {'word': 'accidental', 'dialog': '《海上钢琴师》中，1900的钢琴演奏被描述为一种accidental的天赋。他在船上出生，从未接触过钢琴，却能在琴键上自由穿梭，弹奏出美妙的旋律。这种accidental的天赋让他成为了传奇，也让他在音乐的海洋中找到了属于自己的归宿。', 'options': [{'text': '意外的', 'isCorrect': True}, {'text': '偶然的', 'isCorrect': True}, {'text': '偶然发现', 'isCorrect': False}]}, {'word': 'accompany', 'dialog': '在《哈利·波特》系列中，哈利在成长的道路上，始终有罗恩和赫敏的accompany。他们一起面对黑魔法的威胁，一起经历了无数的冒险。在彼此的陪伴下，他们学会了勇敢和信任，也收获了深厚的友谊。', 'options': [{'text': '伴随', 'isCorrect': True}, {'text': '陪同', 'isCorrect': True}, {'text': '跟随', 'isCorrect': False}]}, {'word': 'accomplish', 'dialog': '《肖申克的救赎》中，安迪通过不懈的努力和智慧，最终accomplished他的自由。他在监狱中建立了图书馆，帮助了无数囚犯，他的坚持和毅力最终感动了监狱长，使他得以重获自由。这是一个关于希望和坚持的故事，告诉我们只要有梦想，就能accomplish奇迹。', 'options': [{'text': '完成', 'isCorrect': True}, {'text': '实现', 'isCorrect': True}, {'text': '达到', 'isCorrect': False}]}, {'word': 'accord', 'dialog': '在《美丽心灵》中，纳什与妻子艾莉西亚努力维持婚姻accord，尽管他们面临着纳什精神分裂症的巨大挑战。艾莉西亚始终坚守在纳什身边，她的爱和耐心成为了纳什对抗病魔的强大支柱。他们的故事告诉我们，真正的accord不仅仅是一种协议，更是一种无私的奉献和承诺。', 'options': [{'text': '协议', 'isCorrect': True}, {'text': '和谐', 'isCorrect': True}, {'text': '一致', 'isCorrect': False}]}, {'word': 'accordance', 'dialog': '《教父》中，迈克尔·柯里昂遵循家族传统，在处理事务时总是遵循严格的accordance。他的决策和行动都体现了家族的荣誉和利益，他的领导力和智慧使家族势力日益壮大。然而，这也让他陷入了复杂的权力斗争，最终付出了沉重的代价。', 'options': [{'text': '一致性', 'isCorrect': True}, {'text': '协议', 'isCorrect': True}, {'text': '一致性', 'isCorrect': True}]}, {'word': 'afraid', 'dialog': '在《少年派的奇幻漂流》中，少年派在漂流过程中多次表达出afraid的情绪。他害怕孤独，害怕死亡，害怕失去希望。然而，正是这种afraid让他更加珍惜生命，更加勇敢地面对困境。', 'options': [{'text': '害怕', 'isCorrect': True}, {'text': '担忧', 'isCorrect': True}, {'text': '恐惧', 'isCorrect': True}]}, {'word': 'punish', 'dialog': '《辛德勒的名单》中，辛德勒因为保护犹太人而受到纳粹的punish。他被剥夺了财产，被关进了集中营，甚至差点失去了生命。然而，他并没有放弃，他用自己的智慧和勇气，最终拯救了上千名犹太人的生命。他的故事告诉我们，即使面对punish，也要坚持正义和善良。', 'options': [{'text': '惩罚', 'isCorrect': True}, {'text': '处罚', 'isCorrect': True}, {'text': '报复', 'isCorrect': False}]}]
# 完成清除json多余字段

# %%
print('开始选项随机操作')

import random

# 为每个条目的options列表随机打乱顺序
for item in clear_json_data:
    random.shuffle(item["options"])

# 打印结果以验证
for item in clear_json_data:
    print(f"Word: {item['word']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}")
    print("-" * 50)

random_json_data = clear_json_data
print('完成选项随机操作')


print(random_json_data)
# Out:
# 开始选项随机操作
# Word: access
# Translation: 入口, Correct: True
# Translation: 通道, Correct: False
# Translation: 接近, Correct: False
# --------------------------------------------------
# Word: accessory
# Translation: 伙伴, Correct: True
# Translation: 装饰品, Correct: False
# Translation: 配件, Correct: False
# --------------------------------------------------
# Word: accident
# Translation: 偶然, Correct: False
# Translation: 意外, Correct: True
# Translation: 事故, Correct: True
# --------------------------------------------------
# Word: accidental
# Translation: 意外的, Correct: True
# Translation: 偶然的, Correct: True
# Translation: 偶然发现, Correct: False
# --------------------------------------------------
# Word: accompany
# Translation: 陪同, Correct: True
# Translation: 跟随, Correct: False
# Translation: 伴随, Correct: True
# --------------------------------------------------
# Word: accomplish
# Translation: 实现, Correct: True
# Translation: 达到, Correct: False
# Translation: 完成, Correct: True
# --------------------------------------------------
# Word: accord
# Translation: 一致, Correct: False
# Translation: 和谐, Correct: True
# Translation: 协议, Correct: True
# --------------------------------------------------
# Word: accordance
# Translation: 一致性, Correct: True
# Translation: 协议, Correct: True
# Translation: 一致性, Correct: True
# --------------------------------------------------
# Word: afraid
# Translation: 害怕, Correct: True
# Translation: 恐惧, Correct: True
# Translation: 担忧, Correct: True
# --------------------------------------------------
# Word: punish
# Translation: 处罚, Correct: True
# Translation: 惩罚, Correct: True
# Translation: 报复, Correct: False
# --------------------------------------------------
# 完成选项随机操作
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地进入了一个神秘的世界，她惊恐地发现，自己必须找到通往这个世界的access，否则她将永远失去回家的路。她的眼中闪烁着无助和恐惧，但当她看到那扇通往现实的大门时，她的眼神中又燃起了希望的火花。', 'options': [{'text': '入口', 'isCorrect': True}, {'text': '通道', 'isCorrect': False}, {'text': '接近', 'isCorrect': False}]}, {'word': 'accessory', 'dialog': '电影中的无脸男，一个看似普通的存在，却成为了千寻冒险中的一个不可或缺的accessory。他默默地在背后帮助她，用他那无形的双手支撑着千寻，让她在困境中找到了前进的力量。他的存在，就像是千寻内心深处的一盏明灯，照亮了她前行的道路。', 'options': [{'text': '伙伴', 'isCorrect': True}, {'text': '装饰品', 'isCorrect': False}, {'text': '配件', 'isCorrect': False}]}, {'word': 'accident', 'dialog': '在《阿甘正传》中，阿甘的人生充满了accident。他的人生轨迹因为一次偶然的跑步而改变，他因为这次accident而成为了越战英雄，也因为另一次accident而结识了挚爱的珍妮。阿甘的故事告诉我们，生活中的accident往往在不经意间塑造了我们的命运。', 'options': [{'text': '偶然', 'isCorrect': False}, {'text': '意外', 'isCorrect': True}, {'text': '事故', 'isCorrect': True}]}, {'word': 'accidental', 'dialog': '《海上钢琴师》中，1900的钢琴演奏被描述为一种accidental的天赋。他在船上出生，从未接触过钢琴，却能在琴键上自由穿梭，弹奏出美妙的旋律。这种accidental的天赋让他成为了传奇，也让他在音乐的海洋中找到了属于自己的归宿。', 'options': [{'text': '意外的', 'isCorrect': True}, {'text': '偶然的', 'isCorrect': True}, {'text': '偶然发现', 'isCorrect': False}]}, {'word': 'accompany', 'dialog': '在《哈利·波特》系列中，哈利在成长的道路上，始终有罗恩和赫敏的accompany。他们一起面对黑魔法的威胁，一起经历了无数的冒险。在彼此的陪伴下，他们学会了勇敢和信任，也收获了深厚的友谊。', 'options': [{'text': '陪同', 'isCorrect': True}, {'text': '跟随', 'isCorrect': False}, {'text': '伴随', 'isCorrect': True}]}, {'word': 'accomplish', 'dialog': '《肖申克的救赎》中，安迪通过不懈的努力和智慧，最终accomplished他的自由。他在监狱中建立了图书馆，帮助了无数囚犯，他的坚持和毅力最终感动了监狱长，使他得以重获自由。这是一个关于希望和坚持的故事，告诉我们只要有梦想，就能accomplish奇迹。', 'options': [{'text': '实现', 'isCorrect': True}, {'text': '达到', 'isCorrect': False}, {'text': '完成', 'isCorrect': True}]}, {'word': 'accord', 'dialog': '在《美丽心灵》中，纳什与妻子艾莉西亚努力维持婚姻accord，尽管他们面临着纳什精神分裂症的巨大挑战。艾莉西亚始终坚守在纳什身边，她的爱和耐心成为了纳什对抗病魔的强大支柱。他们的故事告诉我们，真正的accord不仅仅是一种协议，更是一种无私的奉献和承诺。', 'options': [{'text': '一致', 'isCorrect': False}, {'text': '和谐', 'isCorrect': True}, {'text': '协议', 'isCorrect': True}]}, {'word': 'accordance', 'dialog': '《教父》中，迈克尔·柯里昂遵循家族传统，在处理事务时总是遵循严格的accordance。他的决策和行动都体现了家族的荣誉和利益，他的领导力和智慧使家族势力日益壮大。然而，这也让他陷入了复杂的权力斗争，最终付出了沉重的代价。', 'options': [{'text': '一致性', 'isCorrect': True}, {'text': '协议', 'isCorrect': True}, {'text': '一致性', 'isCorrect': True}]}, {'word': 'afraid', 'dialog': '在《少年派的奇幻漂流》中，少年派在漂流过程中多次表达出afraid的情绪。他害怕孤独，害怕死亡，害怕失去希望。然而，正是这种afraid让他更加珍惜生命，更加勇敢地面对困境。', 'options': [{'text': '害怕', 'isCorrect': True}, {'text': '恐惧', 'isCorrect': True}, {'text': '担忧', 'isCorrect': True}]}, {'word': 'punish', 'dialog': '《辛德勒的名单》中，辛德勒因为保护犹太人而受到纳粹的punish。他被剥夺了财产，被关进了集中营，甚至差点失去了生命。然而，他并没有放弃，他用自己的智慧和勇气，最终拯救了上千名犹太人的生命。他的故事告诉我们，即使面对punish，也要坚持正义和善良。', 'options': [{'text': '处罚', 'isCorrect': True}, {'text': '惩罚', 'isCorrect': True}, {'text': '报复', 'isCorrect': False}]}]

# %%
print('开始添加下个场景字段')
# 为每个条目的options列表添加nextScene
i = 1
for item in random_json_data:
    for option in item['options']:
        if option['isCorrect']:
            option['nextScene'] = i
            i += 1
        else:
            option['nextScene'] = -1

# 打印结果以验证
for item in random_json_data:
    print(f"Word: {item['word']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
next_scene_json_data = random_json_data
print('添加下个场景字段完成')

# %%
print('在json中添加npcName字段')

# 为每个条目添加npcName字段
for item in next_scene_json_data:
    item['npcName'] = moviesName  # 添加npcName字段

# 打印结果以验证
for item in next_scene_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
npc_name_json_data = next_scene_json_data
print('在json中添加npcName字段完成')

print('在json中添加npcAvatar字段')
# 为每个条目添加npcAvatar字段
for item in npc_name_json_data:
    item['npcAvatar'] = next((item["npcAvatar"] for item in assistant_preset if item["npcName"] == moviesName), None)  # 添加npcAvatar字段

# 打印结果以验证
for item in npc_name_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
npc_avatar_json_data = npc_name_json_data
print('在json中添加npcName和npcAvatar字段完成')

print('在json中添加backgroundVideo字段')
# 为每个条目添加backgroundVideo字段
for item in npc_avatar_json_data:
    item['backgroundVideo'] = next((item["backgroundVideo"] for item in assistant_preset if item["npcName"] == moviesName), None)  # 添加backgroundVideo字段

# 打印结果以验证
for item in npc_avatar_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}, Background Video: {item['backgroundVideo']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
background_video_json_data = npc_avatar_json_data
print('在json中添加npcName、npcAvatar和backgroundVideo字段完成')

print(background_video_json_data)

background_video_json_data.append({
    "word": "none",
    "dialog": "恭喜你完成了游戏的所有关卡，点击重玩游戏，重新开始游戏",
    "options": [
        { "text": "重玩游戏", "isCorrect": "true", "nextScene": 0 },
    ],
    "npcName": moviesName,
    "npcAvatar": next((item["npcAvatar"] for item in assistant_preset if item["npcName"] == moviesName), None),
    "backgroundVideo": next((item["backgroundVideo"] for item in assistant_preset if item["npcName"] == moviesName), None),
})

# 将options中的True和False改为小写字符串
for item in background_video_json_data:
    for option in item['options']:
        option['isCorrect'] = 'true' if option['isCorrect'] else 'false'

# 打印结果以验证
for item in background_video_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}, Background Video: {item['backgroundVideo']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)

background_video_json_data

# %%
from api.generate_scene import generate_scene
generate_scene('绿皮书', ['access','accessory','accident','accidental','accompany','accomplish','accord','accordance','afraid','punish'])
# Out:
# 开始生成带单词句子
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《绿皮书》中，托尼·利普对肖恩·科伊尔说：“如果你想要进入这个俱乐部，你需要有access。”这意味着他们需要一种方式来进入一个特定的场所。"
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中，肖恩·科伊尔的车被用作逃亡工具，这辆车在这里被视为他们的accessory，因为它是他们逃跑计划的一部分。"
#     },
#     {
#         "word": "accident",
#         "dialog": "肖恩·科伊尔在一次车祸中受伤，这是他职业生涯中的一个accident，但他最终克服了它，重返舞台。"
#     },
#     {
#         "word": "accidental",
#         "dialog": "电影中，肖恩·科伊尔的音乐家身份并非有意为之，而是由于一个accidental的机会，他开始与托尼·利普合作。"
#     },
#     {
#         "word": "accompany",
#         "dialog": "托尼·利普一直accompany肖恩·科伊尔在巡演中，帮助他处理旅途中的困难。"
#     },
#     {
#         "word": "accomplish",
#         "dialog": "肖恩·科伊尔在电影中最终accomplished他的梦想，重返舞台，这对他来说是一个巨大的成就。"
#     },
#     {
#         "word": "accord",
#         "dialog": "电影中，托尼·利普和肖恩·科伊尔之间建立了相互尊重的accord，这是他们关系中的一个重要方面。"
#     },
#     {
#         "word": "accordance",
#         "dialog": "在电影中，托尼·利普和肖恩·科伊尔在旅行过程中需要遵守一定的accordance，以适应不同地区的文化差异。"
#     },
#     {
#         "word": "afraid",
#         "dialog": "在电影的开头，托尼·利普对肖恩·科伊尔说：“I’m afraid I can’t make this trip with you.” 这表明他对这次旅行感到担忧。"
#     },
#     {
#         "word": "punish",
#         "dialog": "在电影中，托尼·利普曾经因为自己的过去而punish肖恩·科伊尔，但随着故事的发展，他开始意识到自己的错误，并努力改正。"
#     }
# ]
# ```
# 带单词句子生成完成
# 开始生成更长的句子
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《绿皮书》中，肖恩·科伊尔站在那扇紧闭的大门前，他的眼神中充满了渴望。托尼·利普严肃地说：“如果你想要进入这个俱乐部，你需要有access。”那一刻，肖恩的心跳加速，他知道，这扇门后的世界，是他音乐梦想的access，是他通往自由和尊重的钥匙。"
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中，那辆破旧的旅行车在夜色中显得格外孤独，它是肖恩和托尼·利普逃亡计划中的accessory。每当车灯照亮前方的路，它都像是在无声地诉说着他们共同面对的挑战和不确定的未来。"
#     },
#     {
#         "word": "accident",
#         "dialog": "肖恩·科伊尔的车在高速公路上失控，他的世界在那一瞬间变得模糊。他感到恐惧和绝望，但就在这时，托尼·利普的坚定声音让他意识到，无论发生什么，他都不是孤单一人。这是他职业生涯中的一个accident，但也是他成长的一个转折点。"
#     },
#     {
#         "word": "accidental",
#         "dialog": "电影中，肖恩·科伊尔的音乐家身份并非有意为之，而是命运的accidental安排。在一个寒冷的夜晚，他被托尼·利普的真诚所打动，开始了这场意外的旅程，这段旅程将改变他的一生。"
#     },
#     {
#         "word": "accompany",
#         "dialog": "托尼·利普坐在肖恩·科伊尔的身边，他的手紧握着方向盘，眼神坚定。他知道，他不仅仅是accompany肖恩在巡演中，他还在陪伴他穿越种族歧视的黑暗，给他勇气去面对生活中的每一次挑战。"
#     },
#     {
#         "word": "accomplish",
#         "dialog": "肖恩·科伊尔站在舞台中央，灯光聚焦在他身上，他的音乐在空气中回荡。他知道，他accomplished了不仅仅是自己的梦想，更是跨越种族障碍的一次胜利，这是他对自己和托尼·利普的承诺。"
#     },
#     {
#         "word": "accord",
#         "dialog": "在电影的最后，托尼·利普和肖恩·科伊尔坐在一家小餐馆里，他们的笑声和谈话充满了默契。这不仅仅是一份工作上的accord，更是一种超越了种族和文化的深厚友谊。"
#     },
#     {
#         "word": "accordance",
#         "dialog": "旅途中，托尼·利普和肖恩·科伊尔学会了如何在不同的文化和环境中保持accordance。他们一起面对着挑战，一起克服了偏见，这份旅程让他们学会了如何在尊重中生活。"
#     },
#     {
#         "word": "afraid",
#         "dialog": "托尼·利普站在肖恩·科伊尔的家门口，他的心中充满了不安。他深吸一口气，鼓起勇气说：“I’m afraid I can’t make this trip with you.” 但当他看到肖恩眼中的坚定，他知道自己不能放弃，他必须陪他走完这段旅程。"
#     },
#     {
#         "word": "punish",
#         "dialog": "托尼·利普在愤怒和自责中惩罚了自己，他无法接受自己的过去，这导致他伤害了肖恩。但随着时间的推移，他开始反思自己的行为，并努力改正，他明白，真正的惩罚是忽视了自己内心对改变的需求。"
#     }
# ]
# ```
# 更长句子生成完成
# 开始给每个内容加选项
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《绿皮书》中，肖恩·科伊尔站在那扇紧闭的大门前，他的眼神中充满了渴望。托尼·利普严肃地说：“如果你想要进入这个俱乐部，你需要有access。”那一刻，肖恩的心跳加速，他知道，这扇门后的世界，是他音乐梦想的access，是他通往自由和尊重的钥匙。",
#         "options": [
#             { "text": "入口", "isCorrect": true },
#             { "text": "通道", "isCorrect": false },
#             { "text": "接近", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中，那辆破旧的旅行车在夜色中显得格外孤独，它是肖恩和托尼·利普逃亡计划中的accessory。每当车灯照亮前方的路，它都像是在无声地诉说着他们共同面对的挑战和不确定的未来。",
#         "options": [
#             { "text": "配件", "isCorrect": false },
#             { "text": "帮凶", "isCorrect": false },
#             { "text": "辅助工具", "isCorrect": true }
#         ]
#     },
#     {
#         "word": "accident",
#         "dialog": "肖恩·科伊尔的车在高速公路上失控，他的世界在那一瞬间变得模糊。他感到恐惧和绝望，但就在这时，托尼·利普的坚定声音让他意识到，无论发生什么，他都不是孤单一人。这是他职业生涯中的一个accident，但也是他成长的一个转折点。",
#         "options": [
#             { "text": "事故", "isCorrect": true },
#             { "text": "意外", "isCorrect": false },
#             { "text": "偶然", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accidental",
#         "dialog": "电影中，肖恩·科伊尔的音乐家身份并非有意为之，而是命运的accidental安排。在一个寒冷的夜晚，他被托尼·利普的真诚所打动，开始了这场意外的旅程，这段旅程将改变他的一生。",
#         "options": [
#             { "text": "意外的", "isCorrect": true },
#             { "text": "偶然的", "isCorrect": false },
#             { "text": "不故意的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accompany",
#         "dialog": "托尼·利普坐在肖恩·科伊尔的身边，他的手紧握着方向盘，眼神坚定。他知道，他不仅仅是accompany肖恩在巡演中，他还在陪伴他穿越种族歧视的黑暗，给他勇气去面对生活中的每一次挑战。",
#         "options": [
#             { "text": "陪伴", "isCorrect": true },
#             { "text": "伴随", "isCorrect": false },
#             { "text": "陪同", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accomplish",
#         "dialog": "肖恩·科伊尔站在舞台中央，灯光聚焦在他身上，他的音乐在空气中回荡。他知道，他accomplished了不仅仅是自己的梦想，更是跨越种族障碍的一次胜利，这是他对自己和托尼·利普的承诺。",
#         "options": [
#             { "text": "完成", "isCorrect": true },
#             { "text": "实现", "isCorrect": true },
#             { "text": "达到", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accord",
#         "dialog": "在电影的最后，托尼·利普和肖恩·科伊尔坐在一家小餐馆里，他们的笑声和谈话充满了默契。这不仅仅是一份工作上的accord，更是一种超越了种族和文化的深厚友谊。",
#         "options": [
#             { "text": "协议", "isCorrect": true },
#             { "text": "协议书", "isCorrect": false },
#             { "text": "和解", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accordance",
#         "dialog": "旅途中，托尼·利普和肖恩·科伊尔学会了如何在不同的文化和环境中保持accordance。他们一起面对着挑战，一起克服了偏见，这份旅程让他们学会了如何在尊重中生活。",
#         "options": [
#             { "text": "一致", "isCorrect": true },
#             { "text": "一致性", "isCorrect": false },
#             { "text": "协议", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "afraid",
#         "dialog": "托尼·利普站在肖恩·科伊尔的家门口，他的心中充满了不安。他深吸一口气，鼓起勇气说：“I’m afraid I can’t make this trip with you.” 但当他看到肖恩眼中的坚定，他知道自己不能放弃，他必须陪他走完这段旅程。",
#         "options": [
#             { "text": "害怕", "isCorrect": true },
#             { "text": "担心", "isCorrect": false },
#             { "text": "恐惧", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "punish",
#         "dialog": "托尼·利普在愤怒和自责中惩罚了自己，他无法接受自己的过去，这导致他伤害了肖恩。但随着时间的推移，他开始反思自己的行为，并努力改正，他明白，真正的惩罚是忽视了自己内心对改变的需求。",
#         "options": [
#             { "text": "惩罚", "isCorrect": true },
#             { "text": "处罚", "isCorrect": false },
#             { "text": "责罚", "isCorrect": false }
#         ]
#     }
# ]
# ```
# 给每个内容加选项完成
# 开始清除json多余字段
# [{'word': 'access', 'dialog': '在《绿皮书》中，肖恩·科伊尔站在那扇紧闭的大门前，他的眼神中充满了渴望。托尼·利普严肃地说：“如果你想要进入这个俱乐部，你需要有access。”那一刻，肖恩的心跳加速，他知道，这扇门后的世界，是他音乐梦想的access，是他通往自由和尊重的钥匙。', 'options': [{'text': '入口', 'isCorrect': True}, {'text': '通道', 'isCorrect': False}, {'text': '接近', 'isCorrect': False}]}, {'word': 'accessory', 'dialog': '电影中，那辆破旧的旅行车在夜色中显得格外孤独，它是肖恩和托尼·利普逃亡计划中的accessory。每当车灯照亮前方的路，它都像是在无声地诉说着他们共同面对的挑战和不确定的未来。', 'options': [{'text': '配件', 'isCorrect': False}, {'text': '帮凶', 'isCorrect': False}, {'text': '辅助工具', 'isCorrect': True}]}, {'word': 'accident', 'dialog': '肖恩·科伊尔的车在高速公路上失控，他的世界在那一瞬间变得模糊。他感到恐惧和绝望，但就在这时，托尼·利普的坚定声音让他意识到，无论发生什么，他都不是孤单一人。这是他职业生涯中的一个accident，但也是他成长的一个转折点。', 'options': [{'text': '事故', 'isCorrect': True}, {'text': '意外', 'isCorrect': False}, {'text': '偶然', 'isCorrect': False}]}, {'word': 'accidental', 'dialog': '电影中，肖恩·科伊尔的音乐家身份并非有意为之，而是命运的accidental安排。在一个寒冷的夜晚，他被托尼·利普的真诚所打动，开始了这场意外的旅程，这段旅程将改变他的一生。', 'options': [{'text': '意外的', 'isCorrect': True}, {'text': '偶然的', 'isCorrect': False}, {'text': '不故意的', 'isCorrect': False}]}, {'word': 'accompany', 'dialog': '托尼·利普坐在肖恩·科伊尔的身边，他的手紧握着方向盘，眼神坚定。他知道，他不仅仅是accompany肖恩在巡演中，他还在陪伴他穿越种族歧视的黑暗，给他勇气去面对生活中的每一次挑战。', 'options': [{'text': '陪伴', 'isCorrect': True}, {'text': '伴随', 'isCorrect': False}, {'text': '陪同', 'isCorrect': False}]}, {'word': 'accomplish', 'dialog': '肖恩·科伊尔站在舞台中央，灯光聚焦在他身上，他的音乐在空气中回荡。他知道，他accomplished了不仅仅是自己的梦想，更是跨越种族障碍的一次胜利，这是他对自己和托尼·利普的承诺。', 'options': [{'text': '完成', 'isCorrect': True}, {'text': '实现', 'isCorrect': True}, {'text': '达到', 'isCorrect': False}]}, {'word': 'accord', 'dialog': '在电影的最后，托尼·利普和肖恩·科伊尔坐在一家小餐馆里，他们的笑声和谈话充满了默契。这不仅仅是一份工作上的accord，更是一种超越了种族和文化的深厚友谊。', 'options': [{'text': '协议', 'isCorrect': True}, {'text': '协议书', 'isCorrect': False}, {'text': '和解', 'isCorrect': False}]}, {'word': 'accordance', 'dialog': '旅途中，托尼·利普和肖恩·科伊尔学会了如何在不同的文化和环境中保持accordance。他们一起面对着挑战，一起克服了偏见，这份旅程让他们学会了如何在尊重中生活。', 'options': [{'text': '一致', 'isCorrect': True}, {'text': '一致性', 'isCorrect': False}, {'text': '协议', 'isCorrect': False}]}, {'word': 'afraid', 'dialog': '托尼·利普站在肖恩·科伊尔的家门口，他的心中充满了不安。他深吸一口气，鼓起勇气说：“I’m afraid I can’t make this trip with you.” 但当他看到肖恩眼中的坚定，他知道自己不能放弃，他必须陪他走完这段旅程。', 'options': [{'text': '害怕', 'isCorrect': True}, {'text': '担心', 'isCorrect': False}, {'text': '恐惧', 'isCorrect': False}]}, {'word': 'punish', 'dialog': '托尼·利普在愤怒和自责中惩罚了自己，他无法接受自己的过去，这导致他伤害了肖恩。但随着时间的推移，他开始反思自己的行为，并努力改正，他明白，真正的惩罚是忽视了自己内心对改变的需求。', 'options': [{'text': '惩罚', 'isCorrect': True}, {'text': '处罚', 'isCorrect': False}, {'text': '责罚', 'isCorrect': False}]}]
# 完成清除json多余字段
# 开始选项随机操作
# Word: access
# Translation: 入口, Correct: True
# Translation: 接近, Correct: False
# Translation: 通道, Correct: False
# --------------------------------------------------
# Word: accessory
# Translation: 帮凶, Correct: False
# Translation: 辅助工具, Correct: True
# Translation: 配件, Correct: False
# --------------------------------------------------
# Word: accident
# Translation: 意外, Correct: False
# Translation: 偶然, Correct: False
# Translation: 事故, Correct: True
# --------------------------------------------------
# Word: accidental
# Translation: 不故意的, Correct: False
# Translation: 偶然的, Correct: False
# Translation: 意外的, Correct: True
# --------------------------------------------------
# Word: accompany
# Translation: 陪伴, Correct: True
# Translation: 伴随, Correct: False
# Translation: 陪同, Correct: False
# --------------------------------------------------
# Word: accomplish
# Translation: 实现, Correct: True
# Translation: 达到, Correct: False
# Translation: 完成, Correct: True
# --------------------------------------------------
# Word: accord
# Translation: 协议, Correct: True
# Translation: 和解, Correct: False
# Translation: 协议书, Correct: False
# --------------------------------------------------
# Word: accordance
# Translation: 一致, Correct: True
# Translation: 一致性, Correct: False
# Translation: 协议, Correct: False
# --------------------------------------------------
# Word: afraid
# Translation: 恐惧, Correct: False
# Translation: 害怕, Correct: True
# Translation: 担心, Correct: False
# --------------------------------------------------
# Word: punish
# Translation: 责罚, Correct: False
# Translation: 惩罚, Correct: True
# Translation: 处罚, Correct: False
# --------------------------------------------------
# 完成选项随机操作
# [{'word': 'access', 'dialog': '在《绿皮书》中，肖恩·科伊尔站在那扇紧闭的大门前，他的眼神中充满了渴望。托尼·利普严肃地说：“如果你想要进入这个俱乐部，你需要有access。”那一刻，肖恩的心跳加速，他知道，这扇门后的世界，是他音乐梦想的access，是他通往自由和尊重的钥匙。', 'options': [{'text': '入口', 'isCorrect': True}, {'text': '接近', 'isCorrect': False}, {'text': '通道', 'isCorrect': False}]}, {'word': 'accessory', 'dialog': '电影中，那辆破旧的旅行车在夜色中显得格外孤独，它是肖恩和托尼·利普逃亡计划中的accessory。每当车灯照亮前方的路，它都像是在无声地诉说着他们共同面对的挑战和不确定的未来。', 'options': [{'text': '帮凶', 'isCorrect': False}, {'text': '辅助工具', 'isCorrect': True}, {'text': '配件', 'isCorrect': False}]}, {'word': 'accident', 'dialog': '肖恩·科伊尔的车在高速公路上失控，他的世界在那一瞬间变得模糊。他感到恐惧和绝望，但就在这时，托尼·利普的坚定声音让他意识到，无论发生什么，他都不是孤单一人。这是他职业生涯中的一个accident，但也是他成长的一个转折点。', 'options': [{'text': '意外', 'isCorrect': False}, {'text': '偶然', 'isCorrect': False}, {'text': '事故', 'isCorrect': True}]}, {'word': 'accidental', 'dialog': '电影中，肖恩·科伊尔的音乐家身份并非有意为之，而是命运的accidental安排。在一个寒冷的夜晚，他被托尼·利普的真诚所打动，开始了这场意外的旅程，这段旅程将改变他的一生。', 'options': [{'text': '不故意的', 'isCorrect': False}, {'text': '偶然的', 'isCorrect': False}, {'text': '意外的', 'isCorrect': True}]}, {'word': 'accompany', 'dialog': '托尼·利普坐在肖恩·科伊尔的身边，他的手紧握着方向盘，眼神坚定。他知道，他不仅仅是accompany肖恩在巡演中，他还在陪伴他穿越种族歧视的黑暗，给他勇气去面对生活中的每一次挑战。', 'options': [{'text': '陪伴', 'isCorrect': True}, {'text': '伴随', 'isCorrect': False}, {'text': '陪同', 'isCorrect': False}]}, {'word': 'accomplish', 'dialog': '肖恩·科伊尔站在舞台中央，灯光聚焦在他身上，他的音乐在空气中回荡。他知道，他accomplished了不仅仅是自己的梦想，更是跨越种族障碍的一次胜利，这是他对自己和托尼·利普的承诺。', 'options': [{'text': '实现', 'isCorrect': True}, {'text': '达到', 'isCorrect': False}, {'text': '完成', 'isCorrect': True}]}, {'word': 'accord', 'dialog': '在电影的最后，托尼·利普和肖恩·科伊尔坐在一家小餐馆里，他们的笑声和谈话充满了默契。这不仅仅是一份工作上的accord，更是一种超越了种族和文化的深厚友谊。', 'options': [{'text': '协议', 'isCorrect': True}, {'text': '和解', 'isCorrect': False}, {'text': '协议书', 'isCorrect': False}]}, {'word': 'accordance', 'dialog': '旅途中，托尼·利普和肖恩·科伊尔学会了如何在不同的文化和环境中保持accordance。他们一起面对着挑战，一起克服了偏见，这份旅程让他们学会了如何在尊重中生活。', 'options': [{'text': '一致', 'isCorrect': True}, {'text': '一致性', 'isCorrect': False}, {'text': '协议', 'isCorrect': False}]}, {'word': 'afraid', 'dialog': '托尼·利普站在肖恩·科伊尔的家门口，他的心中充满了不安。他深吸一口气，鼓起勇气说：“I’m afraid I can’t make this trip with you.” 但当他看到肖恩眼中的坚定，他知道自己不能放弃，他必须陪他走完这段旅程。', 'options': [{'text': '恐惧', 'isCorrect': False}, {'text': '害怕', 'isCorrect': True}, {'text': '担心', 'isCorrect': False}]}, {'word': 'punish', 'dialog': '托尼·利普在愤怒和自责中惩罚了自己，他无法接受自己的过去，这导致他伤害了肖恩。但随着时间的推移，他开始反思自己的行为，并努力改正，他明白，真正的惩罚是忽视了自己内心对改变的需求。', 'options': [{'text': '责罚', 'isCorrect': False}, {'text': '惩罚', 'isCorrect': True}, {'text': '处罚', 'isCorrect': False}]}]
# 开始添加下个场景字段
# Word: access
# Translation: 入口, Correct: True, NextScene: 1
# Translation: 接近, Correct: False, NextScene: -1
# Translation: 通道, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accessory
# Translation: 帮凶, Correct: False, NextScene: -1
# Translation: 辅助工具, Correct: True, NextScene: 2
# Translation: 配件, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accident
# Translation: 意外, Correct: False, NextScene: -1
# Translation: 偶然, Correct: False, NextScene: -1
# Translation: 事故, Correct: True, NextScene: 3
# --------------------------------------------------
# Word: accidental
# Translation: 不故意的, Correct: False, NextScene: -1
# Translation: 偶然的, Correct: False, NextScene: -1
# Translation: 意外的, Correct: True, NextScene: 4
# --------------------------------------------------
# Word: accompany
# Translation: 陪伴, Correct: True, NextScene: 5
# Translation: 伴随, Correct: False, NextScene: -1
# Translation: 陪同, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accomplish
# Translation: 实现, Correct: True, NextScene: 6
# Translation: 达到, Correct: False, NextScene: -1
# Translation: 完成, Correct: True, NextScene: 7
# --------------------------------------------------
# Word: accord
# Translation: 协议, Correct: True, NextScene: 8
# Translation: 和解, Correct: False, NextScene: -1
# Translation: 协议书, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accordance
# Translation: 一致, Correct: True, NextScene: 9
# Translation: 一致性, Correct: False, NextScene: -1
# Translation: 协议, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: afraid
# Translation: 恐惧, Correct: False, NextScene: -1
# Translation: 害怕, Correct: True, NextScene: 10
# Translation: 担心, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: punish
# Translation: 责罚, Correct: False, NextScene: -1
# Translation: 惩罚, Correct: True, NextScene: 11
# Translation: 处罚, Correct: False, NextScene: -1
# --------------------------------------------------
# 添加下个场景字段完成
# 在json中添加npcName字段
# Word: access, NPC Name: 绿皮书
# Translation: 入口, Correct: True, NextScene: 1
# Translation: 接近, Correct: False, NextScene: -1
# Translation: 通道, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accessory, NPC Name: 绿皮书
# Translation: 帮凶, Correct: False, NextScene: -1
# Translation: 辅助工具, Correct: True, NextScene: 2
# Translation: 配件, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accident, NPC Name: 绿皮书
# Translation: 意外, Correct: False, NextScene: -1
# Translation: 偶然, Correct: False, NextScene: -1
# Translation: 事故, Correct: True, NextScene: 3
# --------------------------------------------------
# Word: accidental, NPC Name: 绿皮书
# Translation: 不故意的, Correct: False, NextScene: -1
# Translation: 偶然的, Correct: False, NextScene: -1
# Translation: 意外的, Correct: True, NextScene: 4
# --------------------------------------------------
# Word: accompany, NPC Name: 绿皮书
# Translation: 陪伴, Correct: True, NextScene: 5
# Translation: 伴随, Correct: False, NextScene: -1
# Translation: 陪同, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accomplish, NPC Name: 绿皮书
# Translation: 实现, Correct: True, NextScene: 6
# Translation: 达到, Correct: False, NextScene: -1
# Translation: 完成, Correct: True, NextScene: 7
# --------------------------------------------------
# Word: accord, NPC Name: 绿皮书
# Translation: 协议, Correct: True, NextScene: 8
# Translation: 和解, Correct: False, NextScene: -1
# Translation: 协议书, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accordance, NPC Name: 绿皮书
# Translation: 一致, Correct: True, NextScene: 9
# Translation: 一致性, Correct: False, NextScene: -1
# Translation: 协议, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: afraid, NPC Name: 绿皮书
# Translation: 恐惧, Correct: False, NextScene: -1
# Translation: 害怕, Correct: True, NextScene: 10
# Translation: 担心, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: punish, NPC Name: 绿皮书
# Translation: 责罚, Correct: False, NextScene: -1
# Translation: 惩罚, Correct: True, NextScene: 11
# Translation: 处罚, Correct: False, NextScene: -1
# --------------------------------------------------
# 在json中添加npcName字段完成
# 在json中添加npcAvatar字段
# Word: access, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 入口, Correct: True, NextScene: 1
# Translation: 接近, Correct: False, NextScene: -1
# Translation: 通道, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accessory, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 帮凶, Correct: False, NextScene: -1
# Translation: 辅助工具, Correct: True, NextScene: 2
# Translation: 配件, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accident, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 意外, Correct: False, NextScene: -1
# Translation: 偶然, Correct: False, NextScene: -1
# Translation: 事故, Correct: True, NextScene: 3
# --------------------------------------------------
# Word: accidental, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 不故意的, Correct: False, NextScene: -1
# Translation: 偶然的, Correct: False, NextScene: -1
# Translation: 意外的, Correct: True, NextScene: 4
# --------------------------------------------------
# Word: accompany, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 陪伴, Correct: True, NextScene: 5
# Translation: 伴随, Correct: False, NextScene: -1
# Translation: 陪同, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accomplish, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 实现, Correct: True, NextScene: 6
# Translation: 达到, Correct: False, NextScene: -1
# Translation: 完成, Correct: True, NextScene: 7
# --------------------------------------------------
# Word: accord, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 协议, Correct: True, NextScene: 8
# Translation: 和解, Correct: False, NextScene: -1
# Translation: 协议书, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accordance, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 一致, Correct: True, NextScene: 9
# Translation: 一致性, Correct: False, NextScene: -1
# Translation: 协议, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: afraid, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 恐惧, Correct: False, NextScene: -1
# Translation: 害怕, Correct: True, NextScene: 10
# Translation: 担心, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: punish, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg
# Translation: 责罚, Correct: False, NextScene: -1
# Translation: 惩罚, Correct: True, NextScene: 11
# Translation: 处罚, Correct: False, NextScene: -1
# --------------------------------------------------
# 在json中添加npcName和npcAvatar字段完成
# 在json中添加backgroundVideo字段
# Word: access, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 入口, Correct: True, NextScene: 1
# Translation: 接近, Correct: False, NextScene: -1
# Translation: 通道, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accessory, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 帮凶, Correct: False, NextScene: -1
# Translation: 辅助工具, Correct: True, NextScene: 2
# Translation: 配件, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accident, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 意外, Correct: False, NextScene: -1
# Translation: 偶然, Correct: False, NextScene: -1
# Translation: 事故, Correct: True, NextScene: 3
# --------------------------------------------------
# Word: accidental, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 不故意的, Correct: False, NextScene: -1
# Translation: 偶然的, Correct: False, NextScene: -1
# Translation: 意外的, Correct: True, NextScene: 4
# --------------------------------------------------
# Word: accompany, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 陪伴, Correct: True, NextScene: 5
# Translation: 伴随, Correct: False, NextScene: -1
# Translation: 陪同, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accomplish, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 实现, Correct: True, NextScene: 6
# Translation: 达到, Correct: False, NextScene: -1
# Translation: 完成, Correct: True, NextScene: 7
# --------------------------------------------------
# Word: accord, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 协议, Correct: True, NextScene: 8
# Translation: 和解, Correct: False, NextScene: -1
# Translation: 协议书, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accordance, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 一致, Correct: True, NextScene: 9
# Translation: 一致性, Correct: False, NextScene: -1
# Translation: 协议, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: afraid, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 恐惧, Correct: False, NextScene: -1
# Translation: 害怕, Correct: True, NextScene: 10
# Translation: 担心, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: punish, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 责罚, Correct: False, NextScene: -1
# Translation: 惩罚, Correct: True, NextScene: 11
# Translation: 处罚, Correct: False, NextScene: -1
# --------------------------------------------------
# 在json中添加npcName、npcAvatar和backgroundVideo字段完成
# [{'word': 'access', 'dialog': '在《绿皮书》中，肖恩·科伊尔站在那扇紧闭的大门前，他的眼神中充满了渴望。托尼·利普严肃地说：“如果你想要进入这个俱乐部，你需要有access。”那一刻，肖恩的心跳加速，他知道，这扇门后的世界，是他音乐梦想的access，是他通往自由和尊重的钥匙。', 'options': [{'text': '入口', 'isCorrect': True, 'nextScene': 1}, {'text': '接近', 'isCorrect': False, 'nextScene': -1}, {'text': '通道', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'accessory', 'dialog': '电影中，那辆破旧的旅行车在夜色中显得格外孤独，它是肖恩和托尼·利普逃亡计划中的accessory。每当车灯照亮前方的路，它都像是在无声地诉说着他们共同面对的挑战和不确定的未来。', 'options': [{'text': '帮凶', 'isCorrect': False, 'nextScene': -1}, {'text': '辅助工具', 'isCorrect': True, 'nextScene': 2}, {'text': '配件', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'accident', 'dialog': '肖恩·科伊尔的车在高速公路上失控，他的世界在那一瞬间变得模糊。他感到恐惧和绝望，但就在这时，托尼·利普的坚定声音让他意识到，无论发生什么，他都不是孤单一人。这是他职业生涯中的一个accident，但也是他成长的一个转折点。', 'options': [{'text': '意外', 'isCorrect': False, 'nextScene': -1}, {'text': '偶然', 'isCorrect': False, 'nextScene': -1}, {'text': '事故', 'isCorrect': True, 'nextScene': 3}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'accidental', 'dialog': '电影中，肖恩·科伊尔的音乐家身份并非有意为之，而是命运的accidental安排。在一个寒冷的夜晚，他被托尼·利普的真诚所打动，开始了这场意外的旅程，这段旅程将改变他的一生。', 'options': [{'text': '不故意的', 'isCorrect': False, 'nextScene': -1}, {'text': '偶然的', 'isCorrect': False, 'nextScene': -1}, {'text': '意外的', 'isCorrect': True, 'nextScene': 4}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'accompany', 'dialog': '托尼·利普坐在肖恩·科伊尔的身边，他的手紧握着方向盘，眼神坚定。他知道，他不仅仅是accompany肖恩在巡演中，他还在陪伴他穿越种族歧视的黑暗，给他勇气去面对生活中的每一次挑战。', 'options': [{'text': '陪伴', 'isCorrect': True, 'nextScene': 5}, {'text': '伴随', 'isCorrect': False, 'nextScene': -1}, {'text': '陪同', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'accomplish', 'dialog': '肖恩·科伊尔站在舞台中央，灯光聚焦在他身上，他的音乐在空气中回荡。他知道，他accomplished了不仅仅是自己的梦想，更是跨越种族障碍的一次胜利，这是他对自己和托尼·利普的承诺。', 'options': [{'text': '实现', 'isCorrect': True, 'nextScene': 6}, {'text': '达到', 'isCorrect': False, 'nextScene': -1}, {'text': '完成', 'isCorrect': True, 'nextScene': 7}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'accord', 'dialog': '在电影的最后，托尼·利普和肖恩·科伊尔坐在一家小餐馆里，他们的笑声和谈话充满了默契。这不仅仅是一份工作上的accord，更是一种超越了种族和文化的深厚友谊。', 'options': [{'text': '协议', 'isCorrect': True, 'nextScene': 8}, {'text': '和解', 'isCorrect': False, 'nextScene': -1}, {'text': '协议书', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'accordance', 'dialog': '旅途中，托尼·利普和肖恩·科伊尔学会了如何在不同的文化和环境中保持accordance。他们一起面对着挑战，一起克服了偏见，这份旅程让他们学会了如何在尊重中生活。', 'options': [{'text': '一致', 'isCorrect': True, 'nextScene': 9}, {'text': '一致性', 'isCorrect': False, 'nextScene': -1}, {'text': '协议', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}, {'word': 'afraid', 'dialog': '托尼·利普站在肖恩·科伊尔的家门口，他的心中充满了不安。他深吸一口气，鼓起勇气说：“I’m afraid I can’t make this trip with you.” 但当他看到肖恩眼中的坚定，他知道自己不能放弃，他必须陪他走完这段旅程。', 'options': [{'text': '恐惧', 'isCorrect': False, 'nextScene': -1}, {'text': '害怕', 'isCorrect': True, 'nextScene': 10}, {'text': '担心', 'isCorrect': False, 'nextScene': -1}], 'npcName': '绿皮书', 'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg', 'backgroundVideo': ...
# Word: access, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 入口, Correct: true, NextScene: 1
# Translation: 接近, Correct: false, NextScene: -1
# Translation: 通道, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: accessory, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 帮凶, Correct: false, NextScene: -1
# Translation: 辅助工具, Correct: true, NextScene: 2
# Translation: 配件, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: accident, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 意外, Correct: false, NextScene: -1
# Translation: 偶然, Correct: false, NextScene: -1
# Translation: 事故, Correct: true, NextScene: 3
# --------------------------------------------------
# Word: accidental, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 不故意的, Correct: false, NextScene: -1
# Translation: 偶然的, Correct: false, NextScene: -1
# Translation: 意外的, Correct: true, NextScene: 4
# --------------------------------------------------
# Word: accompany, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 陪伴, Correct: true, NextScene: 5
# Translation: 伴随, Correct: false, NextScene: -1
# Translation: 陪同, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: accomplish, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 实现, Correct: true, NextScene: 6
# Translation: 达到, Correct: false, NextScene: -1
# Translation: 完成, Correct: true, NextScene: 7
# --------------------------------------------------
# Word: accord, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 协议, Correct: true, NextScene: 8
# Translation: 和解, Correct: false, NextScene: -1
# Translation: 协议书, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: accordance, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 一致, Correct: true, NextScene: 9
# Translation: 一致性, Correct: false, NextScene: -1
# Translation: 协议, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: afraid, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 恐惧, Correct: false, NextScene: -1
# Translation: 害怕, Correct: true, NextScene: 10
# Translation: 担心, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: punish, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 责罚, Correct: false, NextScene: -1
# Translation: 惩罚, Correct: true, NextScene: 11
# Translation: 处罚, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: none, NPC Name: 绿皮书, NPC Avatar: http://cdn.docuparser.top/avatar/lvpishu.jpeg, Background Video: http://cdn.docuparser.top/video/lvpishu.mp4
# Translation: 重玩游戏, Correct: true, NextScene: 0
# --------------------------------------------------
# [{'word': 'access',
#   'dialog': '在《绿皮书》中，肖恩·科伊尔站在那扇紧闭的大门前，他的眼神中充满了渴望。托尼·利普严肃地说：“如果你想要进入这个俱乐部，你需要有access。”那一刻，肖恩的心跳加速，他知道，这扇门后的世界，是他音乐梦想的access，是他通往自由和尊重的钥匙。',
#   'options': [{'text': '入口', 'isCorrect': 'true', 'nextScene': 1},
#    {'text': '接近', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '通道', 'isCorrect': 'false', 'nextScene': -1}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'},
#  {'word': 'accessory',
#   'dialog': '电影中，那辆破旧的旅行车在夜色中显得格外孤独，它是肖恩和托尼·利普逃亡计划中的accessory。每当车灯照亮前方的路，它都像是在无声地诉说着他们共同面对的挑战和不确定的未来。',
#   'options': [{'text': '帮凶', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '辅助工具', 'isCorrect': 'true', 'nextScene': 2},
#    {'text': '配件', 'isCorrect': 'false', 'nextScene': -1}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'},
#  {'word': 'accident',
#   'dialog': '肖恩·科伊尔的车在高速公路上失控，他的世界在那一瞬间变得模糊。他感到恐惧和绝望，但就在这时，托尼·利普的坚定声音让他意识到，无论发生什么，他都不是孤单一人。这是他职业生涯中的一个accident，但也是他成长的一个转折点。',
#   'options': [{'text': '意外', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '偶然', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '事故', 'isCorrect': 'true', 'nextScene': 3}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'},
#  {'word': 'accidental',
#   'dialog': '电影中，肖恩·科伊尔的音乐家身份并非有意为之，而是命运的accidental安排。在一个寒冷的夜晚，他被托尼·利普的真诚所打动，开始了这场意外的旅程，这段旅程将改变他的一生。',
#   'options': [{'text': '不故意的', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '偶然的', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '意外的', 'isCorrect': 'true', 'nextScene': 4}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'},
#  {'word': 'accompany',
#   'dialog': '托尼·利普坐在肖恩·科伊尔的身边，他的手紧握着方向盘，眼神坚定。他知道，他不仅仅是accompany肖恩在巡演中，他还在陪伴他穿越种族歧视的黑暗，给他勇气去面对生活中的每一次挑战。',
#   'options': [{'text': '陪伴', 'isCorrect': 'true', 'nextScene': 5},
#    {'text': '伴随', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '陪同', 'isCorrect': 'false', 'nextScene': -1}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'},
#  {'word': 'accomplish',
#   'dialog': '肖恩·科伊尔站在舞台中央，灯光聚焦在他身上，他的音乐在空气中回荡。他知道，他accomplished了不仅仅是自己的梦想，更是跨越种族障碍的一次胜利，这是他对自己和托尼·利普的承诺。',
#   'options': [{'text': '实现', 'isCorrect': 'true', 'nextScene': 6},
#    {'text': '达到', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '完成', 'isCorrect': 'true', 'nextScene': 7}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'},
#  {'word': 'accord',
#   'dialog': '在电影的最后，托尼·利普和肖恩·科伊尔坐在一家小餐馆里，他们的笑声和谈话充满了默契。这不仅仅是一份工作上的accord，更是一种超越了种族和文化的深厚友谊。',
#   'options': [{'text': '协议', 'isCorrect': 'true', 'nextScene': 8},
#    {'text': '和解', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '协议书', 'isCorrect': 'false', 'nextScene': -1}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'},
#  {'word': 'accordance',
#   'dialog': '旅途中，托尼·利普和肖恩·科伊尔学会了如何在不同的文化和环境中保持accordance。他们一起面对着挑战，一起克服了偏见，这份旅程让他们学会了如何在尊重中生活。',
#   'options': [{'text': '一致', 'isCorrect': 'true', 'nextScene': 9},
#    {'text': '一致性', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '协议', 'isCorrect': 'false', 'nextScene': -1}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'},
#  {'word': 'afraid',
#   'dialog': '托尼·利普站在肖恩·科伊尔的家门口，他的心中充满了不安。他深吸一口气，鼓起勇气说：“I’m afraid I can’t make this trip with you.” 但当他看到肖恩眼中的坚定，他知道自己不能放弃，他必须陪他走完这段旅程。',
#   'options': [{'text': '恐惧', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '害怕', 'isCorrect': 'true', 'nextScene': 10},
#    {'text': '担心', 'isCorrect': 'false', 'nextScene': -1}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'},
#  {'word': 'punish',
#   'dialog': '托尼·利普在愤怒和自责中惩罚了自己，他无法接受自己的过去，这导致他伤害了肖恩。但随着时间的推移，他开始反思自己的行为，并努力改正，他明白，真正的惩罚是忽视了自己内心对改变的需求。',
#   'options': [{'text': '责罚', 'isCorrect': 'false', 'nextScene': -1},
#    {'text': '惩罚', 'isCorrect': 'true', 'nextScene': 11},
#    {'text': '处罚', 'isCorrect': 'false', 'nextScene': -1}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'},
#  {'word': 'none',
#   'dialog': '恭喜你完成了游戏的所有关卡，点击重玩游戏，重新开始游戏',
#   'options': [{'text': '重玩游戏', 'isCorrect': 'true', 'nextScene': 0}],
#   'npcName': '绿皮书',
#   'npcAvatar': 'http://cdn.docuparser.top/avatar/lvpishu.jpeg',
#   'backgroundVideo': 'http://cdn.docuparser.top/video/lvpishu.mp4'}]
