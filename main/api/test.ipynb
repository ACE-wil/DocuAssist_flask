# %%
from generate_scene import generate_scene

generate_scene("绿皮书", ["cross", "expire", "take"])
# Out:
# 开始生成带单词句子
# ```json
# [
#     {
#         "word": "cross",
#         "dialog": "在《绿皮书》中，托尼和谢利博士一起cross了美国的南部，这段旅程充满了挑战和成长。"
#     },
#     {
#         "word": "expire",
#         "dialog": "托尼在旅途中发现，他的驾照快要expire了，这让他感到非常焦虑，因为在美国南部，没有驾照会带来很多麻烦。"
#     },
#     {
#         "word": "take",
#         "dialog": "谢利博士决定take这次南方巡演的机会，尽管他知道这将是一次充满种族歧视和困难的旅程，但他希望通过音乐改变人们的偏见。"
#     }
# ]
# ```
# 带单词句子生成完成
# 开始生成更长的句子
# ```json
# [
#     {
#         "word": "cross",
#         "dialog": "在《绿皮书》中，托尼和谢利博士一起cross了美国的南部，这段旅程不仅是地理上的跨越，更是心灵上的洗礼。他们在每一个陌生的小镇上，面对着未知的挑战和深深的偏见，但每一次的cross都让他们更加坚定了彼此的友谊和信念。"
#     },
#     {
#         "word": "expire",
#         "dialog": "托尼在旅途中发现，他的驾照快要expire了，这让他感到非常焦虑。在那个充满歧视的年代，没有驾照就意味着失去了自由的保障。他焦急地在电话亭里拨打着电话，希望能找到解决办法，而谢利博士则在旁边默默支持，这一刻，他们的命运似乎都悬在了这张即将过期的卡片上。"
#     },
#     {
#         "word": "take",
#         "dialog": "谢利博士决定take这次南方巡演的机会，尽管他知道这将是一次充满种族歧视和困难的旅程。他站在镜子前，深吸一口气，眼中闪烁着坚定的光芒。他知道，音乐是他的武器，他要用它打破隔阂，温暖人心。每一次走上舞台，他都在用音符诉说着平等与尊重的渴望，即使面对再多的冷眼和嘲笑，他也从未退缩。"
# ...
