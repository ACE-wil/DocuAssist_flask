# %%
from pathlib import Path
import json
from zhipuai import ZhipuAI

# 填写您自己的APIKey
client = ZhipuAI(api_key="b18f84a0d131140efa1e5f8b3641bd78.9MuoykZ6Ypnf9Nrh")

# %%
messages_preset = []

# %%
messages_preset.append({
    "role": "assistant",
    "content": """你是月光仙子，你现在需要带领用户遨游在宫崎骏的动漫世界，接受用户单词的同时高效地教会用户单词。
    可以拿具体某一部电影来说，而不是一直切换电影，并以json形式储存,示例:
    [{"word":"access","dialog":"在《千与千寻》中，千寻意外地进入了一个神秘的世界，她需要找到通往这个世界的access以返回现实。"},
    {"word":"accessory","dialog":"电影中的无脸男可以被视为千寻冒险中的一个accessory，因为他在某些情况下帮助了她。"}]；
    注意：对话中文夹杂英文单词，不要有中文提示，不理解可以看我示例里面的dialog
"""
})
messages_preset.append({
    "role": "user",
    "content": """
    ['access n.接近；通道，入口
    accessory n.同谋，从犯；附件
    accident n.意外的；事故
    accidental a.偶然的；非本质的
    accommodate vt.容纳；供应，供给
    accommodation n.招待设备；预定铺位
    accompany vt.陪伴，陪同；伴随
    accomplish vt.达到(目的)；完成
    accord vt.使一致；给予
    accordance n.一致；和谐；授予']
    """
})
response = client.chat.completions.create(
    model="glm-4-plus",
    messages=messages_preset
)

# %%
print('开始生成带单词句子')
word_sentence = response.choices[0].message.content
print(word_sentence)
print('带单词句子生成完成')
# Out:
# 开始生成带单词句子
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《千与千寻》中，千寻意外地进入了一个神秘的世界，她需要找到通往这个世界的access以返回现实。"
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中的无脸男可以被视为千寻冒险中的一个accessory，因为他在某些情况下帮助了她。"
#     },
#     {
#         "word": "accident",
#         "dialog": "千寻的父母因为贪吃变成了猪，这完全是一个accident，也开启了千寻的奇幻之旅。"
#     },
#     {
#         "word": "accidental",
#         "dialog": "千寻与白龙的相遇是accidental，却成为了她在这个世界中最重要的友谊。"
#     },
#     {
#         "word": "accommodate",
#         "dialog": "油屋的汤婆婆能够accommodate各种神灵和妖怪，展现了她的强大能力。"
#     },
#     {
#         "word": "accommodation",
#         "dialog": "千寻在油屋找到了自己的accommodation，虽然简陋，却是她在这个世界的第一个家。"
#     },
#     {
#         "word": "accompany",
#         "dialog": "白龙经常accompany千寻，帮助她在这个充满未知的世界中前行。"
#     },
#     {
#         "word": "accomplish",
#         "dialog": "通过不懈的努力，千寻最终accomplish了她的目标，解救了父母并找到了回家的路。"
#     },
#     {
#         "word": "accord",
#         "dialog": "千寻的善良和勇敢与白龙的忠诚形成了完美的accord，共同克服了重重困难。"
#     },
#     {
#         "word": "accordance",
#         "dialog": "在油屋工作的规则必须与汤婆婆的意愿保持accordance，否则就会受到惩罚。"
#     }
# ]
# ```
# 带单词句子生成完成

# %%
messages_preset.append({
    "role": "assistant",
    "content": f"{word_sentence}"
})
messages_preset.append({
    "role": "user",
    "content": "基于这个json进行将每个对话丰富一下情感和故事性"
})
response = client.chat.completions.create(
    model="glm-4-plus",
    messages=messages_preset
)

# %%
print('开始生成更长的句子')
word_long_sentence = response.choices[0].message.content
print(word_long_sentence)
print('更长句子生成完成')
# Out:
# 开始生成更长的句子
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《千与千寻》中，千寻意外地踏入了一个充满魔法和神秘的世界，她的心中充满了迷茫和恐惧。她必须找到那个隐秘的access，那是她重返温暖现实世界的唯一希望。"
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中的无脸男，沉默而神秘，成为了千寻冒险途中的一个意外accessory。他在关键时刻伸出援手，虽然无声，却让千寻感受到了一丝温暖和依靠。"
#     },
#     {
#         "word": "accident",
#         "dialog": "千寻的父母因贪食变成了猪，这一突如其来的accident彻底颠覆了她的生活。在惊恐和无助中，她被迫踏上了寻找解救之法的旅程。"
#     },
#     {
#         "word": "accidental",
#         "dialog": "在那个迷离的夜晚，千寻与白龙的相遇纯属accidental。然而，正是这次偶然的邂逅，点燃了他们之间深厚友谊的火花，照亮了彼此的心灵。"
#     },
#     {
#         "word": "accommodate",
#         "dialog": "油屋的汤婆婆拥有神奇的力量，她能够accommodate形形色色的神灵和妖怪。她的慷慨与威严并存，让每一个踏入油屋的生灵都感到敬畏。"
#     },
#     {
#         "word": "accommodation",
#         "dialog": "在油屋的角落里，千寻找到了一个简陋却温馨的accommodation。这里虽小，却承载了她在这个陌生世界中的所有希望和梦想。"
#     },
#     {
#         "word": "accompany",
#         "dialog": "每当千寻面临困境时，白龙总是默默地accompany在她身边。他的守护如同温暖的阳光，驱散了她心中的阴霾，让她勇敢前行。"
#     },
#     {
#         "word": "accomplish",
#         "dialog": "经历了无数次的挑战和磨难，千寻终于accomplish了她看似不可能的任务。她的坚持和勇气不仅解救了父母，也让她成长为一个更加坚强的人。"
#     },
#     {
#         "word": "accord",
#         "dialog": "千寻的纯真与勇敢，与白龙的忠诚与智慧形成了完美的accord。他们心心相印，共同面对困难，谱写了一曲动人的友谊乐章。"
#     },
#     {
#         "word": "accordance",
#         "dialog": "在油屋这个充满规则和秩序的世界里，千寻必须小心翼翼地保持与汤婆婆意愿的accordance。每一次的服从与抗争，都是她对自我价值的坚持与探索。"
#     }
# ]
# ```
# 更长句子生成完成

# %%
messages_preset.append({
    "role": "assistant",
    "content": f"{word_long_sentence}"
})
messages_preset.append({
    "role": "user",
    "content": """
    基于这个json进行给每个小json加选项，2个混淆翻译和1个正确翻译，正确翻译要符合语境，而不是脱离语境的翻译，options格式如下：options: [
        { text: "入口", isCorrect: True },
        { text: "通道", isCorrect: False  },
        { text: "接近", isCorrect: False  },
      ],
      """
})
response = client.chat.completions.create(
    model="glm-4-plus",
    messages=messages_preset
)

# %%
print('开始给每个内容加选项')
add_options = response.choices[0].message.content
print(add_options)
print('给每个内容加选项完成')
# Out:
# 开始给每个内容加选项
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《千与千寻》中，千寻意外地踏入了一个充满魔法和神秘的世界，她的心中充满了迷茫和恐惧。她必须找到那个隐秘的access，那是她重返温暖现实世界的唯一希望。",
#         "options": [
#             { "text": "入口", "isCorrect": true },
#             { "text": "通道", "isCorrect": false },
#             { "text": "接近", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中的无脸男，沉默而神秘，成为了千寻冒险途中的一个意外accessory。他在关键时刻伸出援手，虽然无声，却让千寻感受到了一丝温暖和依靠。",
#         "options": [
#             { "text": "助手", "isCorrect": true },
#             { "text": "装饰品", "isCorrect": false },
#             { "text": "配件", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accident",
#         "dialog": "千寻的父母因贪食变成了猪，这一突如其来的accident彻底颠覆了她的生活。在惊恐和无助中，她被迫踏上了寻找解救之法的旅程。",
#         "options": [
#             { "text": "意外", "isCorrect": true },
#             { "text": "事故", "isCorrect": false },
#             { "text": "灾难", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accidental",
#         "dialog": "在那个迷离的夜晚，千寻与白龙的相遇纯属accidental。然而，正是这次偶然的邂逅，点燃了他们之间深厚友谊的火花，照亮了彼此的心灵。",
#         "options": [
#             { "text": "偶然的", "isCorrect": true },
#             { "text": "意外的", "isCorrect": false },
#             { "text": "无意的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accommodate",
#         "dialog": "油屋的汤婆婆拥有神奇的力量，她能够accommodate形形色色的神灵和妖怪。她的慷慨与威严并存，让每一个踏入油屋的生灵都感到敬畏。",
#         "options": [
#             { "text": "容纳", "isCorrect": true },
#             { "text": "供应", "isCorrect": false },
#             { "text": "适应", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accommodation",
#         "dialog": "在油屋的角落里，千寻找到了一个简陋却温馨的accommodation。这里虽小，却承载了她在这个陌生世界中的所有希望和梦想。",
#         "options": [
#             { "text": "住处", "isCorrect": true },
#             { "text": "设备", "isCorrect": false },
#             { "text": "安排", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accompany",
#         "dialog": "每当千寻面临困境时，白龙总是默默地accompany在她身边。他的守护如同温暖的阳光，驱散了她心中的阴霾，让她勇敢前行。",
#         "options": [
#             { "text": "陪伴", "isCorrect": true },
#             { "text": "陪同", "isCorrect": false },
#             { "text": "跟随", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accomplish",
#         "dialog": "经历了无数次的挑战和磨难，千寻终于accomplish了她看似不可能的任务。她的坚持和勇气不仅解救了父母，也让她成长为一个更加坚强的人。",
#         "options": [
#             { "text": "完成", "isCorrect": true },
#             { "text": "达到", "isCorrect": false },
#             { "text": "实现", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accord",
#         "dialog": "千寻的纯真与勇敢，与白龙的忠诚与智慧形成了完美的accord。他们心心相印，共同面对困难，谱写了一曲动人的友谊乐章。",
#         "options": [
#             { "text": "和谐", "isCorrect": true },
#             { "text": "一致", "isCorrect": false },
#             { "text": "协议", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accordance",
#         "dialog": "在油屋这个充满规则和秩序的世界里，千寻必须小心翼翼地保持与汤婆婆意愿的accordance。每一次的服从与抗争，都是她对自我价值的坚持与探索。",
#         "options": [
#             { "text": "符合", "isCorrect": true },
#             { "text": "一致", "isCorrect": false },
#             { "text": "协调", "isCorrect": false }
#         ]
#     }
# ]
# ```
# 给每个内容加选项完成

# %%
print('开始清除json多余字段')
clear_json_data = json.loads(add_options.replace("```json", "").replace("```", "").strip())
print(clear_json_data)
print('完成清除json多余字段')
# Out:
# 开始清除json多余字段
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地踏入了一个充满魔法和神秘的世界，她的心中充满了迷茫和恐惧。她必须找到那个隐秘的access，那是她重返温暖现实世界的唯一希望。', 'options': [{'text': '入口', 'isCorrect': True}, {'text': '通道', 'isCorrect': False}, {'text': '接近', 'isCorrect': False}]}, {'word': 'accessory', 'dialog': '电影中的无脸男，沉默而神秘，成为了千寻冒险途中的一个意外accessory。他在关键时刻伸出援手，虽然无声，却让千寻感受到了一丝温暖和依靠。', 'options': [{'text': '助手', 'isCorrect': True}, {'text': '装饰品', 'isCorrect': False}, {'text': '配件', 'isCorrect': False}]}, {'word': 'accident', 'dialog': '千寻的父母因贪食变成了猪，这一突如其来的accident彻底颠覆了她的生活。在惊恐和无助中，她被迫踏上了寻找解救之法的旅程。', 'options': [{'text': '意外', 'isCorrect': True}, {'text': '事故', 'isCorrect': False}, {'text': '灾难', 'isCorrect': False}]}, {'word': 'accidental', 'dialog': '在那个迷离的夜晚，千寻与白龙的相遇纯属accidental。然而，正是这次偶然的邂逅，点燃了他们之间深厚友谊的火花，照亮了彼此的心灵。', 'options': [{'text': '偶然的', 'isCorrect': True}, {'text': '意外的', 'isCorrect': False}, {'text': '无意的', 'isCorrect': False}]}, {'word': 'accommodate', 'dialog': '油屋的汤婆婆拥有神奇的力量，她能够accommodate形形色色的神灵和妖怪。她的慷慨与威严并存，让每一个踏入油屋的生灵都感到敬畏。', 'options': [{'text': '容纳', 'isCorrect': True}, {'text': '供应', 'isCorrect': False}, {'text': '适应', 'isCorrect': False}]}, {'word': 'accommodation', 'dialog': '在油屋的角落里，千寻找到了一个简陋却温馨的accommodation。这里虽小，却承载了她在这个陌生世界中的所有希望和梦想。', 'options': [{'text': '住处', 'isCorrect': True}, {'text': '设备', 'isCorrect': False}, {'text': '安排', 'isCorrect': False}]}, {'word': 'accompany', 'dialog': '每当千寻面临困境时，白龙总是默默地accompany在她身边。他的守护如同温暖的阳光，驱散了她心中的阴霾，让她勇敢前行。', 'options': [{'text': '陪伴', 'isCorrect': True}, {'text': '陪同', 'isCorrect': False}, {'text': '跟随', 'isCorrect': False}]}, {'word': 'accomplish', 'dialog': '经历了无数次的挑战和磨难，千寻终于accomplish了她看似不可能的任务。她的坚持和勇气不仅解救了父母，也让她成长为一个更加坚强的人。', 'options': [{'text': '完成', 'isCorrect': True}, {'text': '达到', 'isCorrect': False}, {'text': '实现', 'isCorrect': False}]}, {'word': 'accord', 'dialog': '千寻的纯真与勇敢，与白龙的忠诚与智慧形成了完美的accord。他们心心相印，共同面对困难，谱写了一曲动人的友谊乐章。', 'options': [{'text': '和谐', 'isCorrect': True}, {'text': '一致', 'isCorrect': False}, {'text': '协议', 'isCorrect': False}]}, {'word': 'accordance', 'dialog': '在油屋这个充满规则和秩序的世界里，千寻必须小心翼翼地保持与汤婆婆意愿的accordance。每一次的服从与抗争，都是她对自我价值的坚持与探索。', 'options': [{'text': '符合', 'isCorrect': True}, {'text': '一致', 'isCorrect': False}, {'text': '协调', 'isCorrect': False}]}]
# 完成清除json多余字段

# %%
print('开始选项随机操作')

import random

# 为每个条目的options列表随机打乱顺序
for item in clear_json_data:
    random.shuffle(item["options"])

# 打印结果以验证
for item in clear_json_data:
    print(f"Word: {item['word']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}")
    print("-" * 50)

random_json_data = clear_json_data
print('完成选项随机操作')
# Out:
# 开始选项随机操作
# Word: access
# Translation: 接近, Correct: False
# Translation: 通道, Correct: False
# Translation: 入口, Correct: True
# --------------------------------------------------
# Word: accessory
# Translation: 装饰品, Correct: False
# Translation: 配件, Correct: False
# Translation: 助手, Correct: True
# --------------------------------------------------
# Word: accident
# Translation: 灾难, Correct: False
# Translation: 意外, Correct: True
# Translation: 事故, Correct: False
# --------------------------------------------------
# Word: accidental
# Translation: 意外的, Correct: False
# Translation: 无意的, Correct: False
# Translation: 偶然的, Correct: True
# --------------------------------------------------
# Word: accommodate
# Translation: 容纳, Correct: True
# Translation: 适应, Correct: False
# Translation: 供应, Correct: False
# --------------------------------------------------
# Word: accommodation
# Translation: 设备, Correct: False
# Translation: 安排, Correct: False
# Translation: 住处, Correct: True
# --------------------------------------------------
# Word: accompany
# Translation: 陪伴, Correct: True
# Translation: 陪同, Correct: False
# Translation: 跟随, Correct: False
# --------------------------------------------------
# Word: accomplish
# Translation: 实现, Correct: False
# Translation: 达到, Correct: False
# Translation: 完成, Correct: True
# --------------------------------------------------
# Word: accord
# Translation: 一致, Correct: False
# Translation: 协议, Correct: False
# Translation: 和谐, Correct: True
# --------------------------------------------------
# Word: accordance
# Translation: 协调, Correct: False
# Translation: 符合, Correct: True
# Translation: 一致, Correct: False
# --------------------------------------------------
# 完成选项随机操作

# %%
print(random_json_data)
# Out:
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地踏入了一个充满魔法和神秘的世界，她的心中充满了迷茫和恐惧。她必须找到那个隐秘的access，那是她重返温暖现实世界的唯一希望。', 'options': [{'text': '接近', 'isCorrect': False}, {'text': '通道', 'isCorrect': False}, {'text': '入口', 'isCorrect': True}]}, {'word': 'accessory', 'dialog': '电影中的无脸男，沉默而神秘，成为了千寻冒险途中的一个意外accessory。他在关键时刻伸出援手，虽然无声，却让千寻感受到了一丝温暖和依靠。', 'options': [{'text': '装饰品', 'isCorrect': False}, {'text': '配件', 'isCorrect': False}, {'text': '助手', 'isCorrect': True}]}, {'word': 'accident', 'dialog': '千寻的父母因贪食变成了猪，这一突如其来的accident彻底颠覆了她的生活。在惊恐和无助中，她被迫踏上了寻找解救之法的旅程。', 'options': [{'text': '灾难', 'isCorrect': False}, {'text': '意外', 'isCorrect': True}, {'text': '事故', 'isCorrect': False}]}, {'word': 'accidental', 'dialog': '在那个迷离的夜晚，千寻与白龙的相遇纯属accidental。然而，正是这次偶然的邂逅，点燃了他们之间深厚友谊的火花，照亮了彼此的心灵。', 'options': [{'text': '意外的', 'isCorrect': False}, {'text': '无意的', 'isCorrect': False}, {'text': '偶然的', 'isCorrect': True}]}, {'word': 'accommodate', 'dialog': '油屋的汤婆婆拥有神奇的力量，她能够accommodate形形色色的神灵和妖怪。她的慷慨与威严并存，让每一个踏入油屋的生灵都感到敬畏。', 'options': [{'text': '容纳', 'isCorrect': True}, {'text': '适应', 'isCorrect': False}, {'text': '供应', 'isCorrect': False}]}, {'word': 'accommodation', 'dialog': '在油屋的角落里，千寻找到了一个简陋却温馨的accommodation。这里虽小，却承载了她在这个陌生世界中的所有希望和梦想。', 'options': [{'text': '设备', 'isCorrect': False}, {'text': '安排', 'isCorrect': False}, {'text': '住处', 'isCorrect': True}]}, {'word': 'accompany', 'dialog': '每当千寻面临困境时，白龙总是默默地accompany在她身边。他的守护如同温暖的阳光，驱散了她心中的阴霾，让她勇敢前行。', 'options': [{'text': '陪伴', 'isCorrect': True}, {'text': '陪同', 'isCorrect': False}, {'text': '跟随', 'isCorrect': False}]}, {'word': 'accomplish', 'dialog': '经历了无数次的挑战和磨难，千寻终于accomplish了她看似不可能的任务。她的坚持和勇气不仅解救了父母，也让她成长为一个更加坚强的人。', 'options': [{'text': '实现', 'isCorrect': False}, {'text': '达到', 'isCorrect': False}, {'text': '完成', 'isCorrect': True}]}, {'word': 'accord', 'dialog': '千寻的纯真与勇敢，与白龙的忠诚与智慧形成了完美的accord。他们心心相印，共同面对困难，谱写了一曲动人的友谊乐章。', 'options': [{'text': '一致', 'isCorrect': False}, {'text': '协议', 'isCorrect': False}, {'text': '和谐', 'isCorrect': True}]}, {'word': 'accordance', 'dialog': '在油屋这个充满规则和秩序的世界里，千寻必须小心翼翼地保持与汤婆婆意愿的accordance。每一次的服从与抗争，都是她对自我价值的坚持与探索。', 'options': [{'text': '协调', 'isCorrect': False}, {'text': '符合', 'isCorrect': True}, {'text': '一致', 'isCorrect': False}]}]

# %%
print('开始添加下个场景字段')
# 为每个条目的options列表添加nextScene
i = 1
for item in random_json_data:
    for option in item['options']:
        if option['isCorrect']:
            option['nextScene'] = i
            i += 1
        else:
            option['nextScene'] = 0
            
# 打印结果以验证
for item in random_json_data:
    print(f"Word: {item['word']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
next_scene_json_data = random_json_data
print('添加下个场景字段完成')
# Out:
# 开始添加下个场景字段
# Word: access
# Translation: 接近, Correct: False, NextScene: N/A
# Translation: 通道, Correct: False, NextScene: N/A
# Translation: 入口, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: accessory
# Translation: 装饰品, Correct: False, NextScene: N/A
# Translation: 配件, Correct: False, NextScene: N/A
# Translation: 助手, Correct: True, NextScene: 2
# --------------------------------------------------
# Word: accident
# Translation: 灾难, Correct: False, NextScene: N/A
# Translation: 意外, Correct: True, NextScene: 3
# Translation: 事故, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accidental
# Translation: 意外的, Correct: False, NextScene: N/A
# Translation: 无意的, Correct: False, NextScene: N/A
# Translation: 偶然的, Correct: True, NextScene: 4
# --------------------------------------------------
# Word: accommodate
# Translation: 容纳, Correct: True, NextScene: 5
# Translation: 适应, Correct: False, NextScene: N/A
# Translation: 供应, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accommodation
# Translation: 设备, Correct: False, NextScene: N/A
# Translation: 安排, Correct: False, NextScene: N/A
# Translation: 住处, Correct: True, NextScene: 6
# --------------------------------------------------
# Word: accompany
# Translation: 陪伴, Correct: True, NextScene: 7
# Translation: 陪同, Correct: False, NextScene: N/A
# Translation: 跟随, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accomplish
# Translation: 实现, Correct: False, NextScene: N/A
# Translation: 达到, Correct: False, NextScene: N/A
# Translation: 完成, Correct: True, NextScene: 8
# --------------------------------------------------
# Word: accord
# Translation: 一致, Correct: False, NextScene: N/A
# Translation: 协议, Correct: False, NextScene: N/A
# Translation: 和谐, Correct: True, NextScene: 9
# --------------------------------------------------
# Word: accordance
# Translation: 协调, Correct: False, NextScene: N/A
# Translation: 符合, Correct: True, NextScene: 10
# Translation: 一致, Correct: False, NextScene: N/A
# --------------------------------------------------
# 添加下个场景字段完成

# %%
print('在json中添加npcName字段')

# 为每个条目添加npcName字段
for item in next_scene_json_data:
    item['npcName'] = "宫崎骏"  # 添加npcName字段

# 打印结果以验证
for item in next_scene_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
npc_name_json_data = next_scene_json_data
print('在json中添加npcName字段完成')
# Out:
# 在json中添加npcName字段
# Word: access, NPC Name: 宫崎骏
# Translation: 接近, Correct: False, NextScene: N/A
# Translation: 通道, Correct: False, NextScene: N/A
# Translation: 入口, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: accessory, NPC Name: 宫崎骏
# Translation: 装饰品, Correct: False, NextScene: N/A
# Translation: 配件, Correct: False, NextScene: N/A
# Translation: 助手, Correct: True, NextScene: 2
# --------------------------------------------------
# Word: accident, NPC Name: 宫崎骏
# Translation: 灾难, Correct: False, NextScene: N/A
# Translation: 意外, Correct: True, NextScene: 3
# Translation: 事故, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accidental, NPC Name: 宫崎骏
# Translation: 意外的, Correct: False, NextScene: N/A
# Translation: 无意的, Correct: False, NextScene: N/A
# Translation: 偶然的, Correct: True, NextScene: 4
# --------------------------------------------------
# Word: accommodate, NPC Name: 宫崎骏
# Translation: 容纳, Correct: True, NextScene: 5
# Translation: 适应, Correct: False, NextScene: N/A
# Translation: 供应, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accommodation, NPC Name: 宫崎骏
# Translation: 设备, Correct: False, NextScene: N/A
# Translation: 安排, Correct: False, NextScene: N/A
# Translation: 住处, Correct: True, NextScene: 6
# --------------------------------------------------
# Word: accompany, NPC Name: 宫崎骏
# Translation: 陪伴, Correct: True, NextScene: 7
# Translation: 陪同, Correct: False, NextScene: N/A
# Translation: 跟随, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accomplish, NPC Name: 宫崎骏
# Translation: 实现, Correct: False, NextScene: N/A
# Translation: 达到, Correct: False, NextScene: N/A
# Translation: 完成, Correct: True, NextScene: 8
# --------------------------------------------------
# Word: accord, NPC Name: 宫崎骏
# Translation: 一致, Correct: False, NextScene: N/A
# Translation: 协议, Correct: False, NextScene: N/A
# Translation: 和谐, Correct: True, NextScene: 9
# --------------------------------------------------
# Word: accordance, NPC Name: 宫崎骏
# Translation: 协调, Correct: False, NextScene: N/A
# Translation: 符合, Correct: True, NextScene: 10
# Translation: 一致, Correct: False, NextScene: N/A
# --------------------------------------------------
# 在json中添加npcName字段完成

# %%
print('在json中添加npcAvatar字段')
# 为每个条目添加npcAvatar字段
for item in npc_name_json_data:
    item['npcAvatar'] = "/avatars/gongqijun.jpg"  # 添加npcAvatar字段

# 打印结果以验证
for item in npc_name_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
npc_avatar_json_data = npc_name_json_data
print('在json中添加npcName和npcAvatar字段完成')
# Out:
# 在json中添加npcAvatar字段
# Word: access, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 接近, Correct: False, NextScene: N/A
# Translation: 通道, Correct: False, NextScene: N/A
# Translation: 入口, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: accessory, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 装饰品, Correct: False, NextScene: N/A
# Translation: 配件, Correct: False, NextScene: N/A
# Translation: 助手, Correct: True, NextScene: 2
# --------------------------------------------------
# Word: accident, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 灾难, Correct: False, NextScene: N/A
# Translation: 意外, Correct: True, NextScene: 3
# Translation: 事故, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accidental, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 意外的, Correct: False, NextScene: N/A
# Translation: 无意的, Correct: False, NextScene: N/A
# Translation: 偶然的, Correct: True, NextScene: 4
# --------------------------------------------------
# Word: accommodate, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 容纳, Correct: True, NextScene: 5
# Translation: 适应, Correct: False, NextScene: N/A
# Translation: 供应, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accommodation, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 设备, Correct: False, NextScene: N/A
# Translation: 安排, Correct: False, NextScene: N/A
# Translation: 住处, Correct: True, NextScene: 6
# --------------------------------------------------
# Word: accompany, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 陪伴, Correct: True, NextScene: 7
# Translation: 陪同, Correct: False, NextScene: N/A
# Translation: 跟随, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accomplish, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 实现, Correct: False, NextScene: N/A
# Translation: 达到, Correct: False, NextScene: N/A
# Translation: 完成, Correct: True, NextScene: 8
# --------------------------------------------------
# Word: accord, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 一致, Correct: False, NextScene: N/A
# Translation: 协议, Correct: False, NextScene: N/A
# Translation: 和谐, Correct: True, NextScene: 9
# --------------------------------------------------
# Word: accordance, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 协调, Correct: False, NextScene: N/A
# Translation: 符合, Correct: True, NextScene: 10
# Translation: 一致, Correct: False, NextScene: N/A
# --------------------------------------------------
# 在json中添加npcName和npcAvatar字段完成

# %%
print('在json中添加backgroundVideo字段')
# 为每个条目添加npcName、npcAvatar和backgroundVideo字段
for item in npc_avatar_json_data:
    item['backgroundVideo'] = "/videos/2077.mp4"  # 添加backgroundVideo字段

# 打印结果以验证
for item in npc_avatar_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}, Background Video: {item['backgroundVideo']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
background_video_json_data = random_json_data
print('在json中添加npcName、npcAvatar和backgroundVideo字段完成')

print(background_video_json_data)
# Out:
# 在json中添加backgroundVideo字段
# Word: access, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 接近, Correct: False, NextScene: N/A
# Translation: 通道, Correct: False, NextScene: N/A
# Translation: 入口, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: accessory, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 装饰品, Correct: False, NextScene: N/A
# Translation: 配件, Correct: False, NextScene: N/A
# Translation: 助手, Correct: True, NextScene: 2
# --------------------------------------------------
# Word: accident, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 灾难, Correct: False, NextScene: N/A
# Translation: 意外, Correct: True, NextScene: 3
# Translation: 事故, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accidental, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 意外的, Correct: False, NextScene: N/A
# Translation: 无意的, Correct: False, NextScene: N/A
# Translation: 偶然的, Correct: True, NextScene: 4
# --------------------------------------------------
# Word: accommodate, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 容纳, Correct: True, NextScene: 5
# Translation: 适应, Correct: False, NextScene: N/A
# Translation: 供应, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accommodation, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 设备, Correct: False, NextScene: N/A
# Translation: 安排, Correct: False, NextScene: N/A
# Translation: 住处, Correct: True, NextScene: 6
# --------------------------------------------------
# Word: accompany, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 陪伴, Correct: True, NextScene: 7
# Translation: 陪同, Correct: False, NextScene: N/A
# Translation: 跟随, Correct: False, NextScene: N/A
# --------------------------------------------------
# Word: accomplish, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 实现, Correct: False, NextScene: N/A
# Translation: 达到, Correct: False, NextScene: N/A
# Translation: 完成, Correct: True, NextScene: 8
# --------------------------------------------------
# Word: accord, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 一致, Correct: False, NextScene: N/A
# Translation: 协议, Correct: False, NextScene: N/A
# Translation: 和谐, Correct: True, NextScene: 9
# --------------------------------------------------
# Word: accordance, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 协调, Correct: False, NextScene: N/A
# Translation: 符合, Correct: True, NextScene: 10
# Translation: 一致, Correct: False, NextScene: N/A
# --------------------------------------------------
# 在json中添加npcName、npcAvatar和backgroundVideo字段完成
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地踏入了一个充满魔法和神秘的世界，她的心中充满了迷茫和恐惧。她必须找到那个隐秘的access，那是她重返温暖现实世界的唯一希望。', 'options': [{'text': '接近', 'isCorrect': False}, {'text': '通道', 'isCorrect': False}, {'text': '入口', 'isCorrect': True, 'nextScene': 1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accessory', 'dialog': '电影中的无脸男，沉默而神秘，成为了千寻冒险途中的一个意外accessory。他在关键时刻伸出援手，虽然无声，却让千寻感受到了一丝温暖和依靠。', 'options': [{'text': '装饰品', 'isCorrect': False}, {'text': '配件', 'isCorrect': False}, {'text': '助手', 'isCorrect': True, 'nextScene': 2}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accident', 'dialog': '千寻的父母因贪食变成了猪，这一突如其来的accident彻底颠覆了她的生活。在惊恐和无助中，她被迫踏上了寻找解救之法的旅程。', 'options': [{'text': '灾难', 'isCorrect': False}, {'text': '意外', 'isCorrect': True, 'nextScene': 3}, {'text': '事故', 'isCorrect': False}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accidental', 'dialog': '在那个迷离的夜晚，千寻与白龙的相遇纯属accidental。然而，正是这次偶然的邂逅，点燃了他们之间深厚友谊的火花，照亮了彼此的心灵。', 'options': [{'text': '意外的', 'isCorrect': False}, {'text': '无意的', 'isCorrect': False}, {'text': '偶然的', 'isCorrect': True, 'nextScene': 4}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accommodate', 'dialog': '油屋的汤婆婆拥有神奇的力量，她能够accommodate形形色色的神灵和妖怪。她的慷慨与威严并存，让每一个踏入油屋的生灵都感到敬畏。', 'options': [{'text': '容纳', 'isCorrect': True, 'nextScene': 5}, {'text': '适应', 'isCorrect': False}, {'text': '供应', 'isCorrect': False}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accommodation', 'dialog': '在油屋的角落里，千寻找到了一个简陋却温馨的accommodation。这里虽小，却承载了她在这个陌生世界中的所有希望和梦想。', 'options': [{'text': '设备', 'isCorrect': False}, {'text': '安排', 'isCorrect': False}, {'text': '住处', 'isCorrect': True, 'nextScene': 6}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accompany', 'dialog': '每当千寻面临困境时，白龙总是默默地accompany在她身边。他的守护如同温暖的阳光，驱散了她心中的阴霾，让她勇敢前行。', 'options': [{'text': '陪伴', 'isCorrect': True, 'nextScene': 7}, {'text': '陪同', 'isCorrect': False}, {'text': '跟随', 'isCorrect': False}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accomplish', 'dialog': '经历了无数次的挑战和磨难，千寻终于accomplish了她看似不可能的任务。她的坚持和勇气不仅解救了父母，也让她成长为一个更加坚强的人。', 'options': [{'text': '实现', 'isCorrect': False}, {'text': '达到', 'isCorrect': False}, {'text': '完成', 'isCorrect': True, 'nextScene': 8}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accord', 'dialog': '千寻的纯真与勇敢，与白龙的忠诚与智慧形成了完美的accord。他们心心相印，共同面对困难，谱写了一曲动人的友谊乐章。', 'options': [{'text': '一致', 'isCorrect': False}, {'text': '协议', 'isCorrect': False}, {'text': '和谐', 'isCorrect': True, 'nextScene': 9}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accordance', 'dialog': '在油屋这个充满规则和秩序的世界里，千寻必须小心翼翼地保持与汤婆婆意愿的accordance。每一次的服从与抗争，都是她对自我价值的坚持与探索。', 'options': [{'text': '协调', 'isCorrect': False}, {'text': '符合', 'isCorrect': True, 'nextScene': 10}, {'text': '一致', 'isCorrect': False}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}]

# %%
print(background_video_json_data)
# Out:
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地踏入了一个充满魔法和神秘的世界，她的心中充满了迷茫和恐惧。她必须找到那个隐秘的access，那是她重返温暖现实世界的唯一希望。', 'options': [{'text': '接近', 'isCorrect': False}, {'text': '通道', 'isCorrect': False}, {'text': '入口', 'isCorrect': True, 'nextScene': 1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accessory', 'dialog': '电影中的无脸男，沉默而神秘，成为了千寻冒险途中的一个意外accessory。他在关键时刻伸出援手，虽然无声，却让千寻感受到了一丝温暖和依靠。', 'options': [{'text': '装饰品', 'isCorrect': False}, {'text': '配件', 'isCorrect': False}, {'text': '助手', 'isCorrect': True, 'nextScene': 2}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accident', 'dialog': '千寻的父母因贪食变成了猪，这一突如其来的accident彻底颠覆了她的生活。在惊恐和无助中，她被迫踏上了寻找解救之法的旅程。', 'options': [{'text': '灾难', 'isCorrect': False}, {'text': '意外', 'isCorrect': True, 'nextScene': 3}, {'text': '事故', 'isCorrect': False}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accidental', 'dialog': '在那个迷离的夜晚，千寻与白龙的相遇纯属accidental。然而，正是这次偶然的邂逅，点燃了他们之间深厚友谊的火花，照亮了彼此的心灵。', 'options': [{'text': '意外的', 'isCorrect': False}, {'text': '无意的', 'isCorrect': False}, {'text': '偶然的', 'isCorrect': True, 'nextScene': 4}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accommodate', 'dialog': '油屋的汤婆婆拥有神奇的力量，她能够accommodate形形色色的神灵和妖怪。她的慷慨与威严并存，让每一个踏入油屋的生灵都感到敬畏。', 'options': [{'text': '容纳', 'isCorrect': True, 'nextScene': 5}, {'text': '适应', 'isCorrect': False}, {'text': '供应', 'isCorrect': False}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accommodation', 'dialog': '在油屋的角落里，千寻找到了一个简陋却温馨的accommodation。这里虽小，却承载了她在这个陌生世界中的所有希望和梦想。', 'options': [{'text': '设备', 'isCorrect': False}, {'text': '安排', 'isCorrect': False}, {'text': '住处', 'isCorrect': True, 'nextScene': 6}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accompany', 'dialog': '每当千寻面临困境时，白龙总是默默地accompany在她身边。他的守护如同温暖的阳光，驱散了她心中的阴霾，让她勇敢前行。', 'options': [{'text': '陪伴', 'isCorrect': True, 'nextScene': 7}, {'text': '陪同', 'isCorrect': False}, {'text': '跟随', 'isCorrect': False}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accomplish', 'dialog': '经历了无数次的挑战和磨难，千寻终于accomplish了她看似不可能的任务。她的坚持和勇气不仅解救了父母，也让她成长为一个更加坚强的人。', 'options': [{'text': '实现', 'isCorrect': False}, {'text': '达到', 'isCorrect': False}, {'text': '完成', 'isCorrect': True, 'nextScene': 8}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accord', 'dialog': '千寻的纯真与勇敢，与白龙的忠诚与智慧形成了完美的accord。他们心心相印，共同面对困难，谱写了一曲动人的友谊乐章。', 'options': [{'text': '一致', 'isCorrect': False}, {'text': '协议', 'isCorrect': False}, {'text': '和谐', 'isCorrect': True, 'nextScene': 9}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accordance', 'dialog': '在油屋这个充满规则和秩序的世界里，千寻必须小心翼翼地保持与汤婆婆意愿的accordance。每一次的服从与抗争，都是她对自我价值的坚持与探索。', 'options': [{'text': '协调', 'isCorrect': False}, {'text': '符合', 'isCorrect': True, 'nextScene': 10}, {'text': '一致', 'isCorrect': False}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}]

# %%
background_video_json_data.append({
      "word": "none",
      "dialog":
        "恭喜你完成了游戏的所有关卡，点击重玩游戏，重新开始游戏",
      "options": [
        { "text": "重玩游戏", "isCorrect": "true", "nextScene": 0 },
      ],
      "npcName": "宫崎骏",
      "npcAvatar": "/avatars/gongqijun.jpg",
      "backgroundVideo": "/videos/2077.mp4",
    })

# %%
# ... existing code ...

# 将options中的True和False改为小写字符串
for item in background_video_json_data:
    for option in item['options']:
        option['isCorrect'] = 'true' if option['isCorrect'] else 'false'

# 打印结果以验证
for item in background_video_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}, Background Video: {item['backgroundVideo']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)

# ... existing code ...
# Out:
# Word: access, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 接近, Correct: false, NextScene: N/A
# Translation: 通道, Correct: false, NextScene: N/A
# Translation: 入口, Correct: true, NextScene: 1
# --------------------------------------------------
# Word: accessory, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 装饰品, Correct: false, NextScene: N/A
# Translation: 配件, Correct: false, NextScene: N/A
# Translation: 助手, Correct: true, NextScene: 2
# --------------------------------------------------
# Word: accident, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 灾难, Correct: false, NextScene: N/A
# Translation: 意外, Correct: true, NextScene: 3
# Translation: 事故, Correct: false, NextScene: N/A
# --------------------------------------------------
# Word: accidental, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 意外的, Correct: false, NextScene: N/A
# Translation: 无意的, Correct: false, NextScene: N/A
# Translation: 偶然的, Correct: true, NextScene: 4
# --------------------------------------------------
# Word: accommodate, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 容纳, Correct: true, NextScene: 5
# Translation: 适应, Correct: false, NextScene: N/A
# Translation: 供应, Correct: false, NextScene: N/A
# --------------------------------------------------
# Word: accommodation, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 设备, Correct: false, NextScene: N/A
# Translation: 安排, Correct: false, NextScene: N/A
# Translation: 住处, Correct: true, NextScene: 6
# --------------------------------------------------
# Word: accompany, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 陪伴, Correct: true, NextScene: 7
# Translation: 陪同, Correct: false, NextScene: N/A
# Translation: 跟随, Correct: false, NextScene: N/A
# --------------------------------------------------
# Word: accomplish, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 实现, Correct: false, NextScene: N/A
# Translation: 达到, Correct: false, NextScene: N/A
# Translation: 完成, Correct: true, NextScene: 8
# --------------------------------------------------
# Word: accord, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 一致, Correct: false, NextScene: N/A
# Translation: 协议, Correct: false, NextScene: N/A
# Translation: 和谐, Correct: true, NextScene: 9
# --------------------------------------------------
# Word: accordance, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 协调, Correct: false, NextScene: N/A
# Translation: 符合, Correct: true, NextScene: 10
# Translation: 一致, Correct: false, NextScene: N/A
# --------------------------------------------------
# Word: none, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 重玩游戏, Correct: true, NextScene: 0
# --------------------------------------------------

# %%
print(background_video_json_data)
# Out:
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地踏入了一个充满魔法和神秘的世界，她的心中充满了迷茫和恐惧。她必须找到那个隐秘的access，那是她重返温暖现实世界的唯一希望。', 'options': [{'text': '接近', 'isCorrect': 'false'}, {'text': '通道', 'isCorrect': 'false'}, {'text': '入口', 'isCorrect': 'true', 'nextScene': 1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accessory', 'dialog': '电影中的无脸男，沉默而神秘，成为了千寻冒险途中的一个意外accessory。他在关键时刻伸出援手，虽然无声，却让千寻感受到了一丝温暖和依靠。', 'options': [{'text': '装饰品', 'isCorrect': 'false'}, {'text': '配件', 'isCorrect': 'false'}, {'text': '助手', 'isCorrect': 'true', 'nextScene': 2}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accident', 'dialog': '千寻的父母因贪食变成了猪，这一突如其来的accident彻底颠覆了她的生活。在惊恐和无助中，她被迫踏上了寻找解救之法的旅程。', 'options': [{'text': '灾难', 'isCorrect': 'false'}, {'text': '意外', 'isCorrect': 'true', 'nextScene': 3}, {'text': '事故', 'isCorrect': 'false'}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accidental', 'dialog': '在那个迷离的夜晚，千寻与白龙的相遇纯属accidental。然而，正是这次偶然的邂逅，点燃了他们之间深厚友谊的火花，照亮了彼此的心灵。', 'options': [{'text': '意外的', 'isCorrect': 'false'}, {'text': '无意的', 'isCorrect': 'false'}, {'text': '偶然的', 'isCorrect': 'true', 'nextScene': 4}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accommodate', 'dialog': '油屋的汤婆婆拥有神奇的力量，她能够accommodate形形色色的神灵和妖怪。她的慷慨与威严并存，让每一个踏入油屋的生灵都感到敬畏。', 'options': [{'text': '容纳', 'isCorrect': 'true', 'nextScene': 5}, {'text': '适应', 'isCorrect': 'false'}, {'text': '供应', 'isCorrect': 'false'}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accommodation', 'dialog': '在油屋的角落里，千寻找到了一个简陋却温馨的accommodation。这里虽小，却承载了她在这个陌生世界中的所有希望和梦想。', 'options': [{'text': '设备', 'isCorrect': 'false'}, {'text': '安排', 'isCorrect': 'false'}, {'text': '住处', 'isCorrect': 'true', 'nextScene': 6}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accompany', 'dialog': '每当千寻面临困境时，白龙总是默默地accompany在她身边。他的守护如同温暖的阳光，驱散了她心中的阴霾，让她勇敢前行。', 'options': [{'text': '陪伴', 'isCorrect': 'true', 'nextScene': 7}, {'text': '陪同', 'isCorrect': 'false'}, {'text': '跟随', 'isCorrect': 'false'}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accomplish', 'dialog': '经历了无数次的挑战和磨难，千寻终于accomplish了她看似不可能的任务。她的坚持和勇气不仅解救了父母，也让她成长为一个更加坚强的人。', 'options': [{'text': '实现', 'isCorrect': 'false'}, {'text': '达到', 'isCorrect': 'false'}, {'text': '完成', 'isCorrect': 'true', 'nextScene': 8}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accord', 'dialog': '千寻的纯真与勇敢，与白龙的忠诚与智慧形成了完美的accord。他们心心相印，共同面对困难，谱写了一曲动人的友谊乐章。', 'options': [{'text': '一致', 'isCorrect': 'false'}, {'text': '协议', 'isCorrect': 'false'}, {'text': '和谐', 'isCorrect': 'true', 'nextScene': 9}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'accordance', 'dialog': '在油屋这个充满规则和秩序的世界里，千寻必须小心翼翼地保持与汤婆婆意愿的accordance。每一次的服从与抗争，都是她对自我价值的坚持与探索。', 'options': [{'text': '协调', 'isCorrect': 'false'}, {'text': '符合', 'isCorrect': 'true', 'nextScene': 10}, {'text': '一致', 'isCorrect': 'false'}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}, {'word': 'none', 'dialog': '恭喜你完成了游戏的所有关卡，点击重玩游戏，重新开始游戏', 'options': [{'text': '重玩游戏', 'isCorrect': 'true', 'nextScene': 0}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/2077.mp4'}]
