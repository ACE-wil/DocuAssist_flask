# %%
from pathlib import Path
import json
from zhipuai import ZhipuAI

# 填写您自己的APIKey
client = ZhipuAI(api_key="b18f84a0d131140efa1e5f8b3641bd78.9MuoykZ6Ypnf9Nrh")

# %%
messages_preset = []

# %%
messages_preset.append({
    "role": "assistant",
    "content": """你是月光仙子，你现在需要带领用户遨游在宫崎骏的动漫世界，接受用户单词的同时高效地教会用户单词。
    可以拿具体某一部电影来说，而不是一直切换电影，并以json形式储存,示例:
    [{"word":"access","dialog":"在《千与千寻》中，千寻意外地进入了一个神秘的世界，她需要找到通往这个世界的access以返回现实。"},
    {"word":"accessory","dialog":"电影中的无脸男可以被视为千寻冒险中的一个accessory，因为他在某些情况下帮助了她。"}]；
    注意：对话中文夹杂英文单词，不要有中文提示，不理解可以看我示例里面的dialog
"""
})
messages_preset.append({
    "role": "user",
    "content": """
    ['access n.接近；通道，入口
    accessory n.同谋，从犯；附件
    accident n.意外的；事故
    accidental a.偶然的；非本质的
    accommodate vt.容纳；供应，供给
    accommodation n.招待设备；预定铺位
    accompany vt.陪伴，陪同；伴随
    accomplish vt.达到(目的)；完成
    accord vt.使一致；给予
    accordance n.一致；和谐；授予']
    """
})
response = client.chat.completions.create(
    model="glm-4-plus",
    messages=messages_preset
)

# %%
print('开始生成带单词句子')
word_sentence = response.choices[0].message.content
print(word_sentence)
print('带单词句子生成完成')
# Out:
# 开始生成带单词句子
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《千与千寻》中，千寻意外地进入了一个神秘的世界，她需要找到通往这个世界的access以返回现实。"
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中的无脸男可以被视为千寻冒险中的一个accessory，因为他在某些情况下帮助了她。"
#     },
#     {
#         "word": "accident",
#         "dialog": "千寻的父母因为贪吃变成了猪，这完全是一个accident，开启了千寻的奇幻之旅。"
#     },
#     {
#         "word": "accidental",
#         "dialog": "千寻在油屋的种种遭遇都是accidental，但她勇敢地面对了每一个挑战。"
#     },
#     {
#         "word": "accommodate",
#         "dialog": "油屋的汤婆婆能够accommodate各种神灵和妖怪，展现了她的强大能力。"
#     },
#     {
#         "word": "accommodation",
#         "dialog": "千寻在油屋找到了暂时的accommodation，开始了她的工作生活。"
#     },
#     {
#         "word": "accompany",
#         "dialog": "白龙多次accompany千寻，帮助她克服重重困难。"
#     },
#     {
#         "word": "accomplish",
#         "dialog": "通过不懈的努力，千寻最终accomplish了她的目标，救出了父母。"
#     },
#     {
#         "word": "accord",
#         "dialog": "千寻与白龙的友情是基于相互理解和accord，帮助他们共同面对挑战。"
#     },
#     {
#         "word": "accordance",
#         "dialog": "千寻在油屋的一切行为都尽力保持与规则和accordance，以避免麻烦。"
#     }
# ]
# ```
# 带单词句子生成完成

# %%
messages_preset.append({
    "role": "assistant",
    "content": f"{word_sentence}"
})
messages_preset.append({
    "role": "user",
    "content": "基于这个json进行将每个对话丰富一下情感和故事性"
})
response = client.chat.completions.create(
    model="glm-4-plus",
    messages=messages_preset
)

# %%
print('开始生成更长的句子')
word_long_sentence = response.choices[0].message.content
print(word_long_sentence)
print('更长句子生成完成')
# Out:
# 开始生成更长的句子
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《千与千寻》中，千寻意外地踏入了一个充满魔法与未知的神秘世界，她的心中充满了迷茫与恐惧。她迫切地需要找到一条通往这个世界的access，那是她重返温暖现实家园的唯一希望。"
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中的无脸男，沉默而神秘，他悄然出现在千寻的身边，成为了她冒险旅程中的一个不可或缺的accessory。在千寻最需要帮助的时刻，他默默地伸出援手，给予她力量与勇气。"
#     },
#     {
#         "word": "accident",
#         "dialog": "千寻的父母因一时的贪念，误食了神明的食物，瞬间变成了肥硕的猪。这一切发生得如此突然，宛如一场噩梦般的accident，将千寻推入了一个充满未知与挑战的奇幻世界。"
#     },
#     {
#         "word": "accidental",
#         "dialog": "在油屋的每一天，千寻都遭遇着各种accidental的困境与考验。然而，正是这些偶然的经历，磨练了她的意志，让她逐渐成长为勇敢而坚强的少女。"
#     },
#     {
#         "word": "accommodate",
#         "dialog": "汤婆婆的油屋如同一个包容万象的巨大宫殿，她能够accommodate来自四面八方的神灵与妖怪。这里的每一个角落都充满了神秘与奇幻，让人目不暇接。"
#     },
#     {
#         "word": "accommodation",
#         "dialog": "在油屋的深处，千寻找到了一个狭小却温馨的accommodation。这里成为了她在异世界中唯一的避风港，也是她积蓄力量、迎接新挑战的起点。"
#     },
#     {
#         "word": "accompany",
#         "dialog": "白龙，那位温柔而强大的神灵，多次accompany在千寻的身边。他用自己的力量和智慧，为她指引方向、排忧解难，成为了她在这场冒险中最坚实的后盾。"
#     },
#     {
#         "word": "accomplish",
#         "dialog": "面对重重困难与考验，千寻从未放弃过希望。她凭借着坚定的信念和不懈的努力，最终accomplish了她的目标——不仅救出了父母，更找回了自己的名字与初心。"
#     },
#     {
#         "word": "accord",
#         "dialog": "千寻与白龙之间的友情，如同天空中最亮的星辰，彼此相互照耀。他们的心灵在相互理解和accord中紧密相连，共同面对着前方的风风雨雨。"
#     },
#     {
#         "word": "accordance",
#         "dialog": "在油屋这个充满规则与秩序的世界里，千寻始终小心翼翼地保持着与周围环境的accordance。她深知，只有顺应这里的规则，才能更好地保护自己、实现目标。"
#     }
# ]
# ```
# 更长句子生成完成

# %%
messages_preset.append({
    "role": "assistant",
    "content": f"{word_long_sentence}"
})
messages_preset.append({
    "role": "user",
    "content": """
    基于这个json进行给每个小json加选项，2个混淆翻译和1个正确翻译，正确翻译要符合语境，而不是脱离语境的翻译，options格式如下：options: [
        { text: "入口", isCorrect: True },
        { text: "通道", isCorrect: False  },
        { text: "接近", isCorrect: False  },
      ],
      """
})
response = client.chat.completions.create(
    model="glm-4-plus",
    messages=messages_preset
)

# %%
print('开始给每个内容加选项')
add_options = response.choices[0].message.content
print(add_options)
print('给每个内容加选项完成')
# Out:
# 开始给每个内容加选项
# ```json
# [
#     {
#         "word": "access",
#         "dialog": "在《千与千寻》中，千寻意外地踏入了一个充满魔法与未知的神秘世界，她的心中充满了迷茫与恐惧。她迫切地需要找到一条通往这个世界的access，那是她重返温暖现实家园的唯一希望。",
#         "options": [
#             { "text": "入口", "isCorrect": true },
#             { "text": "通道", "isCorrect": false },
#             { "text": "接近", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accessory",
#         "dialog": "电影中的无脸男，沉默而神秘，他悄然出现在千寻的身边，成为了她冒险旅程中的一个不可或缺的accessory。在千寻最需要帮助的时刻，他默默地伸出援手，给予她力量与勇气。",
#         "options": [
#             { "text": "助手", "isCorrect": true },
#             { "text": "装饰品", "isCorrect": false },
#             { "text": "附件", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accident",
#         "dialog": "千寻的父母因一时的贪念，误食了神明的食物，瞬间变成了肥硕的猪。这一切发生得如此突然，宛如一场噩梦般的accident，将千寻推入了一个充满未知与挑战的奇幻世界。",
#         "options": [
#             { "text": "意外", "isCorrect": true },
#             { "text": "事故", "isCorrect": false },
#             { "text": "巧合", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accidental",
#         "dialog": "在油屋的每一天，千寻都遭遇着各种accidental的困境与考验。然而，正是这些偶然的经历，磨练了她的意志，让她逐渐成长为勇敢而坚强的少女。",
#         "options": [
#             { "text": "偶然的", "isCorrect": true },
#             { "text": "意外的", "isCorrect": false },
#             { "text": "非本质的", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accommodate",
#         "dialog": "汤婆婆的油屋如同一个包容万象的巨大宫殿，她能够accommodate来自四面八方的神灵与妖怪。这里的每一个角落都充满了神秘与奇幻，让人目不暇接。",
#         "options": [
#             { "text": "容纳", "isCorrect": true },
#             { "text": "供应", "isCorrect": false },
#             { "text": "适应", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accommodation",
#         "dialog": "在油屋的深处，千寻找到了一个狭小却温馨的accommodation。这里成为了她在异世界中唯一的避风港，也是她积蓄力量、迎接新挑战的起点。",
#         "options": [
#             { "text": "住处", "isCorrect": true },
#             { "text": "设备", "isCorrect": false },
#             { "text": "预定铺位", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accompany",
#         "dialog": "白龙，那位温柔而强大的神灵，多次accompany在千寻的身边。他用自己的力量和智慧，为她指引方向、排忧解难，成为了她在这场冒险中最坚实的后盾。",
#         "options": [
#             { "text": "陪伴", "isCorrect": true },
#             { "text": "陪同", "isCorrect": false },
#             { "text": "伴随", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accomplish",
#         "dialog": "面对重重困难与考验，千寻从未放弃过希望。她凭借着坚定的信念和不懈的努力，最终accomplish了她的目标——不仅救出了父母，更找回了自己的名字与初心。",
#         "options": [
#             { "text": "完成", "isCorrect": true },
#             { "text": "达到", "isCorrect": false },
#             { "text": "实现", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accord",
#         "dialog": "千寻与白龙之间的友情，如同天空中最亮的星辰，彼此相互照耀。他们的心灵在相互理解和accord中紧密相连，共同面对着前方的风风雨雨。",
#         "options": [
#             { "text": "和谐", "isCorrect": true },
#             { "text": "一致", "isCorrect": false },
#             { "text": "给予", "isCorrect": false }
#         ]
#     },
#     {
#         "word": "accordance",
#         "dialog": "在油屋这个充满规则与秩序的世界里，千寻始终小心翼翼地保持着与周围环境的accordance。她深知，只有顺应这里的规则，才能更好地保护自己、实现目标。",
#         "options": [
#             { "text": "一致", "isCorrect": true },
#             { "text": "和谐", "isCorrect": false },
#             { "text": "授予", "isCorrect": false }
#         ]
#     }
# ]
# ```
# 给每个内容加选项完成

# %%
print('开始清除json多余字段')
clear_json_data = json.loads(add_options.replace("```json", "").replace("```", "").strip())
print(clear_json_data)
print('完成清除json多余字段')
# Out:
# 开始清除json多余字段
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地踏入了一个充满魔法与未知的神秘世界，她的心中充满了迷茫与恐惧。她迫切地需要找到一条通往这个世界的access，那是她重返温暖现实家园的唯一希望。', 'options': [{'text': '入口', 'isCorrect': True}, {'text': '通道', 'isCorrect': False}, {'text': '接近', 'isCorrect': False}]}, {'word': 'accessory', 'dialog': '电影中的无脸男，沉默而神秘，他悄然出现在千寻的身边，成为了她冒险旅程中的一个不可或缺的accessory。在千寻最需要帮助的时刻，他默默地伸出援手，给予她力量与勇气。', 'options': [{'text': '助手', 'isCorrect': True}, {'text': '装饰品', 'isCorrect': False}, {'text': '附件', 'isCorrect': False}]}, {'word': 'accident', 'dialog': '千寻的父母因一时的贪念，误食了神明的食物，瞬间变成了肥硕的猪。这一切发生得如此突然，宛如一场噩梦般的accident，将千寻推入了一个充满未知与挑战的奇幻世界。', 'options': [{'text': '意外', 'isCorrect': True}, {'text': '事故', 'isCorrect': False}, {'text': '巧合', 'isCorrect': False}]}, {'word': 'accidental', 'dialog': '在油屋的每一天，千寻都遭遇着各种accidental的困境与考验。然而，正是这些偶然的经历，磨练了她的意志，让她逐渐成长为勇敢而坚强的少女。', 'options': [{'text': '偶然的', 'isCorrect': True}, {'text': '意外的', 'isCorrect': False}, {'text': '非本质的', 'isCorrect': False}]}, {'word': 'accommodate', 'dialog': '汤婆婆的油屋如同一个包容万象的巨大宫殿，她能够accommodate来自四面八方的神灵与妖怪。这里的每一个角落都充满了神秘与奇幻，让人目不暇接。', 'options': [{'text': '容纳', 'isCorrect': True}, {'text': '供应', 'isCorrect': False}, {'text': '适应', 'isCorrect': False}]}, {'word': 'accommodation', 'dialog': '在油屋的深处，千寻找到了一个狭小却温馨的accommodation。这里成为了她在异世界中唯一的避风港，也是她积蓄力量、迎接新挑战的起点。', 'options': [{'text': '住处', 'isCorrect': True}, {'text': '设备', 'isCorrect': False}, {'text': '预定铺位', 'isCorrect': False}]}, {'word': 'accompany', 'dialog': '白龙，那位温柔而强大的神灵，多次accompany在千寻的身边。他用自己的力量和智慧，为她指引方向、排忧解难，成为了她在这场冒险中最坚实的后盾。', 'options': [{'text': '陪伴', 'isCorrect': True}, {'text': '陪同', 'isCorrect': False}, {'text': '伴随', 'isCorrect': False}]}, {'word': 'accomplish', 'dialog': '面对重重困难与考验，千寻从未放弃过希望。她凭借着坚定的信念和不懈的努力，最终accomplish了她的目标——不仅救出了父母，更找回了自己的名字与初心。', 'options': [{'text': '完成', 'isCorrect': True}, {'text': '达到', 'isCorrect': False}, {'text': '实现', 'isCorrect': False}]}, {'word': 'accord', 'dialog': '千寻与白龙之间的友情，如同天空中最亮的星辰，彼此相互照耀。他们的心灵在相互理解和accord中紧密相连，共同面对着前方的风风雨雨。', 'options': [{'text': '和谐', 'isCorrect': True}, {'text': '一致', 'isCorrect': False}, {'text': '给予', 'isCorrect': False}]}, {'word': 'accordance', 'dialog': '在油屋这个充满规则与秩序的世界里，千寻始终小心翼翼地保持着与周围环境的accordance。她深知，只有顺应这里的规则，才能更好地保护自己、实现目标。', 'options': [{'text': '一致', 'isCorrect': True}, {'text': '和谐', 'isCorrect': False}, {'text': '授予', 'isCorrect': False}]}]
# 完成清除json多余字段

# %%
print('开始选项随机操作')

import random

# 为每个条目的options列表随机打乱顺序
for item in clear_json_data:
    random.shuffle(item["options"])

# 打印结果以验证
for item in clear_json_data:
    print(f"Word: {item['word']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}")
    print("-" * 50)

random_json_data = clear_json_data
print('完成选项随机操作')
# Out:
# 开始选项随机操作
# Word: access
# Translation: 接近, Correct: False
# Translation: 通道, Correct: False
# Translation: 入口, Correct: True
# --------------------------------------------------
# Word: accessory
# Translation: 附件, Correct: False
# Translation: 装饰品, Correct: False
# Translation: 助手, Correct: True
# --------------------------------------------------
# Word: accident
# Translation: 巧合, Correct: False
# Translation: 事故, Correct: False
# Translation: 意外, Correct: True
# --------------------------------------------------
# Word: accidental
# Translation: 偶然的, Correct: True
# Translation: 意外的, Correct: False
# Translation: 非本质的, Correct: False
# --------------------------------------------------
# Word: accommodate
# Translation: 适应, Correct: False
# Translation: 供应, Correct: False
# Translation: 容纳, Correct: True
# --------------------------------------------------
# Word: accommodation
# Translation: 设备, Correct: False
# Translation: 住处, Correct: True
# Translation: 预定铺位, Correct: False
# --------------------------------------------------
# Word: accompany
# Translation: 陪伴, Correct: True
# Translation: 伴随, Correct: False
# Translation: 陪同, Correct: False
# --------------------------------------------------
# Word: accomplish
# Translation: 实现, Correct: False
# Translation: 完成, Correct: True
# Translation: 达到, Correct: False
# --------------------------------------------------
# Word: accord
# Translation: 一致, Correct: False
# Translation: 给予, Correct: False
# Translation: 和谐, Correct: True
# --------------------------------------------------
# Word: accordance
# Translation: 授予, Correct: False
# Translation: 一致, Correct: True
# Translation: 和谐, Correct: False
# --------------------------------------------------
# 完成选项随机操作

# %%
print(random_json_data)
# Out:
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地踏入了一个充满魔法与未知的神秘世界，她的心中充满了迷茫与恐惧。她迫切地需要找到一条通往这个世界的access，那是她重返温暖现实家园的唯一希望。', 'options': [{'text': '接近', 'isCorrect': False}, {'text': '通道', 'isCorrect': False}, {'text': '入口', 'isCorrect': True}]}, {'word': 'accessory', 'dialog': '电影中的无脸男，沉默而神秘，他悄然出现在千寻的身边，成为了她冒险旅程中的一个不可或缺的accessory。在千寻最需要帮助的时刻，他默默地伸出援手，给予她力量与勇气。', 'options': [{'text': '附件', 'isCorrect': False}, {'text': '装饰品', 'isCorrect': False}, {'text': '助手', 'isCorrect': True}]}, {'word': 'accident', 'dialog': '千寻的父母因一时的贪念，误食了神明的食物，瞬间变成了肥硕的猪。这一切发生得如此突然，宛如一场噩梦般的accident，将千寻推入了一个充满未知与挑战的奇幻世界。', 'options': [{'text': '巧合', 'isCorrect': False}, {'text': '事故', 'isCorrect': False}, {'text': '意外', 'isCorrect': True}]}, {'word': 'accidental', 'dialog': '在油屋的每一天，千寻都遭遇着各种accidental的困境与考验。然而，正是这些偶然的经历，磨练了她的意志，让她逐渐成长为勇敢而坚强的少女。', 'options': [{'text': '偶然的', 'isCorrect': True}, {'text': '意外的', 'isCorrect': False}, {'text': '非本质的', 'isCorrect': False}]}, {'word': 'accommodate', 'dialog': '汤婆婆的油屋如同一个包容万象的巨大宫殿，她能够accommodate来自四面八方的神灵与妖怪。这里的每一个角落都充满了神秘与奇幻，让人目不暇接。', 'options': [{'text': '适应', 'isCorrect': False}, {'text': '供应', 'isCorrect': False}, {'text': '容纳', 'isCorrect': True}]}, {'word': 'accommodation', 'dialog': '在油屋的深处，千寻找到了一个狭小却温馨的accommodation。这里成为了她在异世界中唯一的避风港，也是她积蓄力量、迎接新挑战的起点。', 'options': [{'text': '设备', 'isCorrect': False}, {'text': '住处', 'isCorrect': True}, {'text': '预定铺位', 'isCorrect': False}]}, {'word': 'accompany', 'dialog': '白龙，那位温柔而强大的神灵，多次accompany在千寻的身边。他用自己的力量和智慧，为她指引方向、排忧解难，成为了她在这场冒险中最坚实的后盾。', 'options': [{'text': '陪伴', 'isCorrect': True}, {'text': '伴随', 'isCorrect': False}, {'text': '陪同', 'isCorrect': False}]}, {'word': 'accomplish', 'dialog': '面对重重困难与考验，千寻从未放弃过希望。她凭借着坚定的信念和不懈的努力，最终accomplish了她的目标——不仅救出了父母，更找回了自己的名字与初心。', 'options': [{'text': '实现', 'isCorrect': False}, {'text': '完成', 'isCorrect': True}, {'text': '达到', 'isCorrect': False}]}, {'word': 'accord', 'dialog': '千寻与白龙之间的友情，如同天空中最亮的星辰，彼此相互照耀。他们的心灵在相互理解和accord中紧密相连，共同面对着前方的风风雨雨。', 'options': [{'text': '一致', 'isCorrect': False}, {'text': '给予', 'isCorrect': False}, {'text': '和谐', 'isCorrect': True}]}, {'word': 'accordance', 'dialog': '在油屋这个充满规则与秩序的世界里，千寻始终小心翼翼地保持着与周围环境的accordance。她深知，只有顺应这里的规则，才能更好地保护自己、实现目标。', 'options': [{'text': '授予', 'isCorrect': False}, {'text': '一致', 'isCorrect': True}, {'text': '和谐', 'isCorrect': False}]}]

# %%
print('开始添加下个场景字段')
# 为每个条目的options列表添加nextScene
i = 1
for item in random_json_data:
    for option in item['options']:
        if option['isCorrect']:
            option['nextScene'] = i
            i += 1
        else:
            option['nextScene'] = -1
            
# 打印结果以验证
for item in random_json_data:
    print(f"Word: {item['word']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
next_scene_json_data = random_json_data
print('添加下个场景字段完成')
# Out:
# 开始添加下个场景字段
# Word: access
# Translation: 接近, Correct: False, NextScene: -1
# Translation: 通道, Correct: False, NextScene: -1
# Translation: 入口, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: accessory
# Translation: 附件, Correct: False, NextScene: -1
# Translation: 装饰品, Correct: False, NextScene: -1
# Translation: 助手, Correct: True, NextScene: 2
# --------------------------------------------------
# Word: accident
# Translation: 巧合, Correct: False, NextScene: -1
# Translation: 事故, Correct: False, NextScene: -1
# Translation: 意外, Correct: True, NextScene: 3
# --------------------------------------------------
# Word: accidental
# Translation: 偶然的, Correct: True, NextScene: 4
# Translation: 意外的, Correct: False, NextScene: -1
# Translation: 非本质的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accommodate
# Translation: 适应, Correct: False, NextScene: -1
# Translation: 供应, Correct: False, NextScene: -1
# Translation: 容纳, Correct: True, NextScene: 5
# --------------------------------------------------
# Word: accommodation
# Translation: 设备, Correct: False, NextScene: -1
# Translation: 住处, Correct: True, NextScene: 6
# Translation: 预定铺位, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accompany
# Translation: 陪伴, Correct: True, NextScene: 7
# Translation: 伴随, Correct: False, NextScene: -1
# Translation: 陪同, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accomplish
# Translation: 实现, Correct: False, NextScene: -1
# Translation: 完成, Correct: True, NextScene: 8
# Translation: 达到, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accord
# Translation: 一致, Correct: False, NextScene: -1
# Translation: 给予, Correct: False, NextScene: -1
# Translation: 和谐, Correct: True, NextScene: 9
# --------------------------------------------------
# Word: accordance
# Translation: 授予, Correct: False, NextScene: -1
# Translation: 一致, Correct: True, NextScene: 10
# Translation: 和谐, Correct: False, NextScene: -1
# --------------------------------------------------
# 添加下个场景字段完成

# %%
print('在json中添加npcName字段')

# 为每个条目添加npcName字段
for item in next_scene_json_data:
    item['npcName'] = "宫崎骏"  # 添加npcName字段

# 打印结果以验证
for item in next_scene_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
npc_name_json_data = next_scene_json_data
print('在json中添加npcName字段完成')
# Out:
# 在json中添加npcName字段
# Word: access, NPC Name: 宫崎骏
# Translation: 接近, Correct: False, NextScene: -1
# Translation: 通道, Correct: False, NextScene: -1
# Translation: 入口, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: accessory, NPC Name: 宫崎骏
# Translation: 附件, Correct: False, NextScene: -1
# Translation: 装饰品, Correct: False, NextScene: -1
# Translation: 助手, Correct: True, NextScene: 2
# --------------------------------------------------
# Word: accident, NPC Name: 宫崎骏
# Translation: 巧合, Correct: False, NextScene: -1
# Translation: 事故, Correct: False, NextScene: -1
# Translation: 意外, Correct: True, NextScene: 3
# --------------------------------------------------
# Word: accidental, NPC Name: 宫崎骏
# Translation: 偶然的, Correct: True, NextScene: 4
# Translation: 意外的, Correct: False, NextScene: -1
# Translation: 非本质的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accommodate, NPC Name: 宫崎骏
# Translation: 适应, Correct: False, NextScene: -1
# Translation: 供应, Correct: False, NextScene: -1
# Translation: 容纳, Correct: True, NextScene: 5
# --------------------------------------------------
# Word: accommodation, NPC Name: 宫崎骏
# Translation: 设备, Correct: False, NextScene: -1
# Translation: 住处, Correct: True, NextScene: 6
# Translation: 预定铺位, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accompany, NPC Name: 宫崎骏
# Translation: 陪伴, Correct: True, NextScene: 7
# Translation: 伴随, Correct: False, NextScene: -1
# Translation: 陪同, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accomplish, NPC Name: 宫崎骏
# Translation: 实现, Correct: False, NextScene: -1
# Translation: 完成, Correct: True, NextScene: 8
# Translation: 达到, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accord, NPC Name: 宫崎骏
# Translation: 一致, Correct: False, NextScene: -1
# Translation: 给予, Correct: False, NextScene: -1
# Translation: 和谐, Correct: True, NextScene: 9
# --------------------------------------------------
# Word: accordance, NPC Name: 宫崎骏
# Translation: 授予, Correct: False, NextScene: -1
# Translation: 一致, Correct: True, NextScene: 10
# Translation: 和谐, Correct: False, NextScene: -1
# --------------------------------------------------
# 在json中添加npcName字段完成

# %%
print('在json中添加npcAvatar字段')
# 为每个条目添加npcAvatar字段
for item in npc_name_json_data:
    item['npcAvatar'] = "/avatars/gongqijun.jpg"  # 添加npcAvatar字段

# 打印结果以验证
for item in npc_name_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
npc_avatar_json_data = npc_name_json_data
print('在json中添加npcName和npcAvatar字段完成')
# Out:
# 在json中添加npcAvatar字段
# Word: access, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 接近, Correct: False, NextScene: -1
# Translation: 通道, Correct: False, NextScene: -1
# Translation: 入口, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: accessory, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 附件, Correct: False, NextScene: -1
# Translation: 装饰品, Correct: False, NextScene: -1
# Translation: 助手, Correct: True, NextScene: 2
# --------------------------------------------------
# Word: accident, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 巧合, Correct: False, NextScene: -1
# Translation: 事故, Correct: False, NextScene: -1
# Translation: 意外, Correct: True, NextScene: 3
# --------------------------------------------------
# Word: accidental, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 偶然的, Correct: True, NextScene: 4
# Translation: 意外的, Correct: False, NextScene: -1
# Translation: 非本质的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accommodate, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 适应, Correct: False, NextScene: -1
# Translation: 供应, Correct: False, NextScene: -1
# Translation: 容纳, Correct: True, NextScene: 5
# --------------------------------------------------
# Word: accommodation, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 设备, Correct: False, NextScene: -1
# Translation: 住处, Correct: True, NextScene: 6
# Translation: 预定铺位, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accompany, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 陪伴, Correct: True, NextScene: 7
# Translation: 伴随, Correct: False, NextScene: -1
# Translation: 陪同, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accomplish, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 实现, Correct: False, NextScene: -1
# Translation: 完成, Correct: True, NextScene: 8
# Translation: 达到, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accord, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 一致, Correct: False, NextScene: -1
# Translation: 给予, Correct: False, NextScene: -1
# Translation: 和谐, Correct: True, NextScene: 9
# --------------------------------------------------
# Word: accordance, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg
# Translation: 授予, Correct: False, NextScene: -1
# Translation: 一致, Correct: True, NextScene: 10
# Translation: 和谐, Correct: False, NextScene: -1
# --------------------------------------------------
# 在json中添加npcName和npcAvatar字段完成

# %%
print('在json中添加backgroundVideo字段')
# 为每个条目添加npcName、npcAvatar和backgroundVideo字段
for item in npc_avatar_json_data:
    item['backgroundVideo'] = "/videos/qianyuqianxun.mp4"  # 添加backgroundVideo字段

# 打印结果以验证
for item in npc_avatar_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}, Background Video: {item['backgroundVideo']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)
background_video_json_data = random_json_data
print('在json中添加npcName、npcAvatar和backgroundVideo字段完成')

print(background_video_json_data)
# Out:
# 在json中添加backgroundVideo字段
# Word: access, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 接近, Correct: False, NextScene: -1
# Translation: 通道, Correct: False, NextScene: -1
# Translation: 入口, Correct: True, NextScene: 1
# --------------------------------------------------
# Word: accessory, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 附件, Correct: False, NextScene: -1
# Translation: 装饰品, Correct: False, NextScene: -1
# Translation: 助手, Correct: True, NextScene: 2
# --------------------------------------------------
# Word: accident, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 巧合, Correct: False, NextScene: -1
# Translation: 事故, Correct: False, NextScene: -1
# Translation: 意外, Correct: True, NextScene: 3
# --------------------------------------------------
# Word: accidental, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 偶然的, Correct: True, NextScene: 4
# Translation: 意外的, Correct: False, NextScene: -1
# Translation: 非本质的, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accommodate, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 适应, Correct: False, NextScene: -1
# Translation: 供应, Correct: False, NextScene: -1
# Translation: 容纳, Correct: True, NextScene: 5
# --------------------------------------------------
# Word: accommodation, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 设备, Correct: False, NextScene: -1
# Translation: 住处, Correct: True, NextScene: 6
# Translation: 预定铺位, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accompany, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 陪伴, Correct: True, NextScene: 7
# Translation: 伴随, Correct: False, NextScene: -1
# Translation: 陪同, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accomplish, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 实现, Correct: False, NextScene: -1
# Translation: 完成, Correct: True, NextScene: 8
# Translation: 达到, Correct: False, NextScene: -1
# --------------------------------------------------
# Word: accord, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 一致, Correct: False, NextScene: -1
# Translation: 给予, Correct: False, NextScene: -1
# Translation: 和谐, Correct: True, NextScene: 9
# --------------------------------------------------
# Word: accordance, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 授予, Correct: False, NextScene: -1
# Translation: 一致, Correct: True, NextScene: 10
# Translation: 和谐, Correct: False, NextScene: -1
# --------------------------------------------------
# 在json中添加npcName、npcAvatar和backgroundVideo字段完成
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地踏入了一个充满魔法与未知的神秘世界，她的心中充满了迷茫与恐惧。她迫切地需要找到一条通往这个世界的access，那是她重返温暖现实家园的唯一希望。', 'options': [{'text': '接近', 'isCorrect': False, 'nextScene': -1}, {'text': '通道', 'isCorrect': False, 'nextScene': -1}, {'text': '入口', 'isCorrect': True, 'nextScene': 1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accessory', 'dialog': '电影中的无脸男，沉默而神秘，他悄然出现在千寻的身边，成为了她冒险旅程中的一个不可或缺的accessory。在千寻最需要帮助的时刻，他默默地伸出援手，给予她力量与勇气。', 'options': [{'text': '附件', 'isCorrect': False, 'nextScene': -1}, {'text': '装饰品', 'isCorrect': False, 'nextScene': -1}, {'text': '助手', 'isCorrect': True, 'nextScene': 2}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accident', 'dialog': '千寻的父母因一时的贪念，误食了神明的食物，瞬间变成了肥硕的猪。这一切发生得如此突然，宛如一场噩梦般的accident，将千寻推入了一个充满未知与挑战的奇幻世界。', 'options': [{'text': '巧合', 'isCorrect': False, 'nextScene': -1}, {'text': '事故', 'isCorrect': False, 'nextScene': -1}, {'text': '意外', 'isCorrect': True, 'nextScene': 3}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accidental', 'dialog': '在油屋的每一天，千寻都遭遇着各种accidental的困境与考验。然而，正是这些偶然的经历，磨练了她的意志，让她逐渐成长为勇敢而坚强的少女。', 'options': [{'text': '偶然的', 'isCorrect': True, 'nextScene': 4}, {'text': '意外的', 'isCorrect': False, 'nextScene': -1}, {'text': '非本质的', 'isCorrect': False, 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accommodate', 'dialog': '汤婆婆的油屋如同一个包容万象的巨大宫殿，她能够accommodate来自四面八方的神灵与妖怪。这里的每一个角落都充满了神秘与奇幻，让人目不暇接。', 'options': [{'text': '适应', 'isCorrect': False, 'nextScene': -1}, {'text': '供应', 'isCorrect': False, 'nextScene': -1}, {'text': '容纳', 'isCorrect': True, 'nextScene': 5}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accommodation', 'dialog': '在油屋的深处，千寻找到了一个狭小却温馨的accommodation。这里成为了她在异世界中唯一的避风港，也是她积蓄力量、迎接新挑战的起点。', 'options': [{'text': '设备', 'isCorrect': False, 'nextScene': -1}, {'text': '住处', 'isCorrect': True, 'nextScene': 6}, {'text': '预定铺位', 'isCorrect': False, 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accompany', 'dialog': '白龙，那位温柔而强大的神灵，多次accompany在千寻的身边。他用自己的力量和智慧，为她指引方向、排忧解难，成为了她在这场冒险中最坚实的后盾。', 'options': [{'text': '陪伴', 'isCorrect': True, 'nextScene': 7}, {'text': '伴随', 'isCorrect': False, 'nextScene': -1}, {'text': '陪同', 'isCorrect': False, 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accomplish', 'dialog': '面对重重困难与考验，千寻从未放弃过希望。她凭借着坚定的信念和不懈的努力，最终accomplish了她的目标——不仅救出了父母，更找回了自己的名字与初心。', 'options': [{'text': '实现', 'isCorrect': False, 'nextScene': -1}, {'text': '完成', 'isCorrect': True, 'nextScene': 8}, {'text': '达到', 'isCorrect': False, 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accord', 'dialog': '千寻与白龙之间的友情，如同天空中最亮的星辰，彼此相互照耀。他们的心灵在相互理解和accord中紧密相连，共同面对着前方的风风雨雨。', 'options': [{'text': '一致', 'isCorrect': False, 'nextScene': -1}, {'text': '给予', 'isCorrect': False, 'nextScene': -1}, {'text': '和谐', 'isCorrect': True, 'nextScene': 9}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accordance', 'dialog': '在油屋这个充满规则与秩序的世界里，千寻始终小心翼翼地保持着与周围环境的accordance。她深知，只有顺应这里的规则，才能更好地保护自己、实现目标。', 'options': [{'text': '授予', 'isCorrect': False, 'nextScene': -1}, {'text': '一致', 'isCorrect': True, 'nextScene': 10}, {'text': '和谐', 'isCorrect': False, 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}]

# %%
print(background_video_json_data)
# Out:
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地踏入了一个充满魔法与未知的神秘世界，她的心中充满了迷茫与恐惧。她迫切地需要找到一条通往这个世界的access，那是她重返温暖现实家园的唯一希望。', 'options': [{'text': '接近', 'isCorrect': False, 'nextScene': -1}, {'text': '通道', 'isCorrect': False, 'nextScene': -1}, {'text': '入口', 'isCorrect': True, 'nextScene': 1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accessory', 'dialog': '电影中的无脸男，沉默而神秘，他悄然出现在千寻的身边，成为了她冒险旅程中的一个不可或缺的accessory。在千寻最需要帮助的时刻，他默默地伸出援手，给予她力量与勇气。', 'options': [{'text': '附件', 'isCorrect': False, 'nextScene': -1}, {'text': '装饰品', 'isCorrect': False, 'nextScene': -1}, {'text': '助手', 'isCorrect': True, 'nextScene': 2}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accident', 'dialog': '千寻的父母因一时的贪念，误食了神明的食物，瞬间变成了肥硕的猪。这一切发生得如此突然，宛如一场噩梦般的accident，将千寻推入了一个充满未知与挑战的奇幻世界。', 'options': [{'text': '巧合', 'isCorrect': False, 'nextScene': -1}, {'text': '事故', 'isCorrect': False, 'nextScene': -1}, {'text': '意外', 'isCorrect': True, 'nextScene': 3}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accidental', 'dialog': '在油屋的每一天，千寻都遭遇着各种accidental的困境与考验。然而，正是这些偶然的经历，磨练了她的意志，让她逐渐成长为勇敢而坚强的少女。', 'options': [{'text': '偶然的', 'isCorrect': True, 'nextScene': 4}, {'text': '意外的', 'isCorrect': False, 'nextScene': -1}, {'text': '非本质的', 'isCorrect': False, 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accommodate', 'dialog': '汤婆婆的油屋如同一个包容万象的巨大宫殿，她能够accommodate来自四面八方的神灵与妖怪。这里的每一个角落都充满了神秘与奇幻，让人目不暇接。', 'options': [{'text': '适应', 'isCorrect': False, 'nextScene': -1}, {'text': '供应', 'isCorrect': False, 'nextScene': -1}, {'text': '容纳', 'isCorrect': True, 'nextScene': 5}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accommodation', 'dialog': '在油屋的深处，千寻找到了一个狭小却温馨的accommodation。这里成为了她在异世界中唯一的避风港，也是她积蓄力量、迎接新挑战的起点。', 'options': [{'text': '设备', 'isCorrect': False, 'nextScene': -1}, {'text': '住处', 'isCorrect': True, 'nextScene': 6}, {'text': '预定铺位', 'isCorrect': False, 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accompany', 'dialog': '白龙，那位温柔而强大的神灵，多次accompany在千寻的身边。他用自己的力量和智慧，为她指引方向、排忧解难，成为了她在这场冒险中最坚实的后盾。', 'options': [{'text': '陪伴', 'isCorrect': True, 'nextScene': 7}, {'text': '伴随', 'isCorrect': False, 'nextScene': -1}, {'text': '陪同', 'isCorrect': False, 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accomplish', 'dialog': '面对重重困难与考验，千寻从未放弃过希望。她凭借着坚定的信念和不懈的努力，最终accomplish了她的目标——不仅救出了父母，更找回了自己的名字与初心。', 'options': [{'text': '实现', 'isCorrect': False, 'nextScene': -1}, {'text': '完成', 'isCorrect': True, 'nextScene': 8}, {'text': '达到', 'isCorrect': False, 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accord', 'dialog': '千寻与白龙之间的友情，如同天空中最亮的星辰，彼此相互照耀。他们的心灵在相互理解和accord中紧密相连，共同面对着前方的风风雨雨。', 'options': [{'text': '一致', 'isCorrect': False, 'nextScene': -1}, {'text': '给予', 'isCorrect': False, 'nextScene': -1}, {'text': '和谐', 'isCorrect': True, 'nextScene': 9}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accordance', 'dialog': '在油屋这个充满规则与秩序的世界里，千寻始终小心翼翼地保持着与周围环境的accordance。她深知，只有顺应这里的规则，才能更好地保护自己、实现目标。', 'options': [{'text': '授予', 'isCorrect': False, 'nextScene': -1}, {'text': '一致', 'isCorrect': True, 'nextScene': 10}, {'text': '和谐', 'isCorrect': False, 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}]

# %%
background_video_json_data.append({
      "word": "none",
      "dialog":
        "恭喜你完成了游戏的所有关卡，点击重玩游戏，重新开始游戏",
      "options": [
        { "text": "重玩游戏", "isCorrect": "true", "nextScene": 0 },
      ],
      "npcName": "宫崎骏",
      "npcAvatar": "/avatars/gongqijun.jpg",
      "backgroundVideo": "/videos/qianyuqianxun.mp4",
    })

# %%
# ... existing code ...

# 将options中的True和False改为小写字符串
for item in background_video_json_data:
    for option in item['options']:
        option['isCorrect'] = 'true' if option['isCorrect'] else 'false'

# 打印结果以验证
for item in background_video_json_data:
    print(f"Word: {item['word']}, NPC Name: {item['npcName']}, NPC Avatar: {item['npcAvatar']}, Background Video: {item['backgroundVideo']}")
    for option in item['options']:
        print(f"Translation: {option['text']}, Correct: {option['isCorrect']}, NextScene: {option.get('nextScene', 'N/A')}")
    print("-" * 50)

# ... existing code ...
# Out:
# Word: access, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 接近, Correct: false, NextScene: -1
# Translation: 通道, Correct: false, NextScene: -1
# Translation: 入口, Correct: true, NextScene: 1
# --------------------------------------------------
# Word: accessory, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 附件, Correct: false, NextScene: -1
# Translation: 装饰品, Correct: false, NextScene: -1
# Translation: 助手, Correct: true, NextScene: 2
# --------------------------------------------------
# Word: accident, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 巧合, Correct: false, NextScene: -1
# Translation: 事故, Correct: false, NextScene: -1
# Translation: 意外, Correct: true, NextScene: 3
# --------------------------------------------------
# Word: accidental, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 偶然的, Correct: true, NextScene: 4
# Translation: 意外的, Correct: false, NextScene: -1
# Translation: 非本质的, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: accommodate, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 适应, Correct: false, NextScene: -1
# Translation: 供应, Correct: false, NextScene: -1
# Translation: 容纳, Correct: true, NextScene: 5
# --------------------------------------------------
# Word: accommodation, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 设备, Correct: false, NextScene: -1
# Translation: 住处, Correct: true, NextScene: 6
# Translation: 预定铺位, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: accompany, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 陪伴, Correct: true, NextScene: 7
# Translation: 伴随, Correct: false, NextScene: -1
# Translation: 陪同, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: accomplish, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 实现, Correct: false, NextScene: -1
# Translation: 完成, Correct: true, NextScene: 8
# Translation: 达到, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: accord, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 一致, Correct: false, NextScene: -1
# Translation: 给予, Correct: false, NextScene: -1
# Translation: 和谐, Correct: true, NextScene: 9
# --------------------------------------------------
# Word: accordance, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/qianyuqianxun.mp4
# Translation: 授予, Correct: false, NextScene: -1
# Translation: 一致, Correct: true, NextScene: 10
# Translation: 和谐, Correct: false, NextScene: -1
# --------------------------------------------------
# Word: none, NPC Name: 宫崎骏, NPC Avatar: /avatars/gongqijun.jpg, Background Video: /videos/2077.mp4
# Translation: 重玩游戏, Correct: true, NextScene: 0
# --------------------------------------------------

# %%
print(background_video_json_data)
# Out:
# [{'word': 'access', 'dialog': '在《千与千寻》中，千寻意外地踏入了一个充满魔法与未知的神秘世界，她的心中充满了迷茫与恐惧。她迫切地需要找到一条通往这个世界的access，那是她重返温暖现实家园的唯一希望。', 'options': [{'text': '接近', 'isCorrect': 'false', 'nextScene': -1}, {'text': '通道', 'isCorrect': 'false', 'nextScene': -1}, {'text': '入口', 'isCorrect': 'true', 'nextScene': 1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accessory', 'dialog': '电影中的无脸男，沉默而神秘，他悄然出现在千寻的身边，成为了她冒险旅程中的一个不可或缺的accessory。在千寻最需要帮助的时刻，他默默地伸出援手，给予她力量与勇气。', 'options': [{'text': '附件', 'isCorrect': 'false', 'nextScene': -1}, {'text': '装饰品', 'isCorrect': 'false', 'nextScene': -1}, {'text': '助手', 'isCorrect': 'true', 'nextScene': 2}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accident', 'dialog': '千寻的父母因一时的贪念，误食了神明的食物，瞬间变成了肥硕的猪。这一切发生得如此突然，宛如一场噩梦般的accident，将千寻推入了一个充满未知与挑战的奇幻世界。', 'options': [{'text': '巧合', 'isCorrect': 'false', 'nextScene': -1}, {'text': '事故', 'isCorrect': 'false', 'nextScene': -1}, {'text': '意外', 'isCorrect': 'true', 'nextScene': 3}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accidental', 'dialog': '在油屋的每一天，千寻都遭遇着各种accidental的困境与考验。然而，正是这些偶然的经历，磨练了她的意志，让她逐渐成长为勇敢而坚强的少女。', 'options': [{'text': '偶然的', 'isCorrect': 'true', 'nextScene': 4}, {'text': '意外的', 'isCorrect': 'false', 'nextScene': -1}, {'text': '非本质的', 'isCorrect': 'false', 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accommodate', 'dialog': '汤婆婆的油屋如同一个包容万象的巨大宫殿，她能够accommodate来自四面八方的神灵与妖怪。这里的每一个角落都充满了神秘与奇幻，让人目不暇接。', 'options': [{'text': '适应', 'isCorrect': 'false', 'nextScene': -1}, {'text': '供应', 'isCorrect': 'false', 'nextScene': -1}, {'text': '容纳', 'isCorrect': 'true', 'nextScene': 5}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accommodation', 'dialog': '在油屋的深处，千寻找到了一个狭小却温馨的accommodation。这里成为了她在异世界中唯一的避风港，也是她积蓄力量、迎接新挑战的起点。', 'options': [{'text': '设备', 'isCorrect': 'false', 'nextScene': -1}, {'text': '住处', 'isCorrect': 'true', 'nextScene': 6}, {'text': '预定铺位', 'isCorrect': 'false', 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accompany', 'dialog': '白龙，那位温柔而强大的神灵，多次accompany在千寻的身边。他用自己的力量和智慧，为她指引方向、排忧解难，成为了她在这场冒险中最坚实的后盾。', 'options': [{'text': '陪伴', 'isCorrect': 'true', 'nextScene': 7}, {'text': '伴随', 'isCorrect': 'false', 'nextScene': -1}, {'text': '陪同', 'isCorrect': 'false', 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accomplish', 'dialog': '面对重重困难与考验，千寻从未放弃过希望。她凭借着坚定的信念和不懈的努力，最终accomplish了她的目标——不仅救出了父母，更找回了自己的名字与初心。', 'options': [{'text': '实现', 'isCorrect': 'false', 'nextScene': -1}, {'text': '完成', 'isCorrect': 'true', 'nextScene': 8}, {'text': '达到', 'isCorrect': 'false', 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accord', 'dialog': '千寻与白龙之间的友情，如同天空中最亮的星辰，彼此相互照耀。他们的心灵在相互理解和accord中紧密相连，共同面对着前方的风风雨雨。', 'options': [{'text': '一致', 'isCorrect': 'false', 'nextScene': -1}, {'text': '给予', 'isCorrect': 'false', 'nextScene': -1}, {'text': '和谐', 'isCorrect': 'true', 'nextScene': 9}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'accordance', 'dialog': '在油屋这个充满规则与秩序的世界里，千寻始终小心翼翼地保持着与周围环境的accordance。她深知，只有顺应这里的规则，才能更好地保护自己、实现目标。', 'options': [{'text': '授予', 'isCorrect': 'false', 'nextScene': -1}, {'text': '一致', 'isCorrect': 'true', 'nextScene': 10}, {'text': '和谐', 'isCorrect': 'false', 'nextScene': -1}], 'npcName': '宫崎骏', 'npcAvatar': '/avatars/gongqijun.jpg', 'backgroundVideo': '/videos/qianyuqianxun.mp4'}, {'word': 'none', 'dialog': '恭喜你完成了游戏的所有关卡，点击重玩游戏，重新开始游戏', 'op ...
